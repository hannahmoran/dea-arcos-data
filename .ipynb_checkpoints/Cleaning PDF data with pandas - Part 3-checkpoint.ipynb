# %% [markdown]
# # Cleaning messy PDF data with pandas and Jupyter notebooks
# ## Part 3 - DEA ARCOS Report 5: Statistical Summary for Retail Drug Purchases

# %% [markdown]
# ### Background
#
# #### What is ARCOS?
# The DEA publishes data annually from its Automation of Reports and Consolidated Orders System, or ARCOS. According to the DEA's website, ARCOS "monitors the flow of DEA controlled substances from their point of manufacture through commercial distribution channels to point of sale or distribution at the dispensing/retail level - hospitals, retail pharmacies, practitioners, mid-level practitioners, and teaching institutions....these transactions...are then summarized into reports which give investigators in Federal and state government agencies information which can then be used to identify the diversion of controlled substances into illicit channels of distribution. The information on drug distribution is used throughout the United States (U.S.) by U.S. Attorneys and DEA investigators to strengthen criminal cases in the courts."
#
# So, ARCOS exists to help the government identify patterns in the manufacture and distribution of controlled substances that might indicate that these substances are being sold illegally. Annual ARCOS reports are publically available on the DEA's website, dating back to the year 2000, but unfortunately they are only available in PDF form and are dozens or even hundreds of pages long.
#
# #### What's in this notebook?
# I was interested in doing some data analysis and visualization on the distribution of oxycodone, an opioid painkiller that is one of the main drivers of the current prescription pain pill (and arguably heroin) addiction epidemic in the United States right now.
#
# Aside from a wealth of fascinating (and sometimes disturbing, sad, and frightening) data to explore, the ARCOS data also presents a great data cleansing challenge, given that it is distributed in PDFs - the perfect opportunity to practice your pandas skills, for example. Luckily, the files tend to have nearly identical formatting, aside from a shift in report formatting in 2006 and a few anomalies here and there.
#
# This notebook is also meant to show the functionality of pandas and Jupyter notebooks for data cleaning - working with this data was a great project for me to improve my pandas skills and I'm sharing the code here so others can learn and practice.
#
# This is part 3 - analysis of Report 5.

# %%
# load libraries, the drug code dict, and list of territories
import pandas as pd
import numpy as np
import pickle

drug_codes = pickle.load(open("drug_codes.pickle", "rb"))
geos = pickle.load(open("geographies.pickle", "rb"))

# make a list of all possible parts of state names for later validation
l = [x.split(" ") for x in geos]
flat_geos = [i for sublist in l for i in sublist]
flat_geos = set(flat_geos)

# activity codes dictionary & flat list
activity_codes = {'A': 'PHARMACIES', 
                  'B': 'HOSPITALS', 
                  'C': 'PRACTITIONERS', 
                  'D': 'TEACHING INSTITUTIONS',
                  'M': 'MID-LEVEL PRACTITIONERS', 
                  'N-U': 'NARCOTIC TREATMENT PROGRAMS'}
l = [x.split(" ") for x in activity_codes.values()]
flat_activity_codes = [i for sublist in l for i in sublist]
flat_activity_codes = set(flat_activity_codes)

del l

# %% [markdown]
# ### Notes on the data
#
# Get the raw data (in PDF....!)
# You can find the ARCOS reports here: https://www.deadiversion.usdoj.gov/arcos/retail_drug_summary/index.html
#
# There are six ARCOS reports published each year and I chose to work with three of them in particular:
# * Report 1:  Retail Drug Distribution by Zip Code for Each State - total drug amounts (in grams) distributed to retail registrants in each state, by 'gateway' zip code (the first three numbers of the zip), on a quarterly basis
# * Report 3: Quarterly Distribution in Grams per 100K Population - quarterly drug consumption in grams per 100,000 population, by state
# * Report 5: Statistical Summary for Retail Drug Purchases - average annual purchases by drug by business activity (pharmacy, hospital, etc.)
#
#
# A few notes:
#
# * For years before 2006, the reports are lumped together into one giant PDF (700+ pages long). In more recent years they have elected to publish a separate PDF for each report.
#
# * I tried several approaches for simply getting the text out of the PDF - for a variety of reasons (in particular the unwieldy nature of the pre-2006 PDFs), it was easiest and quickest to just copy-paste the entire contents of the PDF into a text file. This was an OK solution for me since there aren't that many of them - if you were doing this with hundreds of files you would want to find another way. Another problem I ran into right away was the length of the title running onto multiple lines in the txt file and causing a lot of formatting challenges in a dataframe, so I manually adjusted the title text in each txt file.
#
# * For the pre-2006 reports, I (manually and carefully) removed the report content I wasn't interested in from the text file, and then used pandas to clean what remained.

# %% [markdown]
# In this notebook we will be working with Report 5, the distribution by retail activity.
#
# #### Step 1 - Getting from PDF to pandas in the notebook
#
#
# What to consider and experiment with:
# * How will you pull the data out of the PDF? How much of the formatting (columns, headers, etc) will you be able to preserve?
# * What delimiter works best?
# * If the number of PDF files is small, are there any steps you can perform right in the txt or spreadsheet file that will make things easier?
#
# There are different options for getting data from a PDF into a format you can interact with more directly. I ended up just copy-pasting the full contents of each file as it didn't seem that some of the PDF-to-spreadsheet/other tools out there would really save me that much time.
#
# I tried several text editors and spreadsheet applications, looking for something that would do a relatively good job delimiting the data based on the PDF files. Sublime is one of my favorites and that's what I used in the end.
#
# Tips
# * Try a couple different editors and delimit options, and read each one into pandas to see how the structure of the data looks. Choose one that will minimize the amount of cleaning you need to do
# * Keep your .txt file open as you begin cleaning in pandas
# * Never save over your raw .txt file! This is a trial-and-error process and you will likely end up losing some data at one point or another. If you've saved over the starting point you will have to go back to your PDF...
#
# These were the nastiest by far in terms of formatting and I ended up with many versions of the cleaning function. My approach to this was to run the function line by line when it failed to process a file correctly, find the issue and fix it and allow that to be a separate new function. You could take the extra step of refactoring them all into one version.

# %%
activity_2000 = pd.read_csv('activity_2000.txt', delim_whitespace=True)
activity_2000.head(10)
# Out:
#                                                ARCOS            2           -  \
# 0                                          REPORTING      PERIOD:  01/01/2000
# 1                                             STATE:       ALASKA    BUSINESS
# 2                                             NUMBER           OF       TOTAL
# 3                                               DRUG  REGISTRANTS        SOLD
# 4                                               DRUG         NAME        CODE
# 5  ----------------------------------------------...          NaN         NaN
# 6                                     DL-AMPHETAMINE         BASE       1100B
# 7                                      D-AMPHETAMINE         BASE       1100D
# 8                                    METHYLPHENIDATE         1724          80
# 9                                          OXYCODONE         9143          82
#
#       REPORT           5  STATISTICAL     SUMMARY  FOR  RETAIL  DRUG  \
# 0         TO  12/31/2000          NaN         NaN  NaN     NaN   NaN
# 1  ACTIVITY:  PHARMACIES          NaN         NaN  NaN     NaN   NaN
# 2      GRAMS     AVERAGE          NaN         NaN  NaN     NaN   NaN
# 3         TO    PURCHASE          PER         NaN  NaN     NaN   NaN
# 4       SOLD          TO  REGISTRANTS  REGISTRANT  NaN     NaN   NaN
# 5        NaN         NaN          NaN         NaN  NaN     NaN   NaN
# 6         75    2,359.66        31.46         NaN  NaN     NaN   NaN
# 7         79    7,791.91        98.63         NaN  NaN     NaN   NaN
# 8  12,855.76      160.69          NaN         NaN  NaN     NaN   NaN
# 9  65,876.54      803.37          NaN         NaN  NaN     NaN   NaN
#
#    PURCHASES
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN

# %% [markdown]
# We can already see this is going to be a lot harder to deal with - just for a start, the drug names come before the codes and are spread over multiple columns, which also shifts over much of the numeric data.
#
# #### Step 2 - rename columns & add columns for readability
#
# First, we can make things a little easier by renaming the columns and adding in the new columns we'll need.
#
# I chose to rename the existing columns A-F to make it easier to keep track of them while working out the routines to access and format the data they hold.

# %%
activity_2000.rename(columns={'ARCOS': "A", 
                   '2':'B', 
                   '-': 'C', 
                   'REPORT': 'D', 
                   '5':'E', 
                   'RETAIL':'TOTAL', 
                   'STATISTICAL': 'F'}, 
          inplace=True)


activity_2000.insert(column='Year', loc=0, value=2000)
activity_2000.insert(column='State', loc=1, value=None)
activity_2000.insert(column='Business Activity', loc=2, value=None)
activity_2000.insert(column='Drug', loc=3, value=None)

activity_2000.head()
# Out:
#    Year State Business Activity  Drug          A            B           C  \
# 0  2000  None              None  None  REPORTING      PERIOD:  01/01/2000
# 1  2000  None              None  None     STATE:       ALASKA    BUSINESS
# 2  2000  None              None  None     NUMBER           OF       TOTAL
# 3  2000  None              None  None       DRUG  REGISTRANTS        SOLD
# 4  2000  None              None  None       DRUG         NAME        CODE
#
#            D           E            F     SUMMARY  FOR  TOTAL  DRUG  PURCHASES
# 0         TO  12/31/2000          NaN         NaN  NaN    NaN   NaN        NaN
# 1  ACTIVITY:  PHARMACIES          NaN         NaN  NaN    NaN   NaN        NaN
# 2      GRAMS     AVERAGE          NaN         NaN  NaN    NaN   NaN        NaN
# 3         TO    PURCHASE          PER         NaN  NaN    NaN   NaN        NaN
# 4       SOLD          TO  REGISTRANTS  REGISTRANT  NaN    NaN   NaN        NaN

# %% [markdown]
# #### Step 3 - Get state names
#
# First step is to try to get the state names, which we can see should be in column B when "STATE:" is in column A. I chose to do this by creating a rule for each case of state name length. First we can check whether there's any irregular data that would not follow the assumptions the cleaning routine is based on.

# %%
# are there any values in col B following a col A = STATE:
# that are not part or whole of a state name

# any values that print below will be something that doesn't belong

for i in activity_2000['B'].loc[activity_2000['A']=='STATE:'].unique().tolist():
    if i not in flat_geos:
        print("Unexpected value {}".format(i))
# Out:
# Unexpected value DISTRICT
# Unexpected value NORTH
# Unexpected value NEW
# Unexpected value PUERTO
# Unexpected value RHODE
# Unexpected value SOUTH
# Unexpected value TRUST
# Unexpected value VIRGIN
# Unexpected value WEST

# %%
# also want to check if there are any values aside from
# "BUSINESS" or partial state names in column C
# where col A = "STATE:"

activity_2000['C'].loc[activity_2000['A']=='STATE:'].unique()
# Out:
# array(['BUSINESS', 'OF', 'CAROLINA', 'DAKOTA', 'HAMPSHIRE', 'JERSEY',
#        'MEXICO', 'YORK', 'RICO', 'ISLAND', 'TERRITORIES', 'ISLANDS',
#        'VIRGINIA'], dtype=object)

# %%
# lastly want to check if any values other than 
# 'ACTIVITY','BUSINESS' or partial state names
# show up in columns C and D when col A = STATE:

activity_2000['D'].loc[activity_2000['A']=='STATE:'].unique()
# Out:
# array(['ACTIVITY:', 'COLUMBIA', 'BUSINESS', '(GUAM)'], dtype=object)

# %%
# if "STATE:" is present in column A, 
# we know at least the first part of the state name will be in column B
activity_2000.loc[activity_2000['A']=='STATE:', 'State'] = activity_2000['B']

# rule for dealing with two-word names
activity_2000.loc[(activity_2000['A']=="STATE:") 
                  & (activity_2000["C"]!='BUSINESS'), 'State'] = activity_2000["B"]+" "+activity_2000['C']

# rule for dealing with three-word names
activity_2000.loc[(activity_2000['A']=="STATE:") 
                  & (activity_2000["C"]!='BUSINESS') 
                  & (activity_2000["D"]!='ACTIVITY:') 
                  & (activity_2000["D"]!='BUSINESS'), 'State'] = activity_2000["B"]+" "+activity_2000['C']+" "+activity_2000['D']

activity_2000['State'].unique()
# Out:
# array([None, 'ALASKA', 'ALABAMA', 'ARKANSAS', 'ARIZONA', 'CALIFORNIA',
#        'COLORADO', 'CONNECTICUT', 'DISTRICT OF COLUMBIA', 'DELAWARE',
#        'FLORIDA', 'GEORGIA', 'HAWAII', 'IOWA', 'IDAHO', 'ILLINOIS',
#        'INDIANA', 'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MASSACHUSETTS',
#        'MARYLAND', 'MAINE', 'MICHIGAN', 'MINNESOTA', 'MISSOURI',
#        'MISSISSIPPI', 'MONTANA', 'NEBRASKA', 'NORTH CAROLINA',
#        'NORTH DAKOTA', 'NEW HAMPSHIRE', 'NEW JERSEY', 'NEW MEXICO',
#        'NEVADA', 'NEW YORK', 'OHIO', 'OKLAHOMA', 'OREGON', 'PENNSYLVANIA',
#        'PUERTO RICO', 'RHODE ISLAND', 'SOUTH CAROLINA', 'SOUTH DAKOTA',
#        'TENNESSEE', 'TRUST TERRITORIES (GUAM)', 'TEXAS', 'UTAH',
#        'VIRGINIA', 'VIRGIN ISLANDS', 'VERMONT', 'WASHINGTON', 'WISCONSIN',
#        'WEST VIRGINIA', 'WYOMING'], dtype=object)

# %% [markdown]
# #### Step 4 - get activities
#
# Next step is to pull out the retail activities that are included in the report.
#
# For later reports, there's actually a letter code (similar to the drug codes) that we can use, but in this older format we don't have that so that rules will be very similar to how we got the state names.
#
# Again we want to check some assumptions before running the rules.

# %%
# check for unexpected values in the first column with activity names
# accounting for all state name lengths
# since activity follows the state name

#activity_2000['E'].loc[activity_2000['D']=='ACTIVITY:'].unique()
#activity_2000['F'].loc[activity_2000['E']=='ACTIVITY:'].unique()
activity_2000['SUMMARY'].loc[activity_2000['F']=='ACTIVITY:'].unique()
# Out:
# array(['PHARMACIES', 'HOSPITALS', 'PRACTITIONERS'], dtype=object)

# %%
# check for unexpected values in the second column with activity names
# account for all state name lengths

#activity_2000['F'].loc[activity_2000['D']=='ACTIVITY:'].unique()
#activity_2000['SUMMARY'].loc[activity_2000['E']=='ACTIVITY:'].unique()
activity_2000['FOR'].loc[activity_2000['F']=='ACTIVITY:'].unique()
# Out:
# array([nan])

# %%
# check for unexpected values in the last column with activity names
# note that this is to check on the only 3-word activity,
# narcotic treatment programs
# which don't show up in earlier reporting years


#activity_2000['SUMMARY'].loc[activity_2000['D']=='ACTIVITY:'].unique()
#activity_2000['FOR'].loc[activity_2000['E']=='ACTIVITY:'].unique()
#activity_2000['TOTAL'].loc[activity_2000['F']=='ACTIVITY:'].unique()

# %%
activity_2000[activity_2000['F']=='ACTIVITY:']
# Out:
#       Year                     State Business Activity  Drug       A  \
# 433   2000      DISTRICT OF COLUMBIA              None  None  STATE:
# 449   2000      DISTRICT OF COLUMBIA              None  None  STATE:
# 465   2000      DISTRICT OF COLUMBIA              None  None  STATE:
# 2662  2000  TRUST TERRITORIES (GUAM)              None  None  STATE:
# 2678  2000  TRUST TERRITORIES (GUAM)              None  None  STATE:
# 2694  2000  TRUST TERRITORIES (GUAM)              None  None  STATE:
#
#              B            C         D         E          F        SUMMARY  \
# 433   DISTRICT           OF  COLUMBIA  BUSINESS  ACTIVITY:     PHARMACIES
# 449   DISTRICT           OF  COLUMBIA  BUSINESS  ACTIVITY:      HOSPITALS
# 465   DISTRICT           OF  COLUMBIA  BUSINESS  ACTIVITY:  PRACTITIONERS
# 2662     TRUST  TERRITORIES    (GUAM)  BUSINESS  ACTIVITY:     PHARMACIES
# 2678     TRUST  TERRITORIES    (GUAM)  BUSINESS  ACTIVITY:      HOSPITALS
# 2694     TRUST  TERRITORIES    (GUAM)  BUSINESS  ACTIVITY:  PRACTITIONERS
#
#       FOR  TOTAL  DRUG  PURCHASES
# 433   NaN    NaN   NaN        NaN
# 449   NaN    NaN   NaN        NaN
# 465   NaN    NaN   NaN        NaN
# 2662  NaN    NaN   NaN        NaN
# 2678  NaN    NaN   NaN        NaN
# 2694  NaN    NaN   NaN        NaN

# %%
# once we are sure everything is regular
# run the cleaning routine
    
activity_2000.loc[activity_2000['D']=='ACTIVITY:', 'Business Activity'] = activity_2000['E']
activity_2000.loc[(activity_2000['D']=='ACTIVITY:') 
                  & (pd.notnull(activity_2000['F'])), 'Business Activity'] = activity_2000['E']+" "+activity_2000['F']


activity_2000.loc[activity_2000['E']=='ACTIVITY:', 'Business Activity'] = activity_2000['F']
activity_2000.loc[(activity_2000['E']=='ACTIVITY:') 
                  & (pd.notnull(activity_2000['SUMMARY'])), 'Business Activity'] = activity_2000['F']+" "+activity_2000['SUMMARY']


activity_2000.loc[activity_2000['F']=='ACTIVITY:', 'Business Activity'] = activity_2000['SUMMARY']
activity_2000.loc[(activity_2000['F']=='ACTIVITY:')
                 & (pd.notnull(activity_2000['FOR'])), 'Business Activity'] = activity_2000['SUMMARY']+" "+activity_2000['FOR']



activity_2000.head(20)
# Out:
#     Year   State Business Activity  Drug  \
# 0   2000    None              None  None
# 1   2000  ALASKA        PHARMACIES  None
# 2   2000    None              None  None
# 3   2000    None              None  None
# 4   2000    None              None  None
# 5   2000    None              None  None
# 6   2000    None              None  None
# 7   2000    None              None  None
# 8   2000    None              None  None
# 9   2000    None              None  None
# 10  2000    None              None  None
# 11  2000    None              None  None
# 12  2000    None              None  None
# 13  2000    None              None  None
# 14  2000    None              None  None
# 15  2000    None              None  None
# 16  2000    None              None  None
# 17  2000  ALASKA         HOSPITALS  None
# 18  2000    None              None  None
# 19  2000    None              None  None
#
#                                                     A            B  \
# 0                                           REPORTING      PERIOD:
# 1                                              STATE:       ALASKA
# 2                                              NUMBER           OF
# 3                                                DRUG  REGISTRANTS
# 4                                                DRUG         NAME
# 5   ----------------------------------------------...          NaN
# 6                                      DL-AMPHETAMINE         BASE
# 7                                       D-AMPHETAMINE         BASE
# 8                                     METHYLPHENIDATE         1724
# 9                                           OXYCODONE         9143
# 10                                        HYDROCODONE         9193
# 11                                              DATE:   12/24/2002
# 12                                              PAGE:            2
# 13                                               DRUG  ENFORCEMENT
# 14                                              ARCOS            2
# 15                                        STATISTICAL      SUMMARY
# 16                                          REPORTING      PERIOD:
# 17                                             STATE:       ALASKA
# 18                                             NUMBER           OF
# 19                                               DRUG  REGISTRANTS
#
#                  C          D           E            F     SUMMARY  FOR  \
# 0       01/01/2000         TO  12/31/2000          NaN         NaN  NaN
# 1         BUSINESS  ACTIVITY:  PHARMACIES          NaN         NaN  NaN
# 2            TOTAL      GRAMS     AVERAGE          NaN         NaN  NaN
# 3             SOLD         TO    PURCHASE          PER         NaN  NaN
# 4             CODE       SOLD          TO  REGISTRANTS  REGISTRANT  NaN
# 5              NaN        NaN         NaN          NaN         NaN  NaN
# 6            1100B         75    2,359.66        31.46         NaN  NaN
# 7            1100D         79    7,791.91        98.63         NaN  NaN
# 8               80  12,855.76      160.69          NaN         NaN  NaN
# 9               82  65,876.54      803.37          NaN         NaN  NaN
# 10              82  23,932.85      291.86          NaN         NaN  NaN
# 11      DEPARTMENT         OF     JUSTICE          NaN         NaN  NaN
# 12             NaN        NaN         NaN          NaN         NaN  NaN
# 13  ADMINISTRATION        NaN         NaN          NaN         NaN  NaN
# 14               -     REPORT           5          NaN         NaN  NaN
# 15             FOR     RETAIL        DRUG    PURCHASES         NaN  NaN
# 16      01/01/2000         TO  12/31/2000          NaN         NaN  NaN
# 17        BUSINESS  ACTIVITY:   HOSPITALS          NaN         NaN  NaN
# 18           TOTAL      GRAMS     AVERAGE          NaN         NaN  NaN
# 19            SOLD         TO    PURCHASE          PER         NaN  NaN
#
#     TOTAL  DRUG  PURCHASES
# 0     NaN   NaN        NaN
# 1     NaN   NaN        NaN
# 2     NaN   NaN        NaN
# 3     NaN   NaN        NaN
# 4     NaN   NaN        NaN
# 5     NaN   NaN        NaN
# 6     NaN   NaN        NaN
# 7     NaN   NaN        NaN
# 8     NaN   NaN        NaN
# 9     NaN   NaN        NaN
# 10    NaN   NaN        NaN
# 11    NaN   NaN        NaN
# 12    NaN   NaN        NaN
# 13    NaN   NaN        NaN
# 14    NaN   NaN        NaN
# 15    NaN   NaN        NaN
# 16    NaN   NaN        NaN
# 17    NaN   NaN        NaN
# 18    NaN   NaN        NaN
# 19    NaN   NaN        NaN

# %% [markdown]
# #### Step 5 - forward fill state names and activity names
#
# Use pandas forward fill function to fill in the state and activity names.

# %%
activity_2000['State'] = activity_2000['State'].fillna(method='ffill')
activity_2000['Business Activity'] = activity_2000['Business Activity'].fillna(method='ffill')

activity_2000.head(20)
# Out:
#     Year   State Business Activity  Drug  \
# 0   2000    None              None  None
# 1   2000  ALASKA        PHARMACIES  None
# 2   2000  ALASKA        PHARMACIES  None
# 3   2000  ALASKA        PHARMACIES  None
# 4   2000  ALASKA        PHARMACIES  None
# 5   2000  ALASKA        PHARMACIES  None
# 6   2000  ALASKA        PHARMACIES  None
# 7   2000  ALASKA        PHARMACIES  None
# 8   2000  ALASKA        PHARMACIES  None
# 9   2000  ALASKA        PHARMACIES  None
# 10  2000  ALASKA        PHARMACIES  None
# 11  2000  ALASKA        PHARMACIES  None
# 12  2000  ALASKA        PHARMACIES  None
# 13  2000  ALASKA        PHARMACIES  None
# 14  2000  ALASKA        PHARMACIES  None
# 15  2000  ALASKA        PHARMACIES  None
# 16  2000  ALASKA        PHARMACIES  None
# 17  2000  ALASKA         HOSPITALS  None
# 18  2000  ALASKA         HOSPITALS  None
# 19  2000  ALASKA         HOSPITALS  None
#
#                                                     A            B  \
# 0                                           REPORTING      PERIOD:
# 1                                              STATE:       ALASKA
# 2                                              NUMBER           OF
# 3                                                DRUG  REGISTRANTS
# 4                                                DRUG         NAME
# 5   ----------------------------------------------...          NaN
# 6                                      DL-AMPHETAMINE         BASE
# 7                                       D-AMPHETAMINE         BASE
# 8                                     METHYLPHENIDATE         1724
# 9                                           OXYCODONE         9143
# 10                                        HYDROCODONE         9193
# 11                                              DATE:   12/24/2002
# 12                                              PAGE:            2
# 13                                               DRUG  ENFORCEMENT
# 14                                              ARCOS            2
# 15                                        STATISTICAL      SUMMARY
# 16                                          REPORTING      PERIOD:
# 17                                             STATE:       ALASKA
# 18                                             NUMBER           OF
# 19                                               DRUG  REGISTRANTS
#
#                  C          D           E            F     SUMMARY  FOR  \
# 0       01/01/2000         TO  12/31/2000          NaN         NaN  NaN
# 1         BUSINESS  ACTIVITY:  PHARMACIES          NaN         NaN  NaN
# 2            TOTAL      GRAMS     AVERAGE          NaN         NaN  NaN
# 3             SOLD         TO    PURCHASE          PER         NaN  NaN
# 4             CODE       SOLD          TO  REGISTRANTS  REGISTRANT  NaN
# 5              NaN        NaN         NaN          NaN         NaN  NaN
# 6            1100B         75    2,359.66        31.46         NaN  NaN
# 7            1100D         79    7,791.91        98.63         NaN  NaN
# 8               80  12,855.76      160.69          NaN         NaN  NaN
# 9               82  65,876.54      803.37          NaN         NaN  NaN
# 10              82  23,932.85      291.86          NaN         NaN  NaN
# 11      DEPARTMENT         OF     JUSTICE          NaN         NaN  NaN
# 12             NaN        NaN         NaN          NaN         NaN  NaN
# 13  ADMINISTRATION        NaN         NaN          NaN         NaN  NaN
# 14               -     REPORT           5          NaN         NaN  NaN
# 15             FOR     RETAIL        DRUG    PURCHASES         NaN  NaN
# 16      01/01/2000         TO  12/31/2000          NaN         NaN  NaN
# 17        BUSINESS  ACTIVITY:   HOSPITALS          NaN         NaN  NaN
# 18           TOTAL      GRAMS     AVERAGE          NaN         NaN  NaN
# 19            SOLD         TO    PURCHASE          PER         NaN  NaN
#
#     TOTAL  DRUG  PURCHASES
# 0     NaN   NaN        NaN
# 1     NaN   NaN        NaN
# 2     NaN   NaN        NaN
# 3     NaN   NaN        NaN
# 4     NaN   NaN        NaN
# 5     NaN   NaN        NaN
# 6     NaN   NaN        NaN
# 7     NaN   NaN        NaN
# 8     NaN   NaN        NaN
# 9     NaN   NaN        NaN
# 10    NaN   NaN        NaN
# 11    NaN   NaN        NaN
# 12    NaN   NaN        NaN
# 13    NaN   NaN        NaN
# 14    NaN   NaN        NaN
# 15    NaN   NaN        NaN
# 16    NaN   NaN        NaN
# 17    NaN   NaN        NaN
# 18    NaN   NaN        NaN
# 19    NaN   NaN        NaN

# %% [markdown]
# #### Step 6 - get drug names
#
# We will continue to use the drug codes dictionary to get drug names. The challenge here is that the code follows the drug name, so we may have to look several columns over to find the code.
#
# Regex will be useful here to check where drug codes are appearing (and if there are any we are missing in the dict), since we know all the codes are either 4 digits or 4 digits plus a capital letter.

# %%
cols = ['B', 'C', 'D', 'E', 'F', 'SUMMARY', 'FOR', 'TOTAL', 'DRUG', 'PURCHASES' ]
code_columns = {}

for c in cols:
    print("Checking column {}".format(c))
    if pd.isnull(activity_2000[c]).all():
        print("Null column.")
    else:
        vals = activity_2000[c].loc[activity_2000[c].str.match('^[0-9]{4}[A-Z]?', na=False)].unique().tolist()
        if len(vals)>0:
            code_columns[c] = []
            print("Drug codes found in column {}:".format(c))
            print(vals)

            for v in vals:
                code_columns[c].append(v)
                if v not in drug_codes.keys():
                    print("Unexpected code found: {}".format(v))
        else:
            print("No drug codes found.")
    print()
# Out:
# Checking column B
# Drug codes found in column B:
# ['1724', '9143', '9193']
#
# Checking column C
# Drug codes found in column C:
# ['1100B', '1100D']
#
# Checking column D
# No drug codes found.
#
# Checking column E
# No drug codes found.
#
# Checking column F
# No drug codes found.
#
# Checking column SUMMARY
# No drug codes found.
#
# Checking column FOR
# Null column.
#
# Checking column TOTAL
# Null column.
#
# Checking column DRUG
# Null column.
#
# Checking column PURCHASES
# Null column.

# %% [markdown]
# Now we have a dictionary of column names with the corresponding drug codes to pull from.

# %%
code_columns
# Out:
# {'B': ['1724', '9143', '9193'], 'C': ['1100B', '1100D']}

# %%
for col in code_columns.keys():
    for code in code_columns[col]:
        activity_2000.loc[activity_2000[col]==code, 'Drug'] = drug_codes[code]
        
activity_2000.head(20)
# Out:
#     Year   State Business Activity                 Drug  \
# 0   2000    None              None                 None
# 1   2000  ALASKA        PHARMACIES                 None
# 2   2000  ALASKA        PHARMACIES                 None
# 3   2000  ALASKA        PHARMACIES                 None
# 4   2000  ALASKA        PHARMACIES                 None
# 5   2000  ALASKA        PHARMACIES                 None
# 6   2000  ALASKA        PHARMACIES  DL-AMPHETAMINE BASE
# 7   2000  ALASKA        PHARMACIES   D-AMPHETAMINE BASE
# 8   2000  ALASKA        PHARMACIES      METHYLPHENIDATE
# 9   2000  ALASKA        PHARMACIES            OXYCODONE
# 10  2000  ALASKA        PHARMACIES          HYDROCODONE
# 11  2000  ALASKA        PHARMACIES                 None
# 12  2000  ALASKA        PHARMACIES                 None
# 13  2000  ALASKA        PHARMACIES                 None
# 14  2000  ALASKA        PHARMACIES                 None
# 15  2000  ALASKA        PHARMACIES                 None
# 16  2000  ALASKA        PHARMACIES                 None
# 17  2000  ALASKA         HOSPITALS                 None
# 18  2000  ALASKA         HOSPITALS                 None
# 19  2000  ALASKA         HOSPITALS                 None
#
#                                                     A            B  \
# 0                                           REPORTING      PERIOD:
# 1                                              STATE:       ALASKA
# 2                                              NUMBER           OF
# 3                                                DRUG  REGISTRANTS
# 4                                                DRUG         NAME
# 5   ----------------------------------------------...          NaN
# 6                                      DL-AMPHETAMINE         BASE
# 7                                       D-AMPHETAMINE         BASE
# 8                                     METHYLPHENIDATE         1724
# 9                                           OXYCODONE         9143
# 10                                        HYDROCODONE         9193
# 11                                              DATE:   12/24/2002
# 12                                              PAGE:            2
# 13                                               DRUG  ENFORCEMENT
# 14                                              ARCOS            2
# 15                                        STATISTICAL      SUMMARY
# 16                                          REPORTING      PERIOD:
# 17                                             STATE:       ALASKA
# 18                                             NUMBER           OF
# 19                                               DRUG  REGISTRANTS
#
#                  C          D           E            F     SUMMARY  FOR  \
# 0       01/01/2000         TO  12/31/2000          NaN         NaN  NaN
# 1         BUSINESS  ACTIVITY:  PHARMACIES          NaN         NaN  NaN
# 2            TOTAL      GRAMS     AVERAGE          NaN         NaN  NaN
# 3             SOLD         TO    PURCHASE          PER         NaN  NaN
# 4             CODE       SOLD          TO  REGISTRANTS  REGISTRANT  NaN
# 5              NaN        NaN         NaN          NaN         NaN  NaN
# 6            1100B         75    2,359.66        31.46         NaN  NaN
# 7            1100D         79    7,791.91        98.63         NaN  NaN
# 8               80  12,855.76      160.69          NaN         NaN  NaN
# 9               82  65,876.54      803.37          NaN         NaN  NaN
# 10              82  23,932.85      291.86          NaN         NaN  NaN
# 11      DEPARTMENT         OF     JUSTICE          NaN         NaN  NaN
# 12             NaN        NaN         NaN          NaN         NaN  NaN
# 13  ADMINISTRATION        NaN         NaN          NaN         NaN  NaN
# 14               -     REPORT           5          NaN         NaN  NaN
# 15             FOR     RETAIL        DRUG    PURCHASES         NaN  NaN
# 16      01/01/2000         TO  12/31/2000          NaN         NaN  NaN
# 17        BUSINESS  ACTIVITY:   HOSPITALS          NaN         NaN  NaN
# 18           TOTAL      GRAMS     AVERAGE          NaN         NaN  NaN
# 19            SOLD         TO    PURCHASE          PER         NaN  NaN
#
#     TOTAL  DRUG  PURCHASES
# 0     NaN   NaN        NaN
# 1     NaN   NaN        NaN
# 2     NaN   NaN        NaN
# 3     NaN   NaN        NaN
# 4     NaN   NaN        NaN
# 5     NaN   NaN        NaN
# 6     NaN   NaN        NaN
# 7     NaN   NaN        NaN
# 8     NaN   NaN        NaN
# 9     NaN   NaN        NaN
# 10    NaN   NaN        NaN
# 11    NaN   NaN        NaN
# 12    NaN   NaN        NaN
# 13    NaN   NaN        NaN
# 14    NaN   NaN        NaN
# 15    NaN   NaN        NaN
# 16    NaN   NaN        NaN
# 17    NaN   NaN        NaN
# 18    NaN   NaN        NaN
# 19    NaN   NaN        NaN

# %% [markdown]
# #### Step 7 - Remove extra rows
#
# The last steps will be a lot easier if we can take a moment to drop out some rows that contain only header data and similar.
#
# At this point, if we have a row that has something other than a drug name in column A, we don't need it anymore, since we've pulled out all the state names and business activity names.

# %%
activity_2000['A'].unique()
# Out:
# array(['REPORTING', 'STATE:', 'NUMBER', 'DRUG',
#        '--------------------------------------------------------------------------------------------',
#        'DL-AMPHETAMINE', 'D-AMPHETAMINE', 'METHYLPHENIDATE', 'OXYCODONE',
#        'HYDROCODONE', 'DATE:', 'PAGE:', 'ARCOS', 'STATISTICAL'],
#       dtype=object)

# %%
# to be extra sure, we can add a regex to check for numeric data in column C
# and a report if any is found when the rows are being dropped
# the dashes might vary in length for future years so we will get those later

drops = ['REPORTING', 'STATE:', 'NUMBER', 'DRUG',
         'DATE:', 'PAGE:', 'ARCOS', 'STATISTICAL']

for d in drops:
    check_df = activity_2000.loc[(activity_2000['A']==d)
                                & activity_2000['C'].str.match('[-+]?[0-9,]*\.?[0-9]+?$', na=False)]
    if len(check_df)>0:
        print("Dropping rows with numeric data:")
        print(check_df)
    activity_2000 = activity_2000.drop(activity_2000[activity_2000['A']==d].index)
    
activity_2000.head(10)
# Out:
#     Year   State Business Activity                 Drug  \
# 5   2000  ALASKA        PHARMACIES                 None
# 6   2000  ALASKA        PHARMACIES  DL-AMPHETAMINE BASE
# 7   2000  ALASKA        PHARMACIES   D-AMPHETAMINE BASE
# 8   2000  ALASKA        PHARMACIES      METHYLPHENIDATE
# 9   2000  ALASKA        PHARMACIES            OXYCODONE
# 10  2000  ALASKA        PHARMACIES          HYDROCODONE
# 21  2000  ALASKA         HOSPITALS                 None
# 22  2000  ALASKA         HOSPITALS  DL-AMPHETAMINE BASE
# 23  2000  ALASKA         HOSPITALS   D-AMPHETAMINE BASE
# 24  2000  ALASKA         HOSPITALS      METHYLPHENIDATE
#
#                                                     A     B      C          D  \
# 5   ----------------------------------------------...   NaN    NaN        NaN
# 6                                      DL-AMPHETAMINE  BASE  1100B         75
# 7                                       D-AMPHETAMINE  BASE  1100D         79
# 8                                     METHYLPHENIDATE  1724     80  12,855.76
# 9                                           OXYCODONE  9143     82  65,876.54
# 10                                        HYDROCODONE  9193     82  23,932.85
# 21  ----------------------------------------------...   NaN    NaN        NaN
# 22                                     DL-AMPHETAMINE  BASE  1100B         14
# 23                                      D-AMPHETAMINE  BASE  1100D         19
# 24                                    METHYLPHENIDATE  1724     30   3,939.00
#
#            E      F SUMMARY  FOR  TOTAL  DRUG  PURCHASES
# 5        NaN    NaN     NaN  NaN    NaN   NaN        NaN
# 6   2,359.66  31.46     NaN  NaN    NaN   NaN        NaN
# 7   7,791.91  98.63     NaN  NaN    NaN   NaN        NaN
# 8     160.69    NaN     NaN  NaN    NaN   NaN        NaN
# 9     803.37    NaN     NaN  NaN    NaN   NaN        NaN
# 10    291.86    NaN     NaN  NaN    NaN   NaN        NaN
# 21       NaN    NaN     NaN  NaN    NaN   NaN        NaN
# 22    270.17  19.29     NaN  NaN    NaN   NaN        NaN
# 23  1,226.84  64.57     NaN  NaN    NaN   NaN        NaN
# 24    131.30    NaN     NaN  NaN    NaN   NaN        NaN

# %%
# finally, drop the rows with NaNs and dashes
activity_2000 = activity_2000.drop(activity_2000.loc[pd.isnull(activity_2000['D'])].index)
activity_2000.head(10)
# Out:
#     Year   State Business Activity                 Drug                A  \
# 6   2000  ALASKA        PHARMACIES  DL-AMPHETAMINE BASE   DL-AMPHETAMINE
# 7   2000  ALASKA        PHARMACIES   D-AMPHETAMINE BASE    D-AMPHETAMINE
# 8   2000  ALASKA        PHARMACIES      METHYLPHENIDATE  METHYLPHENIDATE
# 9   2000  ALASKA        PHARMACIES            OXYCODONE        OXYCODONE
# 10  2000  ALASKA        PHARMACIES          HYDROCODONE      HYDROCODONE
# 22  2000  ALASKA         HOSPITALS  DL-AMPHETAMINE BASE   DL-AMPHETAMINE
# 23  2000  ALASKA         HOSPITALS   D-AMPHETAMINE BASE    D-AMPHETAMINE
# 24  2000  ALASKA         HOSPITALS      METHYLPHENIDATE  METHYLPHENIDATE
# 25  2000  ALASKA         HOSPITALS            OXYCODONE        OXYCODONE
# 26  2000  ALASKA         HOSPITALS          HYDROCODONE      HYDROCODONE
#
#        B      C          D         E      F SUMMARY  FOR  TOTAL  DRUG  \
# 6   BASE  1100B         75  2,359.66  31.46     NaN  NaN    NaN   NaN
# 7   BASE  1100D         79  7,791.91  98.63     NaN  NaN    NaN   NaN
# 8   1724     80  12,855.76    160.69    NaN     NaN  NaN    NaN   NaN
# 9   9143     82  65,876.54    803.37    NaN     NaN  NaN    NaN   NaN
# 10  9193     82  23,932.85    291.86    NaN     NaN  NaN    NaN   NaN
# 22  BASE  1100B         14    270.17  19.29     NaN  NaN    NaN   NaN
# 23  BASE  1100D         19  1,226.84  64.57     NaN  NaN    NaN   NaN
# 24  1724     30   3,939.00    131.30    NaN     NaN  NaN    NaN   NaN
# 25  9143     37   8,336.11    225.30    NaN     NaN  NaN    NaN   NaN
# 26  9193     38   2,660.70     70.01    NaN     NaN  NaN    NaN   NaN
#
#     PURCHASES
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN

# %% [markdown]
# #### Step 8 - move over shifted data
#
# The next step is to move over the shifted numeric data.
#
# If the cleaning has all gone properly so far, we should only have numeric data following a drug code and name.
#
# For any drug where the code was in column B, we'll leave it alone. For the rest, we want to move the data over according to how many columns over from column B it has been displaced.

# %%
activity_2000.insert(column='Registrants', loc=4, value=None)
activity_2000.insert(column='Total grams sold', loc=5, value=None)
activity_2000.insert(column='Avg grams/registrant', loc=6, value=None)


activity_2000.head()
# Out:
#     Year   State Business Activity                 Drug Registrants  \
# 6   2000  ALASKA        PHARMACIES  DL-AMPHETAMINE BASE        None
# 7   2000  ALASKA        PHARMACIES   D-AMPHETAMINE BASE        None
# 8   2000  ALASKA        PHARMACIES      METHYLPHENIDATE        None
# 9   2000  ALASKA        PHARMACIES            OXYCODONE        None
# 10  2000  ALASKA        PHARMACIES          HYDROCODONE        None
#
#    Total grams sold Avg grams/registrant                A     B      C  \
# 6              None                 None   DL-AMPHETAMINE  BASE  1100B
# 7              None                 None    D-AMPHETAMINE  BASE  1100D
# 8              None                 None  METHYLPHENIDATE  1724     80
# 9              None                 None        OXYCODONE  9143     82
# 10             None                 None      HYDROCODONE  9193     82
#
#             D         E      F SUMMARY  FOR  TOTAL  DRUG  PURCHASES
# 6          75  2,359.66  31.46     NaN  NaN    NaN   NaN        NaN
# 7          79  7,791.91  98.63     NaN  NaN    NaN   NaN        NaN
# 8   12,855.76    160.69    NaN     NaN  NaN    NaN   NaN        NaN
# 9   65,876.54    803.37    NaN     NaN  NaN    NaN   NaN        NaN
# 10  23,932.85    291.86    NaN     NaN  NaN    NaN   NaN        NaN

# %%
shift = ['B', 'C', 'D', 'E', 'F', 'SUMMARY', 'FOR', 'TOTAL', 'DRUG', 'PURCHASES' ]

for col in code_columns.keys():
        i = shift.index(col)
        for code in code_columns[col]:
            activity_2000.loc[activity_2000[col]==code, 'Registrants'] = activity_2000[shift[i+1]]
            activity_2000.loc[activity_2000[col]==code, 'Total grams sold'] = activity_2000[shift[i+2]]
            activity_2000.loc[activity_2000[col]==code, 'Avg grams/registrant'] = activity_2000[shift[i+3]]


            
activity_2000.head(20)
# Out:
#     Year    State        Business Activity                 Drug Registrants  \
# 6   2000   ALASKA               PHARMACIES  DL-AMPHETAMINE BASE          75
# 7   2000   ALASKA               PHARMACIES   D-AMPHETAMINE BASE          79
# 8   2000   ALASKA               PHARMACIES      METHYLPHENIDATE          80
# 9   2000   ALASKA               PHARMACIES            OXYCODONE          82
# 10  2000   ALASKA               PHARMACIES          HYDROCODONE          82
# 22  2000   ALASKA                HOSPITALS  DL-AMPHETAMINE BASE          14
# 23  2000   ALASKA                HOSPITALS   D-AMPHETAMINE BASE          19
# 24  2000   ALASKA                HOSPITALS      METHYLPHENIDATE          30
# 25  2000   ALASKA                HOSPITALS            OXYCODONE          37
# 26  2000   ALASKA                HOSPITALS          HYDROCODONE          38
# 38  2000   ALASKA            PRACTITIONERS   D-AMPHETAMINE BASE           2
# 39  2000   ALASKA            PRACTITIONERS      METHYLPHENIDATE           4
# 40  2000   ALASKA            PRACTITIONERS            OXYCODONE          11
# 41  2000   ALASKA            PRACTITIONERS          HYDROCODONE         110
# 53  2000   ALASKA  MID-LEVEL PRACTITIONERS            OXYCODONE           1
# 54  2000   ALASKA  MID-LEVEL PRACTITIONERS          HYDROCODONE          10
# 66  2000  ALABAMA               PHARMACIES  DL-AMPHETAMINE BASE       1,156
# 67  2000  ALABAMA               PHARMACIES   D-AMPHETAMINE BASE       1,162
# 68  2000  ALABAMA               PHARMACIES      METHYLPHENIDATE       1,175
# 69  2000  ALABAMA               PHARMACIES            OXYCODONE       1,194
#
#    Total grams sold Avg grams/registrant                A     B      C  \
# 6          2,359.66                31.46   DL-AMPHETAMINE  BASE  1100B
# 7          7,791.91                98.63    D-AMPHETAMINE  BASE  1100D
# 8         12,855.76               160.69  METHYLPHENIDATE  1724     80
# 9         65,876.54               803.37        OXYCODONE  9143     82
# 10        23,932.85               291.86      HYDROCODONE  9193     82
# 22           270.17                19.29   DL-AMPHETAMINE  BASE  1100B
# 23         1,226.84                64.57    D-AMPHETAMINE  BASE  1100D
# 24         3,939.00               131.30  METHYLPHENIDATE  1724     30
# 25         8,336.11               225.30        OXYCODONE  9143     37
# 26         2,660.70                70.01      HYDROCODONE  9193     38
# 38            35.20                17.60    D-AMPHETAMINE  BASE  1100D
# 39           105.51                26.37  METHYLPHENIDATE  1724      4
# 40           175.92                15.99        OXYCODONE  9143     11
# 41           380.60                 3.46      HYDROCODONE  9193    110
# 53             7.15                 7.15        OXYCODONE  9143      1
# 54            44.25                 4.42      HYDROCODONE  9193     10
# 66        29,477.69                25.49   DL-AMPHETAMINE  BASE  1100B
# 67        48,205.81                41.48    D-AMPHETAMINE  BASE  1100D
# 68       128,346.02               109.23  METHYLPHENIDATE  1724  1,175
# 69       280,647.37               235.04        OXYCODONE  9143  1,194
#
#              D          E      F SUMMARY  FOR  TOTAL  DRUG  PURCHASES
# 6           75   2,359.66  31.46     NaN  NaN    NaN   NaN        NaN
# 7           79   7,791.91  98.63     NaN  NaN    NaN   NaN        NaN
# 8    12,855.76     160.69    NaN     NaN  NaN    NaN   NaN        NaN
# 9    65,876.54     803.37    NaN     NaN  NaN    NaN   NaN        NaN
# 10   23,932.85     291.86    NaN     NaN  NaN    NaN   NaN        NaN
# 22          14     270.17  19.29     NaN  NaN    NaN   NaN        NaN
# 23          19   1,226.84  64.57     NaN  NaN    NaN   NaN        NaN
# 24    3,939.00     131.30    NaN     NaN  NaN    NaN   NaN        NaN
# 25    8,336.11     225.30    NaN     NaN  NaN    NaN   NaN        NaN
# 26    2,660.70      70.01    NaN     NaN  NaN    NaN   NaN        NaN
# 38           2      35.20  17.60     NaN  NaN    NaN   NaN        NaN
# 39      105.51      26.37    NaN     NaN  NaN    NaN   NaN        NaN
# 40      175.92      15.99    NaN     NaN  NaN    NaN   NaN        NaN
# 41      380.60       3.46    NaN     NaN  NaN    NaN   NaN        NaN
# 53        7.15       7.15    NaN     NaN  NaN    NaN   NaN        NaN
# 54       44.25       4.42    NaN     NaN  NaN    NaN   NaN        NaN
# 66       1,156  29,477.69  25.49     NaN  NaN    NaN   NaN        NaN
# 67       1,162  48,205.81  41.48     NaN  NaN    NaN   NaN        NaN
# 68  128,346.02     109.23    NaN     NaN  NaN    NaN   NaN        NaN
# 69  280,647.37     235.04    NaN     NaN  NaN    NaN   NaN        NaN

# %% [markdown]
# #### Step 9 - Last few cleanups
#
# * Simplify references to Guam
# * Drop extra columns we don't need
# * Convert key columns to float datatype

# %%
activity_2000.loc[activity_2000['State']=='TRUST TERRITORIES (GUAM)', 'State'] = "GUAM"

cols = ['Total grams sold', 'Avg grams/registrant']
for col in cols:
    activity_2000[col] = activity_2000[col].str.replace(",","").astype(float)

activity_2000['Registrants'] = activity_2000[col].str.replace(",","").astype(int)

activity_2000 = activity_2000[['Year', 'State', 'Business Activity', 'Drug',
                              'Registrants', 'Total grams sold', 'Avg grams/registrant']]
activity_2000.head(10)
# Out:
#     Year   State Business Activity                 Drug  Registrants  \
# 6   2000  ALASKA        PHARMACIES  DL-AMPHETAMINE BASE         75.0
# 7   2000  ALASKA        PHARMACIES   D-AMPHETAMINE BASE         79.0
# 8   2000  ALASKA        PHARMACIES      METHYLPHENIDATE         80.0
# 9   2000  ALASKA        PHARMACIES            OXYCODONE         82.0
# 10  2000  ALASKA        PHARMACIES          HYDROCODONE         82.0
# 22  2000  ALASKA         HOSPITALS  DL-AMPHETAMINE BASE         14.0
# 23  2000  ALASKA         HOSPITALS   D-AMPHETAMINE BASE         19.0
# 24  2000  ALASKA         HOSPITALS      METHYLPHENIDATE         30.0
# 25  2000  ALASKA         HOSPITALS            OXYCODONE         37.0
# 26  2000  ALASKA         HOSPITALS          HYDROCODONE         38.0
#
#     Total grams sold  Avg grams/registrant
# 6            2359.66                 31.46
# 7            7791.91                 98.63
# 8           12855.76                160.69
# 9           65876.54                803.37
# 10          23932.85                291.86
# 22            270.17                 19.29
# 23           1226.84                 64.57
# 24           3939.00                131.30
# 25           8336.11                225.30
# 26           2660.70                 70.01

# %% [markdown]
# ### Refactor the cleaning & checking code
#
# Below is the refactored code to be reused on the remaining files, first for check functions to find irregular data patterns and second to actually clean up the dataframe.
#
# Note there are several versions of the function needed to handle all the various formats - as mentioned these were messy and inconsistent from year to year. To adjust the function, I went through it line by line on a file where it didn't work properly to identify the issues, and then adjusted it to reuse from there.

# %%
def check_activity_old(df, flat_geos, flat_activity_codes):
    df.rename(columns={'ARCOS': "A", 
               '2':'B', 
               '-': 'C', 
               'REPORT': 'D', 
               '5':'E', 
               'RETAIL':'TOTAL', 
               'STATISTICAL': 'F'}, 
      inplace=True)
    # check for unusual values in column A - numeric values
    check_a = df['A'].loc[df['A'].str.match('^[0-9]+', na=False)].unique().tolist()
    if len(check_a)>0:
        print("Unusual values in column A:")
        print(check_a)
        print()
    if "STATE:" not in df['A'].unique().tolist():
        print("Data missing - no STATE: header in column A")
    
    # check for valid geography names
    for i in df['B'].loc[df['A']=='STATE:'].unique().tolist():
        if i not in flat_geos:
            print("Unexpected value in column B for states: {}".format(i))
    
            
    # check for unusual values in columns C and D
    for i in df['C'].loc[df['A']=='STATE:'].unique().tolist():
        if i!= 'BUSINESS' and i not in flat_geos:
            print("Unexpected value in column C for states: {}".format(i))

    for i in df['D'].loc[df['A']=='STATE:'].unique().tolist():
        if i!='BUSINESS' and i!='ACTIVITY:' and i not in flat_geos:
            print("Unexpected value in column D for states: {}".format(i))

            
    # check for unexpected values in columns with activity names
    for i in df['E'].loc[df['D']=='ACTIVITY:'].unique().tolist():
        if i not in flat_activity_codes:
            print("Unexpected value in column D for activities: {}".format(i))  
    for i in df['F'].loc[df['D']=='ACTIVITY:'].unique().tolist():
        if i not in flat_activity_codes:
            print("Unexpected value in column F for activities: {}".format(i))
    for i in df['SUMMARY'].loc[df['F']=='ACTIVITY:'].unique().tolist():
        if i not in flat_activity_codes:
            print("Unexpected value in column 'SUMMARY' for activities: {}".format(i))

            
    # check for drug codes
    cols = ['B', 'C', 'D', 'E', 'F', 'SUMMARY', 'FOR', 'TOTAL', 'DRUG', 'PURCHASES' ]
    code_columns = {}
    for c in cols:
        print("Checking column {}".format(c))
        if pd.isnull(df[c]).all():
            print("Null column.")
        else:
            vals = df[c].loc[df[c].str.match('^[0-9]{4}[A-Z]?', na=False)].unique().tolist()
            if len(vals)>0:
                code_columns[c] = []
                print("Drug codes found in column {}:".format(c))
                print(vals)

                for v in vals:
                    code_columns[c].append(v)
                    if v not in drug_codes.keys():
                        print("Unexpected code found: {}".format(v))
            else:
                print("No drug codes found.")
            check = df[c].loc[~df[c].str.match('^[0-9]+', na=False)].unique()
            print("non-numeric values in column {}:".format(c))
            print(check)

        print()

# %%
def clean_activity_old(df, year, drug_codes, flat_geos):
    """
    Use for years 2000 to 2005 inclusive. 
    """
    # rename columns
    df.rename(columns={'ARCOS': "A", 
                   '2':'B', 
                   '-': 'C', 
                   'REPORT': 'D', 
                   '5':'E', 
                   'RETAIL':'TOTAL', 
                   'STATISTICAL': 'F'}, 
          inplace=True)

    # insert new columns
    df.insert(column='Year', loc=0, value=year)
    df.insert(column='State', loc=1, value=None)
    df.insert(column='Business Activity', loc=2, value=None)
    df.insert(column='Drug', loc=3, value=None)

    # get state names
    df.loc[df['A']=='STATE:', 'State'] = df['B']
    
    df.loc[(df['A']=="STATE:") 
                      & (df["C"]!='BUSINESS'), 'State'] = df["B"]+" "+df['C']

    df.loc[(df['A']=="STATE:") 
           & (df["C"]!='BUSINESS') 
           & (df["D"]!='ACTIVITY:') 
           & (df["D"]!='BUSINESS'), 'State'] = df["B"]+" "+df['C']+" "+df['D']

    # get the business activity names
    df.loc[df['D']=='ACTIVITY:', 'Business Activity'] = df['E']
    df.loc[(df['D']=='ACTIVITY:') 
           & (pd.notnull(df['F'])), 'Business Activity'] = df['E']+" "+df['F']
    df.loc[df['E']=='ACTIVITY:', 'Business Activity'] = df['F']
    df.loc[(df['E']=='ACTIVITY:') 
           & (pd.notnull(df['SUMMARY'])), 'Business Activity'] = df['F']+" "+df['SUMMARY']
    df.loc[df['F']=='ACTIVITY:', 'Business Activity'] = df['SUMMARY']
    df.loc[(df['F']=='ACTIVITY:')
           & (pd.notnull(df['FOR'])), 'Business Activity'] = df['SUMMARY']+" "+df['FOR']

    # forward fill state and business activity
    df['State'] = df['State'].fillna(method='ffill')
    df['Business Activity'] = df['Business Activity'].fillna(method='ffill')

    # get drug code & update
    # same code as in the checking function but quiet
    cols = ['B', 'C', 'D', 'E', 'F', 'SUMMARY', 'FOR', 'TOTAL', 'DRUG', 'PURCHASES' ]
    code_columns = {}

    for c in cols:
        if pd.isnull(df[c]).all():
            continue
        else:
            vals = df[c].loc[df[c].str.match('^[0-9]{4}[A-Z]?', na=False)].unique().tolist()
            if len(vals)>0:
                code_columns[c] = []
                for v in vals:
                    code_columns[c].append(v)
                    if v not in drug_codes.keys():
                        print("Unexpected drug code found: {}".format(v))
            else:
                continue
    for col in code_columns.keys():
        for code in code_columns[col]:
            df.loc[df[col]==code, 'Drug'] = drug_codes[code]
        
    # drop unnecessary rows
    drops = ['REPORTING', 'STATE:', 'NUMBER', 'DRUG',
         'DATE:', 'PAGE:', 'ARCOS', 'STATISTICAL']
    for d in drops:
        check_df = df.loc[(df['A']==d)
                          & df['C'].str.match('[-+]?[0-9,]*\.?[0-9]+?$', na=False)]
        if len(check_df)>0:
            print("Dropping rows with numeric data:")
            print(check_df)
        df = df.drop(df[df['A']==d].index)
    df = df.drop(df.loc[pd.isnull(df['D'])].index)
    
    # add the last few columns we need
    df.insert(column='Registrants', loc=4, value=None)
    df.insert(column='Total grams sold', loc=5, value=None)
    df.insert(column='Avg grams/registrant', loc=6, value=None)
    
    # shift data
    shift = ['B', 'C', 'D', 'E', 'F', 'SUMMARY', 'FOR', 'TOTAL', 'DRUG', 'PURCHASES' ]
    for col in code_columns.keys():
            i = shift.index(col)
            for code in code_columns[col]:
                df.loc[df[col]==code, 'Registrants'] = df[shift[i+1]]
                df.loc[df[col]==code, 'Total grams sold'] = df[shift[i+2]]
                df.loc[df[col]==code, 'Avg grams/registrant'] = df[shift[i+3]]

    # final cleanup
    df.loc[df['State']=='TRUST TERRITORIES (GUAM)', 'State'] = "GUAM"
    repl = ['Total grams sold', 'Avg grams/registrant']
    for col in repl:
        df[col] = df[col].str.replace(",","").astype(float)
    df['Registrants'] = df['Registrants'].str.replace(",","").astype(int)
    df = df[['Year', 'State', 'Business Activity', 'Drug',
             'Registrants', 'Total grams sold', 'Avg grams/registrant']]
    return df

# %%
activity_2000 = pd.read_csv('activity_2000.txt', delim_whitespace=True)
check_activity_old(activity_2000, flat_geos, flat_activity_codes)
# Out:
# Unexpected value in column B for states: TRUST
# Unexpected value in column C for states: TERRITORIES
# Unexpected value in column D for states: (GUAM)
# Unexpected value in column F for activities: nan
# Checking column B
# Drug codes found in column B:
# ['1724', '9143', '9193']
# non-numeric values in column B:
# ['PERIOD:' 'ALASKA' 'OF' 'REGISTRANTS' 'NAME' nan 'BASE' 'ENFORCEMENT'
#  'SUMMARY' 'ALABAMA' 'ARKANSAS' 'ARIZONA' 'CALIFORNIA' 'COLORADO'
#  'CONNECTICUT' 'DISTRICT' 'DELAWARE' 'FLORIDA' 'GEORGIA' 'HAWAII' 'IOWA'
#  'IDAHO' 'ILLINOIS' 'INDIANA' 'KANSAS' 'KENTUCKY' 'LOUISIANA'
#  'MASSACHUSETTS' 'MARYLAND' 'MAINE' 'MICHIGAN' 'MINNESOTA' 'MISSOURI'
#  'MISSISSIPPI' 'MONTANA' 'NEBRASKA' 'NORTH' 'NEW' 'NEVADA' 'OHIO'
#  'OKLAHOMA' 'OREGON' 'PENNSYLVANIA' 'PUERTO' 'RHODE' 'SOUTH' 'TENNESSEE'
#  'TRUST' 'TEXAS' 'UTAH' 'VIRGINIA' 'VIRGIN' 'VERMONT' 'WASHINGTON'
#  'WISCONSIN' 'WEST' 'WYOMING']
#
# Checking column C
# Drug codes found in column C:
# ['1100B', '1100D']
# non-numeric values in column C:
# ['BUSINESS' 'TOTAL' 'SOLD' 'CODE' nan 'DEPARTMENT' 'ADMINISTRATION' '-'
#  'FOR' 'OF' 'CAROLINA' 'DAKOTA' 'HAMPSHIRE' 'JERSEY' 'MEXICO' 'YORK'
#  'RICO' 'ISLAND' 'TERRITORIES' 'ISLANDS' 'VIRGINIA']
#
# Checking column D
# No drug codes found.
# non-numeric values in column D:
# ['TO' 'ACTIVITY:' 'GRAMS' 'SOLD' nan 'OF' 'REPORT' 'RETAIL' 'COLUMBIA'
#  'BUSINESS' '(GUAM)']
#
# Checking column E
# No drug codes found.
# non-numeric values in column E:
# ['PHARMACIES' 'AVERAGE' 'PURCHASE' 'TO' nan 'JUSTICE' 'DRUG' 'HOSPITALS'
#  'PRACTITIONERS' 'MID-LEVEL' 'TEACHING' 'BUSINESS' 'ACTIVITY:']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'PER' 'REGISTRANTS' 'PURCHASES' 'PRACTITIONERS' 'INSTITUTIONS'
#  'ACTIVITY:' 'PHARMACIES' 'HOSPITALS' 'TEACHING' 'MID-LEVEL']
#
# Checking column SUMMARY
# No drug codes found.
# non-numeric values in column SUMMARY:
# [nan 'REGISTRANT' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS' 'INSTITUTIONS']
#
# Checking column FOR
# Null column.
#
# Checking column TOTAL
# Null column.
#
# Checking column DRUG
# Null column.
#
# Checking column PURCHASES
# Null column.

# %%
activity_2000 = clean_activity_old(df=activity_2000, year=2000, 
                                   drug_codes=drug_codes, flat_geos=flat_geos)

activity_2000.head(10)
# Out:
#     Year   State Business Activity                 Drug  Registrants  \
# 6   2000  ALASKA        PHARMACIES  DL-AMPHETAMINE BASE           75
# 7   2000  ALASKA        PHARMACIES   D-AMPHETAMINE BASE           79
# 8   2000  ALASKA        PHARMACIES      METHYLPHENIDATE           80
# 9   2000  ALASKA        PHARMACIES            OXYCODONE           82
# 10  2000  ALASKA        PHARMACIES          HYDROCODONE           82
# 22  2000  ALASKA         HOSPITALS  DL-AMPHETAMINE BASE           14
# 23  2000  ALASKA         HOSPITALS   D-AMPHETAMINE BASE           19
# 24  2000  ALASKA         HOSPITALS      METHYLPHENIDATE           30
# 25  2000  ALASKA         HOSPITALS            OXYCODONE           37
# 26  2000  ALASKA         HOSPITALS          HYDROCODONE           38
#
#     Total grams sold  Avg grams/registrant
# 6            2359.66                 31.46
# 7            7791.91                 98.63
# 8           12855.76                160.69
# 9           65876.54                803.37
# 10          23932.85                291.86
# 22            270.17                 19.29
# 23           1226.84                 64.57
# 24           3939.00                131.30
# 25           8336.11                225.30
# 26           2660.70                 70.01

# %%
activity_2001 = pd.read_csv('activity_2001.txt', delim_whitespace=True)
check_activity_old(activity_2001, flat_geos, flat_activity_codes)
# Out:
# Unexpected value in column B for states: TRUST
# Unexpected value in column C for states: TERRITORIES
# Unexpected value in column D for states: (GUAM)
# Unexpected value in column F for activities: nan
# Checking column B
# Drug codes found in column B:
# ['1105D', '1724', '2165', '9041L', '9050', '9120', '9143', '9150', '9193', '9220L', '9250B', '9300', '9655', '9739', '9740', '9737', '9652', '9743', '9058', '9180L', '9104', '9190', '9603', '9170', '9317', '1105L']
# non-numeric values in column B:
# ['PERIOD:' 'ALASKA' 'OF' 'REGISTRANTS' 'NAME' nan 'BASE' '(SCHEDULE'
#  '(PETHIDINE)' 'POWDERED' 'ENFORCEMENT' 'SUMMARY' 'ALABAMA' 'ARKANSAS'
#  'ARIZONA' 'CALIFORNIA' '(PCP)' 'COLORADO' 'CONNECTICUT' 'DISTRICT'
#  'DELAWARE' 'FLORIDA' 'GEORGIA' 'HAWAII' 'IOWA' 'IDAHO' 'ILLINOIS'
#  'INDIANA' 'KANSAS' 'KENTUCKY' 'LOUISIANA' 'MASSACHUSETTS' 'MARYLAND'
#  'MAINE' 'MICHIGAN' 'MINNESOTA' 'MISSOURI' 'MISSISSIPPI' 'MONTANA'
#  'NEBRASKA' 'NORTH' 'NEW' 'NEVADA' 'OHIO' 'OKLAHOMA' 'OREGON'
#  'PENNSYLVANIA' 'PUERTO' 'RHODE' 'SOUTH' 'TENNESSEE' 'TRUST' 'TEXAS'
#  'UTAH' 'VIRGINIA' 'VIRGIN' 'VERMONT' 'WASHINGTON' 'WISCONSIN' 'WEST'
#  'WYOMING']
#
# Checking column C
# Drug codes found in column C:
# ['1100B', '1100D', '9230', '9639', '9801', '7471']
# non-numeric values in column C:
# ['BUSINESS' 'TOTAL' 'SOLD' 'CODE' nan 'DEPARTMENT' 'ADMINISTRATION' '-'
#  'FOR' 'OF' 'CAROLINA' 'DAKOTA' 'HAMPSHIRE' 'JERSEY' 'MEXICO' 'YORK'
#  'RICO' 'ISLAND' 'TERRITORIES' 'ISLANDS' 'VIRGINIA']
#
# Checking column D
# Drug codes found in column D:
# ['2125', '2315', '2270']
# non-numeric values in column D:
# ['TO' 'ACTIVITY:' 'GRAMS' 'SOLD' nan 'OF' 'REPORT' 'RETAIL' 'COLUMBIA'
#  'BUSINESS' '(GUAM)']
#
# Checking column E
# No drug codes found.
# non-numeric values in column E:
# ['PHARMACIES' 'AVERAGE' 'PURCHASE' 'TO' nan 'JUSTICE' 'DRUG' 'HOSPITALS'
#  'PRACTITIONERS' 'MID-LEVEL' 'TEACHING' 'BUSINESS' 'ACTIVITY:']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'PER' 'REGISTRANTS' 'PURCHASES' 'PRACTITIONERS' 'INSTITUTIONS'
#  'ACTIVITY:' 'PHARMACIES' 'HOSPITALS' 'TEACHING' 'MID-LEVEL']
#
# Checking column SUMMARY
# No drug codes found.
# non-numeric values in column SUMMARY:
# [nan 'REGISTRANT' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS' 'MID-LEVEL'
#  'INSTITUTIONS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'PRACTITIONERS']
#
# Checking column TOTAL
# Null column.
#
# Checking column DRUG
# Null column.
#
# Checking column PURCHASES
# Null column.

# %%
activity_2001 = clean_activity_old(df=activity_2001, year=2001, 
                                   drug_codes=drug_codes, flat_geos=flat_geos)

activity_2001.head(10)
# Out:
#     Year   State Business Activity                       Drug  Registrants  \
# 6   2001  ALASKA        PHARMACIES        DL-AMPHETAMINE BASE           79
# 7   2001  ALASKA        PHARMACIES         D-AMPHETAMINE BASE           83
# 8   2001  ALASKA        PHARMACIES          D-METHAMPHETAMINE           13
# 9   2001  ALASKA        PHARMACIES            METHYLPHENIDATE           85
# 10  2001  ALASKA        PHARMACIES   AMOBARBITAL (SCHEDULE 2)            2
# 11  2001  ALASKA        PHARMACIES                 BUTALBITAL           70
# 12  2001  ALASKA        PHARMACIES  SECOBARBITAL (SCHEDULE 2)           16
# 13  2001  ALASKA        PHARMACIES                    COCAINE            5
# 14  2001  ALASKA        PHARMACIES                    CODEINE           84
# 15  2001  ALASKA        PHARMACIES             DIHYDROCODEINE            6
#
#     Total grams sold  Avg grams/registrant
# 6            2736.82                 34.64
# 7            7486.18                 90.19
# 8              65.20                  5.01
# 9           16899.97                198.82
# 10              9.10                  4.55
# 11           7005.00                100.07
# 12            292.85                 18.30
# 13             28.88                  5.77
# 14          32748.63                389.86
# 15             11.66                  1.94

# %%
activity_2002 = pd.read_csv('activity_2002.txt', delim_whitespace=True)
check_activity_old(activity_2002, flat_geos, flat_activity_codes)
# Out:
# Unexpected value in column F for activities: nan
# Checking column B
# Drug codes found in column B:
# ['1105D', '1724', '9041L', '9050', '9064', '9143', '9150', '9193', '9250B', '9300']
# non-numeric values in column B:
# ['PERIOD:' 'ALASKA' 'OF' 'REGISTRANTS' 'NAME' nan 'BASE' '(PETHIDINE)'
#  'ENFORCEMENT' 'SUMMARY' 'ALABAMA' 'ARKANSAS' 'AMERICAN' 'ARIZONA'
#  'CALIFORNIA' 'COLORADO' 'CONNECTICUT' 'DISTRICT' 'DELAWARE' 'FLORIDA'
#  'GEORGIA' 'GUAM' 'HAWAII' 'IOWA' 'IDAHO' 'ILLINOIS' 'INDIANA' 'KANSAS'
#  'KENTUCKY' 'LOUISIANA' 'MASSACHUSETTS' 'MARYLAND' 'MAINE' 'MICHIGAN'
#  'MINNESOTA' 'MISSOURI' 'MISSISSIPPI' 'MONTANA' 'NORTH' 'NEBRASKA' 'NEW'
#  'NEVADA' 'OHIO' 'OKLAHOMA' 'OREGON' 'PENNSYLVANIA' 'PUERTO' 'RHODE'
#  'SOUTH' 'TENNESSEE' 'TEXAS' 'UTAH' 'VIRGINIA' 'VIRGIN' 'VERMONT'
#  'WASHINGTON' 'WISCONSIN' 'WEST' 'WYOMING']
#
# Checking column C
# Drug codes found in column C:
# ['1100B', '1100D', '9230', '9801']
# non-numeric values in column C:
# ['BUSINESS' 'TOTAL' 'SOLD' 'CODE' nan 'DEPARTMENT' 'ADMINISTRATION' '-'
#  'FOR' 'SAMOA' 'OF' 'CAROLINA' 'DAKOTA' 'HAMPSHIRE' 'JERSEY' 'MEXICO'
#  'YORK' 'RICO' 'ISLAND' 'ISLANDS' 'VIRGINIA']
#
# Checking column D
# No drug codes found.
# non-numeric values in column D:
# ['TO' 'ACTIVITY:' 'GRAMS' 'SOLD' nan 'OF' 'REPORT' 'RETAIL' 'BUSINESS'
#  'COLUMBIA']
#
# Checking column E
# No drug codes found.
# non-numeric values in column E:
# ['PHARMACIES' 'AVERAGE' 'PURCHASE' 'TO' nan 'JUSTICE' 'DRUG' 'HOSPITALS'
#  'PRACTITIONERS' 'MID-LEVEL' 'TEACHING' 'ACTIVITY:' 'BUSINESS']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'PER' 'REGISTRANTS' 'PAGE:' 'PURCHASES' 'PRACTITIONERS'
#  'INSTITUTIONS' 'HOSPITALS' 'ACTIVITY:' 'PHARMACIES' 'TEACHING'
#  'MID-LEVEL']
#
# Checking column SUMMARY
# No drug codes found.
# non-numeric values in column SUMMARY:
# [nan 'REGISTRANT' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS' 'MID-LEVEL'
#  'INSTITUTIONS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'PRACTITIONERS']
#
# Checking column TOTAL
# Null column.
#
# Checking column DRUG
# Null column.
#
# Checking column PURCHASES
# Null column.

# %%
activity_2002 = clean_activity_old(df=activity_2002, year=2002, 
                                   drug_codes=drug_codes, flat_geos=flat_geos)

activity_2002.head(10)
# Out:
#     Year   State Business Activity                 Drug  Registrants  \
# 6   2002  ALASKA        PHARMACIES  DL-AMPHETAMINE BASE           81
# 7   2002  ALASKA        PHARMACIES   D-AMPHETAMINE BASE           82
# 8   2002  ALASKA        PHARMACIES    D-METHAMPHETAMINE            9
# 9   2002  ALASKA        PHARMACIES      METHYLPHENIDATE           84
# 10  2002  ALASKA        PHARMACIES              COCAINE            2
# 11  2002  ALASKA        PHARMACIES              CODEINE           85
# 12  2002  ALASKA        PHARMACIES        BUPRENORPHINE            4
# 13  2002  ALASKA        PHARMACIES            OXYCODONE           86
# 14  2002  ALASKA        PHARMACIES        HYDROMORPHONE           62
# 15  2002  ALASKA        PHARMACIES          HYDROCODONE           85
#
#     Total grams sold  Avg grams/registrant
# 6            3527.03                 43.54
# 7            7719.42                 94.13
# 8              48.81                  5.42
# 9           19843.46                236.23
# 10              6.59                  3.29
# 11          32053.56                377.10
# 12              0.00                  0.00
# 13         100029.28               1163.13
# 14           2544.27                 41.03
# 15          32334.35                380.40

# %%
activity_2003 = pd.read_csv('activity_2003.txt', delim_whitespace=True)
check_activity_old(activity_2003, flat_geos, flat_activity_codes)
# Out:
# Unexpected value in column F for activities: nan
# Checking column B
# Drug codes found in column B:
# ['1105D', '1724', '9041L', '9050', '9143', '9150', '9193', '9250B', '9300']
# non-numeric values in column B:
# ['PERIOD:' 'ALASKA' 'OF' 'REGISTRANTS' 'NAME' nan 'BASE' '(PETHIDINE)'
#  'ENFORCEMENT' 'SUMMARY' 'ALABAMA' 'ARKANSAS' 'AMERICAN' 'ARIZONA'
#  'CALIFORNIA' 'COLORADO' 'CONNECTICUT' 'DISTRICT' 'DELAWARE' 'FLORIDA'
#  'GEORGIA' 'GUAM' 'HAWAII' 'IOWA' 'IDAHO' 'ILLINOIS' 'INDIANA' 'KANSAS'
#  'KENTUCKY' 'LOUISIANA' 'MASSACHUSETTS' 'MARYLAND' 'MAINE' 'MICHIGAN'
#  'MINNESOTA' 'MISSOURI' 'MISSISSIPPI' 'MONTANA' 'NORTH' 'NEBRASKA' 'NEW'
#  'NEVADA' 'OHIO' 'OKLAHOMA' 'OREGON' 'PENNSYLVANIA' 'PUERTO' 'RHODE'
#  'SOUTH' 'TENNESSEE' 'TEXAS' 'UTAH' 'VIRGINIA' 'VIRGIN' 'VERMONT'
#  'WASHINGTON' 'WISCONSIN' 'WEST' 'WYOMING']
#
# Checking column C
# Drug codes found in column C:
# ['1100B', '1100D', '9230', '9801']
# non-numeric values in column C:
# ['BUSINESS' 'TOTAL' 'SOLD' 'CODE' nan 'DEPARTMENT' 'ADMINISTRATION' '-'
#  'FOR' 'SAMOA' 'OF' 'CAROLINA' 'DAKOTA' 'HAMPSHIRE' 'JERSEY' 'MEXICO'
#  'YORK' 'RICO' 'ISLAND' 'ISLANDS' 'VIRGINIA']
#
# Checking column D
# No drug codes found.
# non-numeric values in column D:
# ['TO' 'ACTIVITY:' 'GRAMS' 'SOLD' nan 'OF' 'REPORT' 'RETAIL' 'BUSINESS'
#  'COLUMBIA']
#
# Checking column E
# No drug codes found.
# non-numeric values in column E:
# ['PHARMACIES' 'AVERAGE' 'PURCHASE' 'TO' nan 'JUSTICE' 'DRUG' 'HOSPITALS'
#  'PRACTITIONERS' 'MID-LEVEL' 'TEACHING' 'ACTIVITY:' 'BUSINESS']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'PER' 'REGISTRANTS' 'PURCHASES' 'PRACTITIONERS' 'INSTITUTIONS'
#  'HOSPITALS' 'ACTIVITY:' 'PHARMACIES' 'TEACHING' 'MID-LEVEL']
#
# Checking column SUMMARY
# No drug codes found.
# non-numeric values in column SUMMARY:
# [nan 'REGISTRANT' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS' 'MID-LEVEL'
#  'INSTITUTIONS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'PRACTITIONERS']
#
# Checking column TOTAL
# Null column.
#
# Checking column DRUG
# Null column.
#
# Checking column PURCHASES
# Null column.

# %%
activity_2003 = clean_activity_old(df=activity_2003, year=2003, 
                                   drug_codes=drug_codes, flat_geos=flat_geos)

activity_2003.head(10)
# Out:
#     Year   State Business Activity                    Drug  Registrants  \
# 6   2003  ALASKA        PHARMACIES     DL-AMPHETAMINE BASE           82
# 7   2003  ALASKA        PHARMACIES      D-AMPHETAMINE BASE           83
# 8   2003  ALASKA        PHARMACIES       D-METHAMPHETAMINE           10
# 9   2003  ALASKA        PHARMACIES         METHYLPHENIDATE           86
# 10  2003  ALASKA        PHARMACIES                 COCAINE            4
# 11  2003  ALASKA        PHARMACIES                 CODEINE           85
# 12  2003  ALASKA        PHARMACIES               OXYCODONE           89
# 13  2003  ALASKA        PHARMACIES           HYDROMORPHONE           61
# 14  2003  ALASKA        PHARMACIES             HYDROCODONE           88
# 15  2003  ALASKA        PHARMACIES  MEPERIDINE (PETHIDINE)           79
#
#     Total grams sold  Avg grams/registrant
# 6            3617.96                 44.12
# 7            7352.22                 88.58
# 8              44.01                  4.40
# 9           19864.27                230.97
# 10             15.51                  3.87
# 11          31933.20                375.68
# 12          88212.61                991.15
# 13           1961.41                 32.15
# 14          36279.31                412.26
# 15          19871.25                251.53

# %%
activity_2004 = pd.read_csv('activity_2004.txt', delim_whitespace=True)
check_activity_old(activity_2004, flat_geos, flat_activity_codes)
# Out:
# Unexpected value in column F for activities: nan
# Checking column B
# Drug codes found in column B:
# ['1105D', '1724', '9041L', '9050', '9143', '9150', '9193', '9250B', '9300']
# non-numeric values in column B:
# ['PERIOD:' 'ALASKA' 'OF' 'REGISTRANTS' 'TRADE' nan 'BASE' '(PETHIDINE)'
#  'ENFORCEMENT' 'SUMMARY' 'ALABAMA' 'ARKANSAS' 'AMERICAN' 'ARIZONA'
#  'CALIFORNIA' 'COLORADO' 'CONNECTICUT' 'DISTRICT' 'DELAWARE' 'FLORIDA'
#  'GEORGIA' 'GUAM' 'HAWAII' 'IOWA' 'IDAHO' 'ILLINOIS' 'INDIANA' 'KANSAS'
#  'KENTUCKY' 'LOUISIANA' 'MASSACHUSETTS' 'MARYLAND' 'MAINE' 'MICHIGAN'
#  'MINNESOTA' 'MISSOURI' 'MISSISSIPPI' 'MONTANA' 'NORTH' 'NEBRASKA' 'NEW'
#  'NEVADA' 'OHIO' 'OKLAHOMA' 'OREGON' 'PENNSYLVANIA' 'PUERTO' 'RHODE'
#  'SOUTH' 'TENNESSEE' 'TEXAS' 'UTAH' 'VIRGINIA' 'VIRGIN' 'VERMONT'
#  'WASHINGTON' 'WISCONSIN' 'WEST' 'WYOMING']
#
# Checking column C
# Drug codes found in column C:
# ['1100B', '1100D', '9230', '9801']
# non-numeric values in column C:
# ['BUSINESS' 'TOTAL' 'SOLD' 'NAME' nan 'DEPARTMENT' 'ADMINISTRATION,' '-'
#  'FOR' 'SAMOA' 'OF' 'CAROLINA' 'DAKOTA' 'HAMPSHIRE' 'JERSEY' 'MEXICO'
#  'YORK' 'RICO' 'ISLAND' 'ISLANDS' 'VIRGINIA']
#
# Checking column D
# No drug codes found.
# non-numeric values in column D:
# ['TO' 'ACTIVITY:' 'GRAMS' 'CODE' nan 'OF' 'OFFICE' 'REPORT' 'RETAIL'
#  'BUSINESS' 'COLUMBIA']
#
# Checking column E
# No drug codes found.
# non-numeric values in column E:
# ['PHARMACIES' 'AVERAGE' 'GRAM' 'SOLD' nan 'JUSTICE' 'OF' 'DRUG'
#  'HOSPITALS' 'PRACTITIONERS' 'MID-LEVEL' 'TEACHING' 'ACTIVITY:' 'BUSINESS']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'WGT' 'TO' 'DIVERSION' 'PURCHASES' 'PRACTITIONERS' 'INSTITUTIONS'
#  'HOSPITALS' 'ACTIVITY:' 'PHARMACIES' 'TEACHING' 'MID-LEVEL']
#
# Checking column SUMMARY
# No drug codes found.
# non-numeric values in column SUMMARY:
# [nan 'PER' 'REGISTRANTS' 'CONTROL' 'BY' 'PHARMACIES' 'HOSPITALS'
#  'PRACTITIONERS' 'MID-LEVEL' 'INSTITUTIONS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'REGISTRANT' 'GRAMS' 'PRACTITIONERS']
#
# Checking column TOTAL
# No drug codes found.
# non-numeric values in column TOTAL:
# [nan 'WEIGHT']
#
# Checking column DRUG
# Null column.
#
# Checking column PURCHASES
# Null column.

# %%
activity_2004 = clean_activity_old(df=activity_2004, year=2004, 
                                   drug_codes=drug_codes, flat_geos=flat_geos)

activity_2004.head(10)
# Out:
#     Year   State Business Activity                    Drug  Registrants  \
# 6   2004  ALASKA        PHARMACIES     DL-AMPHETAMINE BASE           82
# 7   2004  ALASKA        PHARMACIES      D-AMPHETAMINE BASE           82
# 8   2004  ALASKA        PHARMACIES       D-METHAMPHETAMINE            8
# 9   2004  ALASKA        PHARMACIES         METHYLPHENIDATE           83
# 10  2004  ALASKA        PHARMACIES                 COCAINE            2
# 11  2004  ALASKA        PHARMACIES                 CODEINE           92
# 12  2004  ALASKA        PHARMACIES               OXYCODONE           87
# 13  2004  ALASKA        PHARMACIES           HYDROMORPHONE           57
# 14  2004  ALASKA        PHARMACIES             HYDROCODONE           91
# 15  2004  ALASKA        PHARMACIES  MEPERIDINE (PETHIDINE)           78
#
#     Total grams sold  Avg grams/registrant
# 6            4147.54                 50.57
# 7            7603.11                 92.72
# 8              22.01                  2.75
# 9           21297.96                256.60
# 10              1.06                  0.53
# 11          30516.76                331.70
# 12          89450.06               1028.16
# 13           1743.55                 30.58
# 14          38206.10                419.84
# 15          17938.42                229.97

# %%
activity_2005 = pd.read_csv('activity_2005.txt', delim_whitespace=True)
check_activity_old(activity_2005, flat_geos, flat_activity_codes)
# Out:
# Unexpected value in column F for activities: nan
# Checking column B
# Drug codes found in column B:
# ['1724', '9041L', '9050', '9064', '9143', '9150', '9193', '9250B', '9300']
# non-numeric values in column B:
# ['PERIOD:' 'ALASKA' 'OF' 'REGISTRANTS' 'NAME' nan 'BASE' '(PETHIDINE)'
#  'ENFORCEMENT' 'SUMMARY' 'ALABAMA' 'ARKANSAS' 'AMERICAN' 'ARIZONA'
#  'CALIFORNIA' 'COLORADO' 'CONNECTICUT' 'DISTRICT' 'DELAWARE' 'FLORIDA'
#  'GEORGIA' 'GUAM' 'HAWAII' 'IOWA' 'IDAHO' 'ILLINOIS' 'INDIANA' 'KANSAS'
#  'KENTUCKY' 'LOUISIANA' 'MASSACHUSETTS' 'MARYLAND' 'MAINE' 'MICHIGAN'
#  'MINNESOTA' 'MISSOURI' 'MISSISSIPPI' 'MONTANA' 'NORTH' 'NEBRASKA' 'NEW'
#  'NEVADA' 'OHIO' 'OKLAHOMA' 'OREGON' 'PENNSYLVANIA' 'PUERTO' 'RHODE'
#  'SOUTH' 'TENNESSEE' 'TEXAS' 'UTAH' 'VIRGINIA' 'VIRGIN' 'VERMONT'
#  'WASHINGTON' 'WISCONSIN' 'WEST' 'WYOMING']
#
# Checking column C
# Drug codes found in column C:
# ['1100B', '1100D', '9230', '9801']
# non-numeric values in column C:
# ['BUSINESS' 'TOTAL' 'SOLD' 'CODE' nan 'DEPARTMENT' 'ADMINISTRATION,' '-'
#  'FOR' 'SAMOA' 'OF' 'CAROLINA' 'DAKOTA' 'HAMPSHIRE' 'JERSEY' 'MEXICO'
#  'YORK' 'RICO' 'ISLAND' 'ISLANDS' 'VIRGINIA']
#
# Checking column D
# No drug codes found.
# non-numeric values in column D:
# ['TO' 'ACTIVITY:' 'GRAMS' 'SOLD' nan 'OF' 'OFFICE' 'REPORT' 'RETAIL'
#  'BUSINESS' 'COLUMBIA']
#
# Checking column E
# No drug codes found.
# non-numeric values in column E:
# ['PHARMACIES' 'AVERAGE' 'GRAM' 'TO' nan 'JUSTICE' 'OF' 'DRUG' 'HOSPITALS'
#  'PRACTITIONERS' 'MID-LEVEL' 'TEACHING' 'ACTIVITY:' 'BUSINESS']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'WGT' 'REGISTRANTS' 'PAGE:' 'DIVERSION' 'PURCHASES' 'PRACTITIONERS'
#  'INSTITUTIONS' 'HOSPITALS' 'ACTIVITY:' 'PHARMACIES' 'TEACHING'
#  'MID-LEVEL']
#
# Checking column SUMMARY
# No drug codes found.
# non-numeric values in column SUMMARY:
# [nan 'PER' 'REGISTRANT' 'CONTROL' 'BY' 'PHARMACIES' 'HOSPITALS'
#  'PRACTITIONERS' 'MID-LEVEL' 'INSTITUTIONS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'GRAMS' 'PRACTITIONERS']
#
# Checking column TOTAL
# No drug codes found.
# non-numeric values in column TOTAL:
# [nan 'WEIGHT']
#
# Checking column DRUG
# Null column.
#
# Checking column PURCHASES
# Null column.

# %%
activity_2005 = clean_activity_old(df=activity_2005, year=2005, 
                                   drug_codes=drug_codes, flat_geos=flat_geos)

activity_2005.head(10)
# Out:
#     Year   State Business Activity                    Drug  Registrants  \
# 6   2005  ALASKA        PHARMACIES     DL-AMPHETAMINE BASE           81
# 7   2005  ALASKA        PHARMACIES      D-AMPHETAMINE BASE           84
# 8   2005  ALASKA        PHARMACIES         METHYLPHENIDATE           85
# 9   2005  ALASKA        PHARMACIES                 COCAINE            2
# 10  2005  ALASKA        PHARMACIES                 CODEINE           90
# 11  2005  ALASKA        PHARMACIES           BUPRENORPHINE           32
# 12  2005  ALASKA        PHARMACIES               OXYCODONE           88
# 13  2005  ALASKA        PHARMACIES           HYDROMORPHONE           67
# 14  2005  ALASKA        PHARMACIES             HYDROCODONE           89
# 15  2005  ALASKA        PHARMACIES  MEPERIDINE (PETHIDINE)           75
#
#     Total grams sold  Avg grams/registrant
# 6            4177.83                 51.57
# 7            7208.45                 85.81
# 8           20836.45                245.13
# 9               4.89                  2.44
# 10          28050.89                311.67
# 11            424.41                 13.26
# 12          81238.51                923.16
# 13           1610.07                 24.03
# 14          39198.21                440.42
# 15          14308.89                190.78

# %% [markdown]
# #### Moving on to new year files
#
# Like with the other reports, years after 2006 follow a slightly different format, so we need to adjust the checking and cleaning code to account for that.

# %%
activity_2006 = pd.read_csv('activity_2006.txt', delim_whitespace=True)
activity_2006.head(10)
# Out:
#                ARCOS          3           -      REPORT           5  \
# 0          REPORTING    PERIOD:  01/01/2006          TO  12/31/2006
# 1                Run      Date:  03/27/2015         NaN         NaN
# 2      STATE:ALABAMA   BUSINESS  ACTIVITY:A           -  PHARMACIES
# 3               DRUG       NAME        DRUG        CODE      BUYERS
# 4        AMPHETAMINE       1100       1,215  193,908.24       159.6
# 5  D-METHAMPHETAMINE      1105D          55      244.11        4.44
# 6    METHYLPHENIDATE       1724       1,219  278,888.64      228.78
# 7         BUTALBITAL       2165         927      47,630       51.38
# 8      PENTOBARBITAL  (SCHEDULE          2)        2270           2
# 9       SECOBARBITAL  (SCHEDULE          2)        2315          12
#
#   STATISTICAL SUMMARY  FOR RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 0         NaN     NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 1         NaN     NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 2         NaN     NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 3       TOTAL   GRAMS  AVG  GRAMS   NaN        NaN NaN    NaN NaN
# 4         NaN     NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 5         NaN     NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 6         NaN     NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 7         NaN     NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 8       27.33   13.67  NaN    NaN   NaN        NaN NaN    NaN NaN
# 9         183   15.25  NaN    NaN   NaN        NaN NaN    NaN NaN

# %%
def check_activity_new(df, flat_geos, flat_activity_codes):
    df.rename(columns={'ARCOS': "A", 
                   '3':'B', 
                   '-': 'C', 
                   'REPORT': 'D', 
                   '5':'E', 
                   'STATISTICAL':'F', 
                   'SUMMARY': 'G'}, 
          inplace=True)
    # check for unusual values in column A - 
    # we don't expect any numeric values here
    check_a = df['A'].loc[df['A'].str.match('^[0-9]+', na=False)].unique().tolist()
    if len(check_a)>0:
        print("Unusual numerical values in column A:")
        print(check_a)
        print()
    
    # check for unexpected geography names
    l = df['A'].loc[df['A'].str.match('STATE:')].unique().tolist()
    l = [x.split(":")[1] for x in l]
    for i in l:
        if i not in flat_geos:
            print("Unexpected value in column A for states: {}".format(i))
    
    # check for unusual activity codes
    for c in ['C', 'D', 'E']:
        codes = df[c].loc[df[c].str.match("ACTIVITY:", 
                                              na=False)].str.split(":", 
                                                                   expand=True)[1].unique().tolist()
        for code in codes:
            if code not in activity_codes.keys():
                print("Unexpected activity code {} in column {}:".format(code, c))
            

    # we don't expect any numeric values to show up until col C
    for c in ['A', 'B']:
        check = df[c].loc[(df[c].str.match('^[0-9]+', 
                                           na=False))
                           & (~df[c].str.match('^[0-9]{4}[A-Z]?', 
                                               na=False))].unique().tolist()
        if len(check)>0:
            print("Unusual numerical values in column {}".format(c))
            print(check)
            print()
          
    # check for unusual values in columns B and C
    for i in df['B'].loc[df['A'].str.match('STATE:')].unique().tolist():
        if i not in flat_geos:
            print("Unexpected value in column B for states: {}".format(i))

    for i in df['C'].loc[df['A'].str.match('STATE:')].unique().tolist():
        if i not in flat_geos:
            print("Unexpected value in column C for states: {}".format(i))

            
    # check for drug codes
    cols = ['B', 'C', 'D', 'E', 'F', 'G', 'FOR', 'RETAIL', 
            'DRUG', 'PURCHASES', 'BY', 'GRAMS', 'WT']
    code_columns = {}
    for c in cols:
        print("Checking column {}".format(c))
        if pd.isnull(df[c]).all():
            print("Null column.")
        else:
            try:
                vals = df[c].loc[df[c].str.match('^[0-9]{4}[A-Z]?', 
                                                 na=False)].unique().tolist()
            except AttributeError:
                vals = df[c].loc[df[c].astype(str).str.match('^[0-9]{4}[A-Z]?', 
                                                             na=False)].unique().tolist()
            if len(vals)>0:
                code_columns[c] = []
                print("Drug codes found in column {}:".format(c))
                print(vals)

                for v in vals:
                    code_columns[c].append(v)
                    if v not in drug_codes.keys():
                        print("Unexpected code found: {}".format(v))
            else:
                print("No drug codes found.")
            try:
                check = df[c].loc[~df[c].str.match('^[0-9]+', na=False)].unique()
            except AttributeError:
                check = df[c].loc[~df[c].astype(str).str.match('^[0-9]+', na=False)].unique()
            print("non-numeric values in column {}:".format(c))
            print(check)

        print()

# %%
check_activity_new(activity_2006, flat_geos=flat_geos, flat_activity_codes=flat_activity_codes)
# Out:
# Unusual numerical values in column A:
# ['14-HYDROXYCODEINONE']
#
# Unusual numerical values in column A
# ['14-HYDROXYCODEINONE']
#
# Unusual numerical values in column B
# ['3']
#
# Unexpected value in column B for states: BUSINESS
# Unexpected value in column C for states: ACTIVITY:A
# Unexpected value in column C for states: ACTIVITY:B
# Unexpected value in column C for states: ACTIVITY:C
# Unexpected value in column C for states: ACTIVITY:D
# Unexpected value in column C for states: ACTIVITY:M
# Unexpected value in column C for states: ACTIVITY:N-U
# Unexpected value in column C for states: BUSINESS
# Checking column B
# Drug codes found in column B:
# ['1100', '1105D', '1724', '2165', '7379', '9041L', '9050', '9064', '9120', '9143', '9150', '9193', '9220L', '9250B', '9300', '9411', '9652', '9739', '9737', '9665', '9655', '7285', '9190', '9180L', '7370', '9273D', '9333']
# non-numeric values in column B:
# ['PERIOD:' 'Date:' 'BUSINESS' 'NAME' '(SCHEDULE' '(PETHIDINE)' 'POWDERED'
#  'BASE' 'SUMMARY' 'SAMOA' 'OF' nan '(PCP)' 'HYDROXYBUTYRIC' 'HAMPSHIRE'
#  'JERSEY' 'MEXICO' 'YORK' 'CAROLINA' 'DAKOTA' 'RICO' 'ISLAND' 'ISLANDS'
#  'VIRGINIA']
#
# Checking column C
# Drug codes found in column C:
# ['9230', '9639', '9801', '9740', '7471']
# non-numeric values in column C:
# ['ACTIVITY:A' 'DRUG' 'ACTIVITY:B' '-' 'FOR' 'ACTIVITY:C' 'ACTIVITY:D'
#  'ACTIVITY:M' 'ACTIVITY:N-U' 'BUSINESS' 'COLUMBIA' nan 'ACID']
#
# Checking column D
# Drug codes found in column D:
# ['2270', '2315', '2125', '2010']
# non-numeric values in column D:
# ['TO' nan '-' 'CODE' 'REPORT' 'RETAIL' 'NARCOTIC' 'ACTIVITY:B' 'BUSINESS'
#  'ACTIVITY:A' 'ACTIVITY:C' 'ACTIVITY:M' 'ACTIVITY:N-U' 'ACTIVITY:D']
#
# Checking column E
# No drug codes found.
# non-numeric values in column E:
# [nan 'PHARMACIES' 'BUYERS' 'HOSPITALS' 'DRUG' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' '-' 'ACTIVITY:A' 'ACTIVITY:B' 'ACTIVITY:C'
#  'ACTIVITY:M' 'ACTIVITY:N-U' 'NARCOTIC']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'TOTAL' 'PURCHASES' 'INSTITUTIONS' 'PRACTITIONERS' 'PROGRAMS'
#  'HOSPITALS' '-' 'NARCOTIC' 'PHARMACIES' 'MID-LEVEL' 'TREATMENT'
#  'TEACHING']
#
# Checking column G
# No drug codes found.
# non-numeric values in column G:
# [nan 'GRAMS' 'BY' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS' 'MID-LEVEL'
#  'TREATMENT' 'PROGRAMS' 'INSTITUTIONS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'AVG' 'GRAMS' 'PRACTITIONERS']
#
# Checking column RETAIL
# No drug codes found.
# non-numeric values in column RETAIL:
# [nan 'GRAMS' 'WT']
#
# Checking column DRUG
# Null column.
#
# Checking column PURCHASES
# Null column.
#
# Checking column BY
# Null column.
#
# Checking column GRAMS
# Null column.
#
# Checking column WT
# Null column.

# %%
def clean_activity_new(df, year, drug_codes, flat_geos, activity_codes):
    """
    Use for years 2006 to   inclusive
    """
    # rename columns
    df.rename(columns={'ARCOS': "A", 
                   '3':'B', 
                   '-': 'C', 
                   'REPORT': 'D', 
                   '5':'E', 
                   'STATISTICAL':'F', 
                   'SUMMARY': 'G'}, 
          inplace=True)

    # insert new columns
    df.insert(column='Year', loc=0, value=year)
    df.insert(column='State', loc=1, value=None)
    df.insert(column='Business Activity', loc=2, value=None)
    df.insert(column='Drug', loc=3, value=None)

    # get state names
    df.loc[(df['A'].str.match("STATE:", na=False)) 
           &(df['B']=='BUSINESS'), 'State'] = df['A'].str.split(":", expand=True)[1]
    df.loc[(df['A'].str.match("STATE:", na=False)) 
           &(df['C']=='BUSINESS'), 'State'] = df['A'].str.split(":", expand=True)[1]+" "+df['B']
    df.loc[(df['A'].str.match("STATE:", na=False)) 
           &(df['D']=='BUSINESS'), 'State'] = df['A'].str.split(":", expand=True)[1]+" "+df['B']+" "+df['C']
    
    # add a line to specifically handle the 2017 file
    df.loc[(df['A'].str.match("ENTIRE", na=False)) 
           &(df['B']=='UNITED'), 'State'] = 'UNITED STATES'

    # get business activity codes
    # will use the activity code dict later to get the name
    cols = ['C', 'D', 'E']
    cols_shift = ['D', 'E', 'F']
    for c in cols:
        i = cols.index(c)
        df.loc[df[c].str.match("ACTIVITY:[A-Z]", na=False), 
                      'Business Activity'] = df[c].str.split(":", expand=True)[1]
        # in a few cases, the letter code is not concatenated
        # and appears in the next column
        df.loc[df[c].str.match("ACTIVITY:$", na=False), 
          'Business Activity'] = df[cols_shift[i]]

    # forward fill state and business activity codes
    df['State'] = df['State'].fillna(method='ffill')
    df['Business Activity'] = df['Business Activity'].fillna(method='ffill')

    # get drug code & update
    # same code as in the checking function but quiet
    cols = ['B', 'C', 'D', 'E', 'F', 'G', 
            'FOR', 'RETAIL', 'DRUG', 
            'PURCHASES', 'BY', 'GRAMS', 'WT']    
    code_columns = {}

    for c in cols:
        if pd.isnull(df[c]).all():
            continue
        else:
            try:
                vals = df[c].loc[df[c].str.match('^[0-9]{4}[A-Z]?', 
                                                 na=False)].unique().tolist()
            except AttributeError:
                vals = df[c].loc[df[c].astype(str).str.match('^[0-9]{4}[A-Z]?', 
                                                             na=False)].unique().tolist()            
            if len(vals)>0:
                code_columns[c] = []
                for v in vals:
                    code_columns[c].append(v)
                    if v not in drug_codes.keys():
                        print("Unexpected drug code found: {}".format(v))
            else:
                continue
    for col in code_columns.keys():
        for code in code_columns[col]:
            df.loc[df[col]==code, 'Drug'] = drug_codes[code]
        
    # drop unnecessary rows
    df = df.drop(df.loc[df['A'].str.match("STATE:")].index)
    df = df.drop(df.loc[pd.isnull(df['Drug'])].index)

    
    # add the last few columns we need
    df.insert(column='Registrants', loc=4, value=None)
    df.insert(column='Total grams sold', loc=5, value=None)
    df.insert(column='Avg grams/registrant', loc=6, value=None)
    
    # shift data
    shift = ['B', 'C', 'D', 'E', 'F', 
            'G', 'FOR', 'RETAIL', 'DRUG', 
            'PURCHASES', 'BY', 'GRAMS', 'WT']  
    for col in code_columns.keys():
            i = shift.index(col)
            for code in code_columns[col]:
                df.loc[df[col]==code, 'Registrants'] = df[shift[i+1]]
                df.loc[df[col]==code, 'Total grams sold'] = df[shift[i+2]]
                df.loc[df[col]==code, 'Avg grams/registrant'] = df[shift[i+3]]

    # final cleanup
    df.loc[df['State']=='TRUST TERRITORIES (GUAM)', 'State'] = "GUAM"
    repl = ['Total grams sold', 'Avg grams/registrant']
    
    # in a few cases there are files that come in 
    # having mixed datatypes within columns 
    # or formatted as floats in a column where we only want ints
    # exceptions catch these and convert everything to strings first
    for col in repl:
        try:
            df[col] = df[col].str.replace(",","").astype(float)
        except:
            df[col] = df[col].astype(str)
            df[col] = df[col].str.replace(",","").astype(float)
    
    try:
        df['Registrants'] = df['Registrants'].str.replace(",","").astype(int)
    except:
        df['Registrants'] = df['Registrants'].astype(str)
        try:
            df['Registrants'] = df['Registrants'].str.replace(",","").astype(int)
        except ValueError:
            df['Registrants'] = df['Registrants'].str.replace(",","").astype(float).astype(int)
    
    # get business activity names
    df['Business Activity'] = df['Business Activity'].apply(lambda x: activity_codes[x])
    df = df[['Year', 'State', 'Business Activity', 'Drug',
             'Registrants', 'Total grams sold', 'Avg grams/registrant']]
    return df

# %%
activity_2006 = clean_activity_new(activity_2006, year=2006, 
                                   drug_codes=drug_codes, flat_geos=flat_geos, 
                                   activity_codes=activity_codes)
activity_2006.head()
# Out:
#    Year    State Business Activity                        Drug  Registrants  \
# 4  2006  ALABAMA        PHARMACIES                 AMPHETAMINE         1215
# 5  2006  ALABAMA        PHARMACIES           D-METHAMPHETAMINE           55
# 6  2006  ALABAMA        PHARMACIES             METHYLPHENIDATE         1219
# 7  2006  ALABAMA        PHARMACIES                  BUTALBITAL          927
# 8  2006  ALABAMA        PHARMACIES  PENTOBARBITAL (SCHEDULE 2)            2
#
#    Total grams sold  Avg grams/registrant
# 4         193908.24                159.60
# 5            244.11                  4.44
# 6         278888.64                228.78
# 7          47630.00                 51.38
# 8             27.33                 13.67

# %%
activity_2007 = pd.read_csv('activity_2007.txt', delim_whitespace=True)
check_activity_new(activity_2007, flat_geos=flat_geos, 
                   flat_activity_codes=flat_activity_codes)
# Out:
# Unusual numerical values in column B
# ['3']
#
# Unexpected value in column B for states: BUSINESS
# Unexpected value in column C for states: ACTIVITY:A
# Unexpected value in column C for states: ACTIVITY:B
# Unexpected value in column C for states: ACTIVITY:C
# Unexpected value in column C for states: ACTIVITY:D
# Unexpected value in column C for states: ACTIVITY:M
# Unexpected value in column C for states: ACTIVITY:N-U
# Unexpected value in column C for states: BUSINESS
# Checking column B
# Drug codes found in column B:
# ['1100', '1105D', '1205', '1724', '2165', '7379', '9041L', '9050', '9064', '9120', '9143', '9150', '9193', '9220L', '9250B', '9300', '9411', '9652', '9739', '9737', '9655', '9180L', '9273D']
# non-numeric values in column B:
# ['PERIOD:' 'Date:' 'BUSINESS' 'NAME' '(SCHEDULE' '(PETHIDINE)' 'POWDERED'
#  'BASE' 'SUMMARY' 'HYDROXYBUTYRIC' 'SAMOA' 'OF' nan 'IN' '(PCP)'
#  'HAMPSHIRE' 'JERSEY' 'MEXICO' 'YORK' 'CAROLINA' 'DAKOTA' 'RICO' 'ISLAND'
#  'ISLANDS' 'VIRGINIA']
#
# Checking column C
# Drug codes found in column C:
# ['9230', '9639', '9801', '9740', '7471']
# non-numeric values in column C:
# ['ACTIVITY:A' 'DRUG' 'ACTIVITY:B' '-' 'FOR' 'ACTIVITY:C' 'ACID' 'ACID(FDA'
#  'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' 'BUSINESS' 'COLUMBIA' nan
#  'SESAME']
#
# Checking column D
# Drug codes found in column D:
# ['2270', '2315', '2125', '2010']
# non-numeric values in column D:
# ['TO' nan '-' 'CODE' 'REPORT' 'RETAIL' 'APPROVED' 'NARCOTIC' 'ACTIVITY:B'
#  'BUSINESS' 'OIL' 'ACTIVITY:A' 'ACTIVITY:C' 'ACTIVITY:M' 'ACTIVITY:N-U'
#  'ACTIVITY:D']
#
# Checking column E
# Drug codes found in column E:
# ['2012', '7369']
# non-numeric values in column E:
# [nan 'PHARMACIES' 'BUYERS' 'HOSPITALS' 'DRUG' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' '-' 'ACTIVITY:A' 'ACTIVITY:B' 'ACTIVITY:C'
#  'ACTIVITY:N-U' 'NARCOTIC']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'TOTAL' 'PURCHASES' 'INSTITUTIONS' 'PRACTITIONERS' 'PROGRAMS'
#  'HOSPITALS' '-' 'NARCOTIC' 'PHARMACIES' 'MID-LEVEL' 'TREATMENT'
#  'TEACHING']
#
# Checking column G
# No drug codes found.
# non-numeric values in column G:
# [nan 'GRAMS' 'BY' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS' 'TREATMENT'
#  'PROGRAMS' 'INSTITUTIONS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'AVG' 'GRAMS']
#
# Checking column RETAIL
# No drug codes found.
# non-numeric values in column RETAIL:
# [nan 'GRAMS' 'WT']
#
# Checking column DRUG
# Null column.
#
# Checking column PURCHASES
# Null column.
#
# Checking column BY
# Null column.
#
# Checking column GRAMS
# Null column.
#
# Checking column WT
# Null column.

# %%
activity_2007 = clean_activity_new(activity_2007, year=2007, 
                                   drug_codes=drug_codes, flat_geos=flat_geos, 
                                   activity_codes=activity_codes)
activity_2007.head()
# Out:
#    Year    State Business Activity               Drug  Registrants  \
# 4  2007  ALABAMA        PHARMACIES        AMPHETAMINE         1238
# 5  2007  ALABAMA        PHARMACIES  D-METHAMPHETAMINE           53
# 6  2007  ALABAMA        PHARMACIES   LISDEXAMFETAMINE          908
# 7  2007  ALABAMA        PHARMACIES    METHYLPHENIDATE         1244
# 8  2007  ALABAMA        PHARMACIES         BUTALBITAL          945
#
#    Total grams sold  Avg grams/registrant
# 4         240152.17                193.98
# 5            283.08                  5.34
# 6          16325.77                 17.98
# 7         318954.58                256.39
# 8          51850.00                 54.87

# %%
activity_2008 = pd.read_csv('activity_2008.txt', delim_whitespace=True)
check_activity_new(activity_2008, flat_geos=flat_geos, 
                   flat_activity_codes=flat_activity_codes)
# Out:
# Unusual numerical values in column A:
# ['3,4-METHYLENEDIOXYAMPHETAMINE']
#
# Unusual numerical values in column A
# ['3,4-METHYLENEDIOXYAMPHETAMINE']
#
# Unusual numerical values in column B
# ['3']
#
# Unexpected value in column B for states: BUSINESS
# Unexpected value in column C for states: ACTIVITY:A
# Unexpected value in column C for states: ACTIVITY:B
# Unexpected value in column C for states: ACTIVITY:C
# Unexpected value in column C for states: ACTIVITY:D
# Unexpected value in column C for states: ACTIVITY:M
# Unexpected value in column C for states: ACTIVITY:N-U
# Unexpected value in column C for states: BUSINESS
# Checking column B
# Drug codes found in column B:
# ['1100', '1105D', '1205', '1724', '2165', '9041L', '9050', '9064', '9120', '9143', '9150', '9193', '9220L', '9250B', '9300', '9652', '9737', '9739', '1615', '7379', '9668', '9190', '9180L', '2285', '2885', '9170', '9655', '7370', '2765', '9273D']
# non-numeric values in column B:
# ['PERIOD:' 'Date:' 'BUSINESS' 'NAME' '(SCHEDULE' '(PETHIDINE)' 'POWDERED'
#  'BASE' 'SUMMARY' 'HYDROXYBUTYRIC' 'SAMOA' '(PCP)' 'OF' nan '(3,4-MDA'
#  'HAMPSHIRE' 'JERSEY' 'MEXICO' 'YORK' 'ACID)' 'CAROLINA' 'DAKOTA' 'RICO'
#  'ISLAND' 'ISLANDS' 'VIRGINIA']
#
# Checking column C
# Drug codes found in column C:
# ['9230', '9639', '9801', '9740', '7471', '9168']
# non-numeric values in column C:
# ['ACTIVITY:A' 'DRUG' 'ACTIVITY:B' '-' 'FOR' 'ACTIVITY:C' 'ACID'
#  'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' 'BUSINESS' 'ACID(FDA' 'COLUMBIA'
#  nan 'O']
#
# Checking column D
# Drug codes found in column D:
# ['2270', '2315', '2125', '2010', '7400']
# non-numeric values in column D:
# ['TO' nan '-' 'CODE' 'REPORT' 'RETAIL' 'NARCOTIC' 'ACTIVITY:B' 'APPROVED'
#  'BUSINESS' 'ACTIVITY:A' 'ACTIVITY:C' 'ACTIVITY:M' 'ACTIVITY:N-U'
#  'ACTIVITY:D']
#
# Checking column E
# Drug codes found in column E:
# ['2012']
# non-numeric values in column E:
# [nan 'PHARMACIES' 'BUYERS' 'HOSPITALS' 'DRUG' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' '-' 'ACTIVITY:A' 'ACTIVITY:B' 'ACTIVITY:C'
#  'ACTIVITY:N-U' 'NARCOTIC']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'TOTAL' 'PURCHASES' 'INSTITUTIONS' 'PRACTITIONERS' 'PROGRAMS'
#  'HOSPITALS' '-' 'NARCOTIC' 'PHARMACIES' 'MID-LEVEL' 'TREATMENT'
#  'TEACHING']
#
# Checking column G
# No drug codes found.
# non-numeric values in column G:
# [nan 'GRAMS' 'BY' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS' 'TREATMENT'
#  'PROGRAMS' 'INSTITUTIONS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'AVG' 'GRAMS']
#
# Checking column RETAIL
# No drug codes found.
# non-numeric values in column RETAIL:
# [nan 'GRAMS' 'WT']
#
# Checking column DRUG
# Null column.
#
# Checking column PURCHASES
# Null column.
#
# Checking column BY
# Null column.
#
# Checking column GRAMS
# Null column.
#
# Checking column WT
# Null column.

# %%
activity_2008 = clean_activity_new(activity_2008, year=2008, 
                                   drug_codes=drug_codes, flat_geos=flat_geos, 
                                   activity_codes=activity_codes)
activity_2008.head()
# Out:
#    Year    State Business Activity               Drug  Registrants  \
# 4  2008  ALABAMA        PHARMACIES        AMPHETAMINE         1267
# 5  2008  ALABAMA        PHARMACIES  D-METHAMPHETAMINE           50
# 6  2008  ALABAMA        PHARMACIES   LISDEXAMFETAMINE         1180
# 7  2008  ALABAMA        PHARMACIES    METHYLPHENIDATE         1266
# 8  2008  ALABAMA        PHARMACIES         BUTALBITAL          797
#
#    Total grams sold  Avg grams/registrant
# 4         228044.03                179.99
# 5            196.43                  3.93
# 6          70740.36                 59.95
# 7         268348.52                211.97
# 8          33050.00                 41.47

# %%
activity_2009 = pd.read_csv('activity_2009.txt', delim_whitespace=True)
check_activity_new(activity_2009, flat_geos=flat_geos, 
                   flat_activity_codes=flat_activity_codes)
# Out:
# Unusual numerical values in column A:
# ['9041', '16,896,952.51']
#
# Unusual numerical values in column A
# ['16,896,952.51']
#
# Unusual numerical values in column B
# ['3', '1']
#
# Unexpected value in column B for states: BUSINESS
# Unexpected value in column C for states: ACTIVITY:A
# Unexpected value in column C for states: ACTIVITY:B
# Unexpected value in column C for states: ACTIVITY:C
# Unexpected value in column C for states: ACTIVITY:D
# Unexpected value in column C for states: ACTIVITY:M
# Unexpected value in column C for states: ACTIVITY:N-U
# Unexpected value in column C for states: BUSINESS
# Checking column B
# Drug codes found in column B:
# ['1100', '1105D', '1205', '1724', '2165', '9041L', '9050', '9064', '9120', '9143', '9150', '9193', '9220L', '9250B', '9300', '9652', '9780', '9737', '9739', '7379', '2885', '9668', '2765', '2783', '9655', '1615', '9273D', '9180L']
# non-numeric values in column B:
# ['PERIOD:' 'Date:' 'BUSINESS' 'NAME' '(SCHEDULE' '(PETHIDINE)' 'POWDERED'
#  'BASE' 'SUMMARY' 'SAMOA' 'HYDROXYBUTYRIC' 'OF' nan 'HAMPSHIRE' '(PCP)'
#  'JERSEY' 'MEXICO' 'YORK' 'CAROLINA' 'DAKOTA' 'RICO' 'ISLAND' 'ISLANDS'
#  'VIRGINIA']
#
# Checking column C
# Drug codes found in column C:
# ['9230', '9639', '9740', '9801', '7471']
# non-numeric values in column C:
# ['ACTIVITY:A' 'DRUG' 'ACTIVITY:B' '-' 'FOR' 'ACTIVITY:C' 'ACTIVITY:D'
#  'ACTIVITY:M' 'ACTIVITY:N-U' 'BUSINESS' 'ACID(FDA' 'COLUMBIA' nan]
#
# Checking column D
# Drug codes found in column D:
# ['2270', '2315', '2125']
# non-numeric values in column D:
# ['TO' nan '-' 'CODE' 'REPORT' 'RETAIL' 'NARCOTIC' 'ACTIVITY:B' 'APPROVED'
#  'BUSINESS' 'ACTIVITY:A' 'ACTIVITY:C' 'ACTIVITY:D' 'ACTIVITY:M'
#  'ACTIVITY:N-U']
#
# Checking column E
# Drug codes found in column E:
# ['2012']
# non-numeric values in column E:
# [nan 'PHARMACIES' 'BUYERS' 'HOSPITALS' 'DRUG' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' '-' 'ACTIVITY:A' 'ACTIVITY:B' 'ACTIVITY:C'
#  'ACTIVITY:D' 'ACTIVITY:N-U' 'NARCOTIC']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'TOTAL' 'PURCHASES' 'INSTITUTIONS' 'PRACTITIONERS' 'PROGRAMS'
#  'HOSPITALS' '-' 'NARCOTIC' 'PHARMACIES' 'TEACHING' 'MID-LEVEL'
#  'TREATMENT']
#
# Checking column G
# No drug codes found.
# non-numeric values in column G:
# [nan 'GRAMS' 'BY' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS' 'TEACHING'
#  'TREATMENT' 'INSTITUTIONS' 'PROGRAMS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'AVG' 'GRAMS' 'INSTITUTIONS']
#
# Checking column RETAIL
# No drug codes found.
# non-numeric values in column RETAIL:
# [nan 'GRAMS' 'WT']
#
# Checking column DRUG
# Null column.
#
# Checking column PURCHASES
# Null column.
#
# Checking column BY
# Null column.
#
# Checking column GRAMS
# Null column.
#
# Checking column WT
# Null column.

# %% [markdown]
# First unusual values to check out:
# * '9041' and '16,896,952.51' in column A - the first looks like a drug code, and the second looks like our recurring wrapped large value problem
# * '3' and '1' in column B - could be page numbers or some other header data

# %%
activity_2009[activity_2009['A']=='9041']
# Out:
#          A  B  C  D    E    F    G  FOR RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 480   9041  1  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 698   9041  1  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 959   9041  1  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 3413  9041  1  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN

# %%
drug_codes['9041']
# Out:
# 'COCAINE'

# %%
activity_2009.iloc[478:482]
# Out:
#             A      B    C       D     E    F    G  FOR RETAIL  DRUG  \
# 478  DIAZEPAM   2765    2       0     0  NaN  NaN  NaN    NaN   NaN
# 479  NABILONE   7379    1    0.02  0.02  NaN  NaN  NaN    NaN   NaN
# 480      9041      1    0       0   NaN  NaN  NaN  NaN    NaN   NaN
# 481   COCAINE  9041L  115  346.73  3.02  NaN  NaN  NaN    NaN   NaN
#
#      PURCHASES  BY  GRAMS  WT
# 478        NaN NaN    NaN NaN
# 479        NaN NaN    NaN NaN
# 480        NaN NaN    NaN NaN
# 481        NaN NaN    NaN NaN

# %%
activity_2009.iloc[957:961]
# Out:
#              A      B   C      D     E    F    G  FOR RETAIL  DRUG  PURCHASES  \
# 957   ZOLPIDEM   2783   5    1.8  0.36  NaN  NaN  NaN    NaN   NaN        NaN
# 958  LORAZEPAM   2885   2    1.2   0.6  NaN  NaN  NaN    NaN   NaN        NaN
# 959       9041      1   0      0   NaN  NaN  NaN  NaN    NaN   NaN        NaN
# 960    COCAINE  9041L  17  33.21  1.95  NaN  NaN  NaN    NaN   NaN        NaN
#
#      BY  GRAMS  WT
# 957 NaN    NaN NaN
# 958 NaN    NaN NaN
# 959 NaN    NaN NaN
# 960 NaN    NaN NaN

# %%
activity_2009.iloc[3411:3415]
# Out:
#                   A          B   C      D     E           F       G  FOR  \
# 3411     BUTALBITAL       2165   1     30    30         NaN     NaN  NaN
# 3412  PENTOBARBITAL  (SCHEDULE  2)   2270   153  133,542.77  872.83  NaN
# 3413           9041          1   0      0   NaN         NaN     NaN  NaN
# 3414        COCAINE      9041L  11  11.43  1.04         NaN     NaN  NaN
#
#      RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 3411    NaN   NaN        NaN NaN    NaN NaN
# 3412    NaN   NaN        NaN NaN    NaN NaN
# 3413    NaN   NaN        NaN NaN    NaN NaN
# 3414    NaN   NaN        NaN NaN    NaN NaN

# %% [markdown]
# This looks to be another case of the dueling cocaine codes. Again since all the rows of data associated with the 9041 code are empty, and aren't following I will just let them drop out of the final data in the cleaning function.

# %%
# next examine what looks like a wrapped value
activity_2009[activity_2009['A']=='16,896,952.51']
# Out:
#                   A    B    C    D    E    F    G  FOR RETAIL  DRUG  \
# 2546  16,896,952.51  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN   NaN
#
#       PURCHASES  BY  GRAMS  WT
# 2546        NaN NaN    NaN NaN

# %%
activity_2009.iloc[2544:2548]
# Out:
#                     A               B         C           D       E    F  \
# 2544  METHYLPHENIDATE            1724     1,229  412,906.88  335.97  NaN
# 2545            GAMMA  HYDROXYBUTYRIC  ACID(FDA    APPROVED    2012    1
# 2546    16,896,952.51             NaN       NaN         NaN     NaN  NaN
# 2547       BUTALBITAL            2165       810      42,270   52.19  NaN
#
#                   G  FOR RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 2544            NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 2545  16,896,952.51  NaN    NaN   NaN        NaN NaN    NaN NaN
# 2546            NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 2547            NaN  NaN    NaN   NaN        NaN NaN    NaN NaN

# %% [markdown]
# Definitely a wrapped value. Even if this occurs in other files it's likely to vary in terms of the column shifts etc. so I'll just do it as a manual fix. No need to worry about row 2546; it will get dropped out by the cleaning function regardless.

# %%
# important that we not have dropped any rows yet 
# so that we can use loc and iloc interchangeably for the indexing here
activity_2009.loc[2545, 'FOR'] = activity_2009.loc[2546, 'A']
activity_2009.iloc[2544:2548]
# Out:
#                     A               B         C           D       E    F  \
# 2544  METHYLPHENIDATE            1724     1,229  412,906.88  335.97  NaN
# 2545            GAMMA  HYDROXYBUTYRIC  ACID(FDA    APPROVED    2012    1
# 2546    16,896,952.51             NaN       NaN         NaN     NaN  NaN
# 2547       BUTALBITAL            2165       810      42,270   52.19  NaN
#
#                   G            FOR RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 2544            NaN            NaN    NaN   NaN        NaN NaN    NaN NaN
# 2545  16,896,952.51  16,896,952.51    NaN   NaN        NaN NaN    NaN NaN
# 2546            NaN            NaN    NaN   NaN        NaN NaN    NaN NaN
# 2547            NaN            NaN    NaN   NaN        NaN NaN    NaN NaN

# %%
activity_2009[activity_2009['B']=='3']
# Out:
#           A  B  C       D  E    F    G  FOR RETAIL  DRUG  PURCHASES  BY  \
# 33    ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 69    ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 97    ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 132   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 168   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 198   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 231   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 267   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 300   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 334   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 369   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 399   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 435   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 471   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 505   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 537   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 573   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 609   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 636   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 672   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 708   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 738   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 774   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 801   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 837   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 872   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 903   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 939   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 975   ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 1002  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# ...     ... .. ..     ... ..  ...  ...  ...    ...   ...        ...  ..
# 4305  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4338  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4374  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4410  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4440  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4476  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4509  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4545  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4575  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4611  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4645  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4674  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4710  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4740  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4770  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4800  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4836  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4872  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4903  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4938  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 4972  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 5004  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 5037  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 5071  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 5103  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 5137  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 5172  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 5203  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 5236  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
# 5271  ARCOS  3  -  REPORT  5  NaN  NaN  NaN    NaN   NaN        NaN NaN
#
#       GRAMS  WT
# 33      NaN NaN
# 69      NaN NaN
# 97      NaN NaN
# 132     NaN NaN
# 168     NaN NaN
# 198     NaN NaN
# 231     NaN NaN
# 267     NaN NaN
# 300     NaN NaN
# 334     NaN NaN
# 369     NaN NaN
# 399     NaN NaN
# 435     NaN NaN
# 471     NaN NaN
# 505     NaN NaN
# 537     NaN NaN
# 573     NaN NaN
# 609     NaN NaN
# 636     NaN NaN
# 672     NaN NaN
# 708     NaN NaN
# 738     NaN NaN
# 774     NaN NaN
# 801     NaN NaN
# 837     NaN NaN
# 872     NaN NaN
# 903     NaN NaN
# 939     NaN NaN
# 975     NaN NaN
# 1002    NaN NaN
# ...     ...  ..
# 4305    NaN NaN
# 4338    NaN NaN
# 4374    NaN NaN
# 4410    NaN NaN
# 4440    NaN NaN
# 4476    NaN NaN
# 4509    NaN NaN
# 4545    NaN NaN
# 4575    NaN NaN
# 4611    NaN NaN
# 4645    NaN NaN
# 4674    NaN NaN
# 4710    NaN NaN
# 4740    NaN NaN
# 4770    NaN NaN
# 4800    NaN NaN
# 4836    NaN NaN
# 4872    NaN NaN
# 4903    NaN NaN
# 4938    NaN NaN
# 4972    NaN NaN
# 5004    NaN NaN
# 5037    NaN NaN
# 5071    NaN NaN
# 5103    NaN NaN
# 5137    NaN NaN
# 5172    NaN NaN
# 5203    NaN NaN
# 5236    NaN NaN
# 5271    NaN NaN
#
# [158 rows x 14 columns]

# %%
activity_2009[activity_2009['B']=='1']
# Out:
#          A  B  C  D    E    F    G  FOR RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 480   9041  1  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 698   9041  1  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 959   9041  1  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 3413  9041  1  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN

# %% [markdown]
# Now we can clean the file; after cleaning you can verify that the problematic rows were dropped.

# %%
activity_2009 = clean_activity_new(activity_2009, year=2009, 
                                   drug_codes=drug_codes, flat_geos=flat_geos, 
                                   activity_codes=activity_codes)
activity_2009.head()
# Out:
#    Year    State Business Activity               Drug  Registrants  \
# 4  2009  ALABAMA        PHARMACIES        AMPHETAMINE         1251
# 5  2009  ALABAMA        PHARMACIES  D-METHAMPHETAMINE           41
# 6  2009  ALABAMA        PHARMACIES   LISDEXAMFETAMINE         1204
# 7  2009  ALABAMA        PHARMACIES    METHYLPHENIDATE         1259
# 8  2009  ALABAMA        PHARMACIES         BUTALBITAL          775
#
#    Total grams sold  Avg grams/registrant
# 4         259801.90                207.68
# 5            196.83                  4.80
# 6         121313.71                100.76
# 7         263010.46                208.90
# 8          30270.00                 39.06

# %%
# uncomment to see that the rows with irregular data were dropped
# now we use loc; using iloc will return a row that's now in that index position
# the row that used to have both the index location and index name will now be gone
# and each of these will return a KeyError

#activity_2009.loc[480]
#activity_2009.loc[698]
#activity_2009.loc[959]
#activity_2009.loc[3413]
#activity_2009.loc[2546]

# %%
activity_2010 = pd.read_csv('activity_2010.txt', delim_whitespace=True)
check_activity_new(activity_2010, flat_geos=flat_geos, 
                   flat_activity_codes=flat_activity_codes)
# Out:
# Unusual numerical values in column A:
# ['9041', '4-HYDROXY-3-METHOXY-METHAMPHETAMINE(H', '16,120,104.19']
#
# Unusual numerical values in column A
# ['4-HYDROXY-3-METHOXY-METHAMPHETAMINE(H', '16,120,104.19']
#
# Unusual numerical values in column B
# ['3', '1']
#
# Unexpected value in column B for states: BUSINESS
# Unexpected value in column C for states: ACTIVITY:A
# Unexpected value in column C for states: ACTIVITY:B
# Unexpected value in column C for states: ACTIVITY:C
# Unexpected value in column C for states: ACTIVITY:D
# Unexpected value in column C for states: ACTIVITY:M
# Unexpected value in column C for states: ACTIVITY:N-U
# Unexpected value in column C for states: BUSINESS
# Checking column B
# Drug codes found in column B:
# ['1100', '1105D', '1205', '1724', '2165', '7379', '9041L', '9050', '9064', '9120', '9143', '9150', '9193', '9220L', '9250B', '9300', '9652', '9739', '9780', '9737', '2783', '1615', '9041', '9190', '9655', '7444', '9180L', '9273D', '2885', '9743']
# non-numeric values in column B:
# ['PERIOD:' 'Date:' 'BUSINESS' 'NAME' 'RACEMIC' '(SCHEDULE' '(PETHIDINE)'
#  'POWDERED' 'BASE' 'SUMMARY' 'SAMOA' 'HYDROXYBUTYRIC' 'OF' nan '(PCP)'
#  'HAMPSHIRE' 'JERSEY' 'MEXICO' 'YORK' 'CAROLINA' 'DAKOTA' 'RICO' 'ISLAND'
#  'ISLANDS' 'VIRGINIA']
#
# Checking column C
# Drug codes found in column C:
# ['9230', '9639', '9740', '9801', '7471']
# non-numeric values in column C:
# ['ACTIVITY:A' 'DRUG' 'BASE' 'ACTIVITY:B' '-' 'FOR' 'ACTIVITY:C'
#  'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' 'BUSINESS' 'ACID(FDA' 'POPPY'
#  'COLUMBIA' nan]
#
# Checking column D
# Drug codes found in column D:
# ['1105B', '2270', '2315', '2125']
# non-numeric values in column D:
# ['TO' nan '-' 'CODE' 'REPORT' 'RETAIL' 'NARCOTIC' 'ACTIVITY:B' 'APPROVED'
#  'STRAW' 'BUSINESS' 'ACTIVITY:A' 'ACTIVITY:C' 'ACTIVITY:M' 'ACTIVITY:N-U'
#  'ACTIVITY:D']
#
# Checking column E
# Drug codes found in column E:
# ['2012', '9670']
# non-numeric values in column E:
# [nan 'PHARMACIES' 'BUYERS' 'HOSPITALS' 'DRUG' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' '-' 'ACTIVITY:A' 'ACTIVITY:B' 'ACTIVITY:C'
#  'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' 'NARCOTIC']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'TOTAL' 'PURCHASES' 'INSTITUTIONS' 'PRACTITIONERS' 'PROGRAMS'
#  'HOSPITALS' '-' 'NARCOTIC' 'PHARMACIES' 'MID-LEVEL' 'TREATMENT'
#  'TEACHING']
#
# Checking column G
# No drug codes found.
# non-numeric values in column G:
# [nan 'GRAMS' 'BY' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' 'PROGRAMS' 'INSTITUTIONS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'AVG' 'GRAMS' 'INSTITUTIONS' 'PRACTITIONERS']
#
# Checking column RETAIL
# No drug codes found.
# non-numeric values in column RETAIL:
# [nan 'GRAMS' 'WT']
#
# Checking column DRUG
# Null column.
#
# Checking column PURCHASES
# Null column.
#
# Checking column BY
# Null column.
#
# Checking column GRAMS
# Null column.
#
# Checking column WT
# Null column.

# %% [markdown]
# Similar story here with some values to check:
#
# * '9041' and '16,120,104.19' in column A
# * '3' and '1' in column B

# %%
activity_2010[activity_2010['A']=='9041']
# Out:
#         A  B  C  D    E    F    G  FOR RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 920  9041  1  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN

# %%
activity_2010.iloc[918:922]
# Out:
#                  A          B    C         D     E          F       G  FOR  \
# 918  PENTOBARBITAL  (SCHEDULE   2)      2270    77  21,916.80  284.63  NaN
# 919   SECOBARBITAL  (SCHEDULE   2)      2315     1      18.31   18.31  NaN
# 920           9041          1    0         0   NaN        NaN     NaN  NaN
# 921        COCAINE      9041L  256  2,023.73  7.91        NaN     NaN  NaN
#
#     RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 918    NaN   NaN        NaN NaN    NaN NaN
# 919    NaN   NaN        NaN NaN    NaN NaN
# 920    NaN   NaN        NaN NaN    NaN NaN
# 921    NaN   NaN        NaN NaN    NaN NaN

# %% [markdown]
# Another 9041 cocaine entry that's empty; as before we'll let it drop in the cleaning step.

# %%
activity_2010[activity_2010['A']=='16,120,104.19']
# Out:
#                   A    B    C    D    E    F    G  FOR RETAIL  DRUG  \
# 2539  16,120,104.19  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN   NaN
#
#       PURCHASES  BY  GRAMS  WT
# 2539        NaN NaN    NaN NaN

# %%
activity_2010.iloc[2537:2541]
# Out:
#                     A               B         C           D       E     F  \
# 2537  METHYLPHENIDATE            1724     1,214  446,324.88  367.65   NaN
# 2538            GAMMA  HYDROXYBUTYRIC  ACID(FDA    APPROVED    2012     1
# 2539    16,120,104.19             NaN       NaN         NaN     NaN   NaN
# 2540      AMOBARBITAL       (SCHEDULE        2)        2125       1  0.46
#
#                   G  FOR RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 2537            NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 2538  16,120,104.19  NaN    NaN   NaN        NaN NaN    NaN NaN
# 2539            NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 2540           0.46  NaN    NaN   NaN        NaN NaN    NaN NaN

# %%
# same fix as before
# again remember you can only do it this way if you have not dropped any rows yet 
# so that we can use loc and iloc interchangeably for the indexing here
# row 2539 will get dropped in the cleaning
activity_2010.loc[2538, 'FOR'] = activity_2010.loc[2539, 'A']
activity_2010.iloc[2537:2540]
# Out:
#                     A               B         C           D       E    F  \
# 2537  METHYLPHENIDATE            1724     1,214  446,324.88  367.65  NaN
# 2538            GAMMA  HYDROXYBUTYRIC  ACID(FDA    APPROVED    2012    1
# 2539    16,120,104.19             NaN       NaN         NaN     NaN  NaN
#
#                   G            FOR RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 2537            NaN            NaN    NaN   NaN        NaN NaN    NaN NaN
# 2538  16,120,104.19  16,120,104.19    NaN   NaN        NaN NaN    NaN NaN
# 2539            NaN            NaN    NaN   NaN        NaN NaN    NaN NaN

# %%
# this is just header data
#activity_2010[activity_2010['B']=='3'].head()

# %%
# this is the cocaine 9041 row
#activity_2010[activity_2010['B']=='1']

# %%
activity_2010 = clean_activity_new(activity_2010, year=2010, 
                                   drug_codes=drug_codes, flat_geos=flat_geos, 
                                   activity_codes=activity_codes)
activity_2010.head()
# Out:
#    Year    State Business Activity                             Drug  \
# 4  2010  ALABAMA        PHARMACIES                      AMPHETAMINE
# 5  2010  ALABAMA        PHARMACIES  DL-METHAMPHETAMINE RACEMIC BASE
# 6  2010  ALABAMA        PHARMACIES                D-METHAMPHETAMINE
# 7  2010  ALABAMA        PHARMACIES                 LISDEXAMFETAMINE
# 8  2010  ALABAMA        PHARMACIES                  METHYLPHENIDATE
#
#    Registrants  Total grams sold  Avg grams/registrant
# 4         1259         295394.90                234.63
# 5           31             85.59                  2.76
# 6           35            161.89                  4.63
# 7         1219         153102.27                125.60
# 8         1264         268138.96                212.14

# %%
# uncomment to check that the irregular rows were dropped if you like
#activity_2010.loc[2539]
#activity_2010.loc[920]

# %%
activity_2011 = pd.read_csv('activity_2011.txt', delim_whitespace=True)
check_activity_new(activity_2011, flat_geos=flat_geos, 
                   flat_activity_codes=flat_activity_codes)
# Out:
# Unusual numerical values in column A:
# ['17,577,800.06', '9041']
#
# Unusual numerical values in column A
# ['17,577,800.06']
#
# Unusual numerical values in column B
# ['3', '2', '1', '9']
#
# Unexpected value in column B for states: BUSINESS
# Unexpected value in column C for states: ACTIVITY:A
# Unexpected value in column C for states: ACTIVITY:B
# Unexpected value in column C for states: ACTIVITY:C
# Unexpected value in column C for states: ACTIVITY:D
# Unexpected value in column C for states: ACTIVITY:M
# Unexpected value in column C for states: ACTIVITY:N-U
# Unexpected value in column C for states: BUSINESS
# Checking column B
# Drug codes found in column B:
# ['1100', '1105D', '1205', '1724', '2165', '7379', '9041L', '9050', '9064', '9120', '9143', '9150', '9193', '9220L', '9250B', '9300', '9652', '9780', '9737', '9739', '9041', '9668', '1615', '9600', '2783', '2885', '9743', '9046']
# non-numeric values in column B:
# ['PERIOD:' 'Date:' 'BUSINESS' 'NAME' 'RACEMIC' '(SCHEDULE' '(PETHIDINE)'
#  'POWDERED' 'BASE' 'SUMMARY' 'SAMOA' 'TINCTURE' 'OF' nan '(PCP)'
#  'HYDROXYBUTYRIC' 'HAMPSHIRE' 'JERSEY' 'MEXICO' 'YORK' 'CAROLINA' 'DAKOTA'
#  'RICO' 'ISLAND' 'ISLANDS' 'VIRGINIA']
#
# Checking column C
# Drug codes found in column C:
# ['9230', '9639', '9740', '9801', '9630', '7471']
# non-numeric values in column C:
# ['ACTIVITY:A' 'DRUG' 'BASE' 'ACTIVITY:B' '-' 'FOR' 'ACTIVITY:C'
#  'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' 'BUSINESS' 'COLUMBIA' nan
#  'ACID(FDA']
#
# Checking column D
# Drug codes found in column D:
# ['1105B', '2270', '2315', '2125']
# non-numeric values in column D:
# ['TO' nan '-' 'CODE' 'REPORT' 'RETAIL' 'NARCOTIC' 'ACTIVITY:B' 'BUSINESS'
#  'APPRO' 'ACTIVITY:A' 'ACTIVITY:C' 'ACTIVITY:D' 'ACTIVITY:M'
#  'ACTIVITY:N-U']
#
# Checking column E
# Drug codes found in column E:
# ['2012']
# non-numeric values in column E:
# [nan 'PHARMACIES' 'BUYERS' 'HOSPITALS' 'DRUG' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' '-' 'ACTIVITY:A' 'ACTIVITY:B' 'ACTIVITY:C'
#  'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' 'NARCOTIC']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'TOTAL' 'PURCHASES' 'INSTITUTIONS' 'PRACTITIONERS' 'PROGRAMS'
#  'HOSPITALS' '-' 'NARCOTIC' 'PHARMACIES' 'TEACHING' 'MID-LEVEL'
#  'TREATMENT']
#
# Checking column G
# No drug codes found.
# non-numeric values in column G:
# [nan 'GRAMS' 'BY' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' 'INSTITUTIONS' 'PROGRAMS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'AVG' 'GRAMS' 'INSTITUTIONS' 'PRACTITIONERS']
#
# Checking column RETAIL
# No drug codes found.
# non-numeric values in column RETAIL:
# [nan 'GRAMS' 'WT']
#
# Checking column DRUG
# Null column.
#
# Checking column PURCHASES
# Null column.
#
# Checking column BY
# Null column.
#
# Checking column GRAMS
# Null column.
#
# Checking column WT
# Null column.

# %% [markdown]
# To check out:
# * '17,577,800.06' and '9041' in column A (seeing a pattern yet...?)
# * '3', '2', '1', '9' in column B

# %%
activity_2011[activity_2011['A']=='17,577,800.06']
# Out:
#                   A    B    C    D    E    F    G  FOR RETAIL  DRUG  \
# 2539  17,577,800.06  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN   NaN
#
#       PURCHASES  BY  GRAMS  WT
# 2539        NaN NaN    NaN NaN

# %%
activity_2011.iloc[2537:2541]
# Out:
#                     A               B         C           D       E    F  \
# 2537  METHYLPHENIDATE            1724     1,209  571,305.10  472.54  NaN
# 2538            GAMMA  HYDROXYBUTYRIC  ACID(FDA       APPRO    2012    1
# 2539    17,577,800.06             NaN       NaN         NaN     NaN  NaN
# 2540       BUTALBITAL            2165       883      61,075   69.17  NaN
#
#                   G  FOR RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 2537            NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 2538  17,577,800.06  NaN    NaN   NaN        NaN NaN    NaN NaN
# 2539            NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 2540            NaN  NaN    NaN   NaN        NaN NaN    NaN NaN

# %%
# fix this one as before and let it drop in the cleaning
activity_2011.loc[2538, 'FOR'] = activity_2011.loc[2539, 'A']
activity_2011.iloc[2537:2541]
# Out:
#                     A               B         C           D       E    F  \
# 2537  METHYLPHENIDATE            1724     1,209  571,305.10  472.54  NaN
# 2538            GAMMA  HYDROXYBUTYRIC  ACID(FDA       APPRO    2012    1
# 2539    17,577,800.06             NaN       NaN         NaN     NaN  NaN
# 2540       BUTALBITAL            2165       883      61,075   69.17  NaN
#
#                   G            FOR RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 2537            NaN            NaN    NaN   NaN        NaN NaN    NaN NaN
# 2538  17,577,800.06  17,577,800.06    NaN   NaN        NaN NaN    NaN NaN
# 2539            NaN            NaN    NaN   NaN        NaN NaN    NaN NaN
# 2540            NaN            NaN    NaN   NaN        NaN NaN    NaN NaN

# %%
activity_2011[activity_2011['A']=='9041']
# Out:
#          A  B  C  D    E    F    G  FOR RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 2573  9041  2  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 2989  9041  1  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 3054  9041  9  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 4334  9041  2  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 4815  9041  1  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN

# %% [markdown]
# More 9041 cocaine data - however these look a little different because they've got more than 1 registrant associated. Still, they all end up being blank, so we'll continue to let them drop.

# %%
# uncomment to see the surrounding data for each of the rows
#activity_2011.iloc[2572:2575]
#activity_2011.iloc[2988:2991]
#activity_2011.iloc[3053:3056]
#activity_2011.iloc[4333:4336]
#activity_2011.iloc[4814:4817]

# %%
# this is header data
#activity_2011[activity_2011['B']=='3']

# %%
# these are all rows from the 9041 cocaine data

#activity_2011[activity_2011['B']=='2']
#activity_2011[activity_2011['B']=='1']
#activity_2011[activity_2011['B']=='9']

# %%
activity_2011 = clean_activity_new(activity_2011, year=2011, 
                                   drug_codes=drug_codes, flat_geos=flat_geos, 
                                   activity_codes=activity_codes)
activity_2011.head()
# Out:
#    Year    State Business Activity                             Drug  \
# 4  2011  ALABAMA        PHARMACIES                      AMPHETAMINE
# 5  2011  ALABAMA        PHARMACIES  DL-METHAMPHETAMINE RACEMIC BASE
# 6  2011  ALABAMA        PHARMACIES                D-METHAMPHETAMINE
# 7  2011  ALABAMA        PHARMACIES                 LISDEXAMFETAMINE
# 8  2011  ALABAMA        PHARMACIES                  METHYLPHENIDATE
#
#    Registrants  Total grams sold  Avg grams/registrant
# 4         1273         328351.81                257.94
# 5           39            154.31                  3.96
# 6           16             73.91                  4.62
# 7         1242         188868.16                152.07
# 8         1271         285745.75                224.82

# %%
# uncomment to verify the dropped rows

#activity_2011.loc[2539]
#activity_2011.loc[2573]
#activity_2011.loc[2989]
#activity_2011.loc[3054]
#activity_2011.loc[4334]
#activity_2011.loc[4815]

# %%
activity_2012 = pd.read_csv('activity_2012.txt', delim_whitespace=True)
check_activity_new(activity_2012, flat_geos=flat_geos, 
                   flat_activity_codes=flat_activity_codes)
# Out:
# Unusual numerical values in column A:
# ['5-METHOXY-N,N', '5-METHOXY-N,N-DIISOPROPYLTRYPTAMINE(5-M', '9041']
#
# Unusual numerical values in column A
# ['5-METHOXY-N,N', '5-METHOXY-N,N-DIISOPROPYLTRYPTAMINE(5-M']
#
# Unusual numerical values in column B
# ['3', '4-METHOXYMETHCATHINONE;ME', '2']
#
# Unexpected value in column B for states: BUSINESS
# Unexpected value in column C for states: ACTIVITY:A
# Unexpected value in column C for states: ACTIVITY:B
# Unexpected value in column C for states: ACTIVITY:C
# Unexpected value in column C for states: ACTIVITY:D
# Unexpected value in column C for states: ACTIVITY:M
# Unexpected value in column C for states: ACTIVITY:N-U
# Unexpected value in column C for states: BUSINESS
# Checking column B
# Drug codes found in column B:
# ['1100', '1105D', '1205', '1724', '2165', '7379', '9041L', '9050', '9064', '9120', '9143', '9150', '9193', '9220L', '9250B', '9300', '9652', '9737', '9780', '9739', '9041', '9668', '9743', '7439', '7438', '7370', '1615', '9200', '9056']
# non-numeric values in column B:
# ['PERIOD:' 'Date:' 'BUSINESS' 'NAME' 'RACEMIC' '(SCHEDULE' '(PETHIDINE)'
#  'POWDERED' 'BASE' 'SUMMARY' 'SAMOA' 'OF' '(3,4-METHYLENEDIOXY-N-METHYLC'
#  'TINCTURE' '(PCP)' nan 'DIMETHYLTRYPTAMINE' 'HYDROXYBUTYRIC' 'HAMPSHIRE'
#  'JERSEY' 'MEXICO' 'YORK' 'CAROLINA' 'DAKOTA' 'RICO' 'ISLAND' 'ISLANDS'
#  'VIRGINIA']
#
# Checking column C
# Drug codes found in column C:
# ['9230', '9639', '9740', '9801', '7540', '9630', '7471', '1248', '7431']
# non-numeric values in column C:
# ['ACTIVITY:A' 'DRUG' 'BASE' 'ACTIVITY:B' '-' 'FOR' 'ACTIVITY:C'
#  'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' 'BUSINESS' 'POPPY' 'COLUMBIA'
#  nan 'ACID(FDA']
#
# Checking column D
# Drug codes found in column D:
# ['1105B', '2270', '2315', '2125']
# non-numeric values in column D:
# ['TO' nan '-' 'CODE' 'REPORT' 'RETAIL' 'NARCOTIC' 'ACTIVITY:B' 'STRAW'
#  'BUSINESS' 'APPROVED' 'ACTIVITY:A' 'ACTIVITY:C' 'ACTIVITY:M'
#  'ACTIVITY:N-U' 'ACTIVITY:D']
#
# Checking column E
# Drug codes found in column E:
# ['9670', '2012']
# non-numeric values in column E:
# [nan 'PHARMACIES' 'BUYERS' 'HOSPITALS' 'DRUG' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' '-' 'ACTIVITY:A' 'ACTIVITY:B' 'ACTIVITY:C'
#  'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' 'NARCOTIC']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'TOTAL' 'PURCHASES' 'INSTITUTIONS' 'PRACTITIONERS' 'PROGRAMS'
#  'HOSPITALS' '-' 'NARCOTIC' 'PHARMACIES' 'MID-LEVEL' 'TREATMENT'
#  'TEACHING']
#
# Checking column G
# No drug codes found.
# non-numeric values in column G:
# [nan 'GRAMS' 'BY' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' 'PROGRAMS' 'INSTITUTIONS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'AVG' 'GRAMS' 'INSTITUTIONS' 'PRACTITIONERS']
#
# Checking column RETAIL
# No drug codes found.
# non-numeric values in column RETAIL:
# [nan 'GRAMS' 'WT']
#
# Checking column DRUG
# Null column.
#
# Checking column PURCHASES
# Null column.
#
# Checking column BY
# Null column.
#
# Checking column GRAMS
# Null column.
#
# Checking column WT
# Null column.

# %% [markdown]
# Just some more of the usual suspects to check:
# * '9041' in column A
# * '3', '2' in column B

# %%
activity_2012[activity_2012['A']=='9041']
# Out:
#          A  B  C  D    E    F    G  FOR RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 3518  9041  3  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN
# 3938  9041  2  0  0  NaN  NaN  NaN  NaN    NaN   NaN        NaN NaN    NaN NaN

# %%
activity_2012.iloc[3517:3520]
# Out:
#              A      B  C     D     E    F    G  FOR RETAIL  DRUG  PURCHASES  \
# 3517  PSILOCIN   7438  1  0.01  0.01  NaN  NaN  NaN    NaN   NaN        NaN
# 3518      9041      3  0     0   NaN  NaN  NaN  NaN    NaN   NaN        NaN
# 3519   COCAINE  9041L  4  7.04  1.76  NaN  NaN  NaN    NaN   NaN        NaN
#
#       BY  GRAMS  WT
# 3517 NaN    NaN NaN
# 3518 NaN    NaN NaN
# 3519 NaN    NaN NaN

# %%
activity_2012.iloc[3937:3940]
# Out:
#                   A          B   C     D     E          F         G  FOR  \
# 3937  PENTOBARBITAL  (SCHEDULE  2)  2270     4  13,240.82  3,310.20  NaN
# 3938           9041          2   0     0   NaN        NaN       NaN  NaN
# 3939        CODEINE       9050   1  4.42  4.42        NaN       NaN  NaN
#
#      RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 3937    NaN   NaN        NaN NaN    NaN NaN
# 3938    NaN   NaN        NaN NaN    NaN NaN
# 3939    NaN   NaN        NaN NaN    NaN NaN

# %% [markdown]
# This is a little unusual in that we don't see an entry for 9041L cocaine, which is the one that usually has data associated. However, these are still empty rows, so we will let them drop.

# %%
# this is header data
#activity_2012[activity_2012['B']=='3']

# this is the 9041 cocaine row
#activity_2012[activity_2012['B']=='2']

# %%
activity_2012 = clean_activity_new(activity_2012, year=2012, 
                                   drug_codes=drug_codes, flat_geos=flat_geos, 
                                   activity_codes=activity_codes)
activity_2012.head()
# Out:
#    Year    State Business Activity                             Drug  \
# 4  2012  ALABAMA        PHARMACIES                      AMPHETAMINE
# 5  2012  ALABAMA        PHARMACIES  DL-METHAMPHETAMINE RACEMIC BASE
# 6  2012  ALABAMA        PHARMACIES                D-METHAMPHETAMINE
# 7  2012  ALABAMA        PHARMACIES                 LISDEXAMFETAMINE
# 8  2012  ALABAMA        PHARMACIES                  METHYLPHENIDATE
#
#    Registrants  Total grams sold  Avg grams/registrant
# 4         1308         374199.35                286.09
# 5           36            188.47                  5.24
# 6            6             29.32                  4.89
# 7         1277         222824.02                174.49
# 8         1304         292500.10                224.31

# %%
# uncomment to verify the dropped rows
#activity_2012.loc[3938]
#activity_2012.loc[3518]

# %%
activity_2013 = pd.read_csv('activity_2013.txt', delim_whitespace=True)
check_activity_new(activity_2013, flat_geos=flat_geos, 
                   flat_activity_codes=flat_activity_codes)
# Out:
# Unusual numerical values in column A:
# ['9041']
#
# Unusual numerical values in column B
# ['3', '1', '8', '32', '2', '11', '9', '4']
#
# Unexpected value in column B for states: BUSINESS
# Unexpected value in column C for states: ACTIVITY:A
# Unexpected value in column C for states: ACTIVITY:B
# Unexpected value in column C for states: ACTIVITY:C
# Unexpected value in column C for states: ACTIVITY:D
# Unexpected value in column C for states: ACTIVITY:M
# Unexpected value in column C for states: ACTIVITY:N-U
# Unexpected value in column C for states: BUSINESS
# Checking column B
# Drug codes found in column B:
# ['1100', '1105D', '1205', '2165', '4187', '9041L', '9050', '9064', '9120', '9143', '9150', '9193', '9220L', '9250B', '9300', '9652', '9780', '9041', '9737', '9739', '7379', '9668', '1615', '9056', '9743']
# non-numeric values in column B:
# ['PERIOD:' 'Date:' 'BUSINESS' 'NAME' 'RACEMIC' '(DL;D;L;ISOMERS)'
#  '(SCHEDULE' '(PETHIDINE)' 'POWDERED' 'BASE' 'SAMOA' 'OF' '(PCP)' nan
#  'HYDROXYBUTYRIC' 'HAMPSHIRE' 'JERSEY' 'MEXICO' 'YORK' 'CAROLINA' 'DAKOTA'
#  'RICO' 'ISLAND' 'ISLANDS' 'VIRGINIA']
#
# Checking column C
# Drug codes found in column C:
# ['1724', '9230', '9639', '9740', '9801', '7471']
# non-numeric values in column C:
# ['ACTIVITY:A' 'DRUG' 'BASE' 'ACTIVITY:B' '-' 'ACTIVITY:C' 'ACTIVITY:D'
#  'ACTIVITY:M' 'ACTIVITY:N-U' 'BUSINESS' 'POPPY' 'COLUMBIA' nan 'ACID(FDA']
#
# Checking column D
# Drug codes found in column D:
# ['1105B', '2270', '2315', '2125']
# non-numeric values in column D:
# ['TO' nan '-' 'CODE' 'REPORT' 'NARCOTIC' 'ACTIVITY:B' 'STRAW' 'BUSINESS'
#  'APPROVED' 'ACTIVITY:A' 'ACTIVITY:C' 'ACTIVITY:M' 'ACTIVITY:N-U'
#  'ACTIVITY:D']
#
# Checking column E
# Drug codes found in column E:
# ['9670', '2012']
# non-numeric values in column E:
# [nan 'PHARMACIES' 'BUYERS' 'HOSPITALS' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' '-' 'ACTIVITY:A' 'ACTIVITY:B' 'ACTIVITY:C'
#  'ACTIVITY:M' 'ACTIVITY:N-U' 'NARCOTIC']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'TOTAL' 'STATISTICAL' 'INSTITUTIONS' 'PRACTITIONERS' 'PROGRAMS'
#  'HOSPITALS' '-' 'NARCOTIC' 'PHARMACIES' 'MID-LEVEL' 'TREATMENT'
#  'TEACHING']
#
# Checking column G
# No drug codes found.
# non-numeric values in column G:
# [nan 'GRAMS' 'SUMMARY' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS'
#  'MID-LEVEL' 'TREATMENT' 'PROGRAMS' 'INSTITUTIONS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'AVG' 'FOR' 'PRACTITIONERS']
#
# Checking column RETAIL
# No drug codes found.
# non-numeric values in column RETAIL:
# [nan 'GRAMS' 'RETAIL']
#
# Checking column DRUG
# No drug codes found.
# non-numeric values in column DRUG:
# [nan 'DRUG']
#
# Checking column PURCHASES
# No drug codes found.
# non-numeric values in column PURCHASES:
# [nan 'PURCHASES']
#
# Checking column BY
# No drug codes found.
# non-numeric values in column BY:
# [nan 'BY']
#
# Checking column GRAMS
# No drug codes found.
# non-numeric values in column GRAMS:
# [nan 'GRAMS']
#
# Checking column WT
# No drug codes found.
# non-numeric values in column WT:
# [nan 'WT']

# %% [markdown]
# To check:
#
# * '9041' in column A
# * '3', '1', '8', '32', '2', '11', '9', '4' in column B

# %%
activity_2013[activity_2013['A']=='9041']
# Out:
#          A   B  C  D    E    F    G  FOR RETAIL DRUG PURCHASES   BY GRAMS   WT
# 65    9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 340   9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 748   9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 824   9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 2696  9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 2723  9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3168  9041   8  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3198  9041  32  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3285  9041   2  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3309  9041   3  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3467  9041  11  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3494  9041   3  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3583  9041   3  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3688  9041   2  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3711  9041   2  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 4036  9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 4061  9041   3  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 4219  9041   9  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 4247  9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 4887  9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 4909  9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 5003  9041   4  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN

# %% [markdown]
# So many 9041 rows! Uncomment below to see the surrounding data for each.

# %%
#activity_2013.iloc[64:67]
#activity_2013.iloc[339:342]
#activity_2013.iloc[747:750]
#activity_2013.iloc[823:826]
#activity_2013.iloc[2695:2698]
#activity_2013.iloc[2722:2725]
#activity_2013.iloc[3167:3170]
#activity_2013.iloc[3197:3200]
#activity_2013.iloc[3284:3287]
#activity_2013.iloc[3308:3311]
#activity_2013.iloc[3466:3469]
#activity_2013.iloc[3466:3469]
#activity_2013.iloc[3493:3496]
#activity_2013.iloc[3582:3585]
#activity_2013.iloc[3687:3690]
#activity_2013.iloc[3710:3713]
#activity_2013.iloc[4035:4038]
#activity_2013.iloc[4060:4063]
#activity_2013.iloc[4218:4221]
#activity_2013.iloc[4246:4249]
#activity_2013.iloc[4886:4889]
#activity_2013.iloc[4908:4911]
#activity_2013.iloc[5002:5005]

# %%
# this is header data
#activity_2013[activity_2013['B']=='3']

# these are all 9041 rows
#activity_2013[activity_2013['B']=='1']
#activity_2013[activity_2013['B']=='8']
#activity_2013[activity_2013['B']=='32']
#activity_2013[activity_2013['B']=='2']
#activity_2013[activity_2013['B']=='11']
#activity_2013[activity_2013['B']=='9']
#activity_2013[activity_2013['B']=='4']

# %%
activity_2013 = clean_activity_new(activity_2013, year=2013, 
                                   drug_codes=drug_codes, flat_geos=flat_geos, 
                                   activity_codes=activity_codes)
activity_2013.head()
# Out:
#    Year    State Business Activity                             Drug  \
# 4  2013  ALABAMA        PHARMACIES                      AMPHETAMINE
# 5  2013  ALABAMA        PHARMACIES  DL-METHAMPHETAMINE RACEMIC BASE
# 6  2013  ALABAMA        PHARMACIES                D-METHAMPHETAMINE
# 7  2013  ALABAMA        PHARMACIES                 LISDEXAMFETAMINE
# 8  2013  ALABAMA        PHARMACIES                  METHYLPHENIDATE
#
#    Registrants  Total grams sold  Avg grams/registrant
# 4         1319         399689.13                303.02
# 5           39            165.16                  4.23
# 6            5             16.07                  3.21
# 7         1292         234639.23                181.61
# 8         1315         277243.00                210.83

# %%
# verify that the rows have been dropped

#activity_2013.loc[65]
#activity_2013.loc[340]
#activity_2013.loc[748]
#activity_2013.loc[824]
#activity_2013.loc[2696]
#activity_2013.loc[2723]
#activity_2013.loc[3168]
#activity_2013.loc[3198]
#activity_2013.loc[3285]
#activity_2013.loc[3309]
#activity_2013.loc[3467]
#activity_2013.loc[3494]
#activity_2013.loc[3583]
#activity_2013.loc[3688]
#activity_2013.loc[3711]
#activity_2013.loc[4036]
#activity_2013.loc[4061]
#activity_2013.loc[4219]
#activity_2013.loc[4247]
#activity_2013.loc[4887]
#activity_2013.loc[4909]
#activity_2013.loc[5003]

# %%
activity_2014 = pd.read_csv('activity_2014.txt', delim_whitespace=True)
check_activity_new(activity_2014, flat_geos=flat_geos, 
                   flat_activity_codes=flat_activity_codes)
# Out:
# Unusual numerical values in column A:
# ['9041']
#
# Unusual numerical values in column B
# ['3', '1', '18', '5', '4', '2', '16', '13']
#
# Unexpected value in column B for states: BUSINESS
# Unexpected value in column C for states: ACTIVITY:A
# Unexpected value in column C for states: ACTIVITY:B
# Unexpected value in column C for states: ACTIVITY:C
# Unexpected value in column C for states: ACTIVITY:D
# Unexpected value in column C for states: ACTIVITY:M
# Unexpected value in column C for states: ACTIVITY:N-U
# Unexpected value in column C for states: BUSINESS
# Checking column B
# Drug codes found in column B:
# ['1100', '1105D', '1205', '2165', '7379', '9041L', '9050', '9064', '9120', '9143', '9150', '9193', '9220L', '9250B', '9300', '9652', '9780', '9737', '9739', '9668', '9041', '9743', '9170']
# non-numeric values in column B:
# ['PERIOD:' 'Date:' 'BUSINESS' 'NAME' 'RACEMIC' '(DL;D;L;ISOMERS)'
#  '(SCHEDULE' '(PETHIDINE)' 'POWDERED' 'BASE' 'HYDROXYBUTYRIC' 'SAMOA' 'OF'
#  nan 'HAMPSHIRE' 'JERSEY' 'MEXICO' 'YORK' 'CAROLINA' 'DAKOTA' 'RICO'
#  'ISLAND' 'ISLANDS' 'VIRGINIA']
#
# Checking column C
# Drug codes found in column C:
# ['1724', '9230', '9639', '9801', '9740']
# non-numeric values in column C:
# ['ACTIVITY:A' 'DRUG' 'BASE' 'ACTIVITY:B' 'ACID(FDA' '-' 'ACTIVITY:C'
#  'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' 'BUSINESS' 'COLUMBIA' nan]
#
# Checking column D
# Drug codes found in column D:
# ['1105B', '2315', '2125', '2270']
# non-numeric values in column D:
# ['TO' nan '-' 'CODE' 'APPROVED' 'REPORT' 'NARCOTIC' 'ACTIVITY:B'
#  'BUSINESS' 'ACTIVITY:A' 'ACTIVITY:C' 'ACTIVITY:M' 'ACTIVITY:N-U'
#  'ACTIVITY:D']
#
# Checking column E
# Drug codes found in column E:
# ['2012']
# non-numeric values in column E:
# [nan 'PHARMACIES' 'BUYERS' 'HOSPITALS' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' '-' 'ACTIVITY:A' 'ACTIVITY:B' 'ACTIVITY:C'
#  'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' 'NARCOTIC']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'TOTAL' 'STATISTICAL' 'INSTITUTIONS' 'PRACTITIONERS' 'PROGRAMS'
#  'HOSPITALS' '-' 'NARCOTIC' 'PHARMACIES' 'MID-LEVEL' 'TREATMENT'
#  'TEACHING']
#
# Checking column G
# No drug codes found.
# non-numeric values in column G:
# [nan 'GRAMS' 'SUMMARY' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' 'PROGRAMS' 'INSTITUTIONS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'AVG' 'FOR' 'INSTITUTIONS' 'PRACTITIONERS']
#
# Checking column RETAIL
# No drug codes found.
# non-numeric values in column RETAIL:
# [nan 'GRAMS' 'RETAIL']
#
# Checking column DRUG
# No drug codes found.
# non-numeric values in column DRUG:
# [nan 'DRUG']
#
# Checking column PURCHASES
# No drug codes found.
# non-numeric values in column PURCHASES:
# [nan 'PURCHASES']
#
# Checking column BY
# No drug codes found.
# non-numeric values in column BY:
# [nan 'BY']
#
# Checking column GRAMS
# No drug codes found.
# non-numeric values in column GRAMS:
# [nan 'GRAMS']
#
# Checking column WT
# No drug codes found.
# non-numeric values in column WT:
# [nan 'WT']

# %% [markdown]
# Things to check:
# * '9041' in column A
# * '3', '1', '18', '5', '4', '2', '16', '13' in column B

# %%
activity_2014[activity_2014['A']=='9041']
# Out:
#          A   B  C  D    E    F    G  FOR RETAIL DRUG PURCHASES   BY GRAMS   WT
# 39    9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 63    9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 207   9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 256   9041  18  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 532   9041   3  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 558   9041   3  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 660   9041   5  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 1005  9041   3  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 1202  9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 1669  9041   4  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 1970  9041   4  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 2043  9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 2242  9041   2  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 2265  9041   3  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 2358  9041   2  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 2614  9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3232  9041   2  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3402  9041   3  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3683  9041  16  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3712  9041  13  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3780  9041   2  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3797  9041   2  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3870  9041   2  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 4883  9041   4  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN

# %% [markdown]
# Again, a lot of 9041 rows. Too many to bother with manually printing them all out - this isn't as pretty but does the job.

# %%
def show_9041_rows(df, i):
    return df.iloc[i-1:i+2, 0:6]

for i in activity_2014[activity_2014['A']=='9041'].index:
    print(show_9041_rows(activity_2014, i))
    print()
# Out:
#                 A          B   C       D    E      F
# 38  PENTOBARBITAL  (SCHEDULE  2)    2270    6  699.5
# 39           9041          1   0       0  NaN    NaN
# 40        COCAINE      9041L  44  202.42  4.6    NaN
#
#                 A          B   C       D     E          F
# 62  PENTOBARBITAL  (SCHEDULE  2)    2270    73  47,575.93
# 63           9041          1   0       0   NaN        NaN
# 64        COCAINE      9041L  11  105.99  9.64        NaN
#
#             A      B  C     D     E    F
# 206  NABILONE   7379  2  0.75  0.38  NaN
# 207      9041      1  0     0   NaN  NaN
# 208   COCAINE  9041L  6    20  3.33  NaN
#
#                  A          B   C       D     E           F
# 255  PENTOBARBITAL  (SCHEDULE  2)    2270   158  187,699.96
# 256           9041         18   0       0   NaN         NaN
# 257        COCAINE      9041L  21  160.13  7.63         NaN
#
#                  A          B   C       D    E         F
# 531  PENTOBARBITAL  (SCHEDULE  2)    2270   15  1,933.99
# 532           9041          3   0       0  NaN       NaN
# 533        COCAINE      9041L  56  268.95  4.8       NaN
#
#                  A          B   C       D     E           F
# 557  PENTOBARBITAL  (SCHEDULE  2)    2270   187  138,986.31
# 558           9041          3   0       0   NaN         NaN
# 559        COCAINE      9041L  22  167.77  7.63         NaN
#
#                  A          B   C      D     E          F
# 659  PENTOBARBITAL  (SCHEDULE  2)   2270    74  67,389.99
# 660           9041          5   0      0   NaN        NaN
# 661        COCAINE      9041L   6  49.43  8.24        NaN
#
#                   A          B   C      D     E           F
# 1004  PENTOBARBITAL  (SCHEDULE  2)   2270   161  162,664.71
# 1005           9041          3   0      0   NaN         NaN
# 1006        COCAINE      9041L  18  94.64  5.26         NaN
#
#                   A          B   C       D     E      F
# 1201  PENTOBARBITAL  (SCHEDULE  2)    2270     4  68.36
# 1202           9041          1   0       0   NaN    NaN
# 1203        COCAINE      9041L  22  211.77  9.63    NaN
#
#                   A          B   C       D     E       F
# 1668  PENTOBARBITAL  (SCHEDULE  2)    2270     6  486.23
# 1669           9041          4   0       0   NaN     NaN
# 1670        COCAINE      9041L  77  509.61  6.62     NaN
#
#                   A          B   C      D     E          F
# 1969  PENTOBARBITAL  (SCHEDULE  2)   2270    87  49,719.07
# 1970           9041          4   0      0   NaN        NaN
# 1971        COCAINE      9041L  14  30.03  2.15        NaN
#
#                   A          B   C       D      E          F
# 2042  PENTOBARBITAL  (SCHEDULE  2)    2270     16  12,882.18
# 2043           9041          1   0       0    NaN        NaN
# 2044        COCAINE      9041L  85  969.94  11.41        NaN
#
#                   A          B   C       D      E          F
# 2241  PENTOBARBITAL  (SCHEDULE  2)    2270     16  15,388.53
# 2242           9041          2   0       0    NaN        NaN
# 2243        COCAINE      9041L  91  921.01  10.12        NaN
#
#                   A          B   C       D     E           F
# 2264  PENTOBARBITAL  (SCHEDULE  2)    2270   141  109,291.40
# 2265           9041          3   0       0   NaN         NaN
# 2266        COCAINE      9041L  22  134.67  6.12         NaN
#
#                   A          B   C     D    E          F
# 2357  PENTOBARBITAL  (SCHEDULE  2)  2270   36  38,677.38
# 2358           9041          2   0     0  NaN        NaN
# 2359        COCAINE      9041L   3    12    4        NaN
#
#                   A          B   C       D     E       F
# 2613  PENTOBARBITAL  (SCHEDULE  2)    2270     9  868.56
# 2614           9041          1   0       0   NaN     NaN
# 2615        COCAINE      9041L  49  194.27  3.96     NaN
#
#                   A          B   C     D     E           F
# 3231  PENTOBARBITAL  (SCHEDULE  2)  2270   154  115,948.65
# 3232           9041          2   0     0   NaN         NaN
# 3233        COCAINE      9041L   4  8.29  2.07         NaN
#
#                   A          B   C     D     E           F
# 3401  PENTOBARBITAL  (SCHEDULE  2)  2270   258  225,185.17
# 3402           9041          3   0     0   NaN         NaN
# 3403        COCAINE      9041L   2  2.93  1.46         NaN
#
#                   A          B    C         D     E         F
# 3682  PENTOBARBITAL  (SCHEDULE   2)      2270    25  3,315.22
# 3683           9041         16    0         0   NaN       NaN
# 3684        COCAINE      9041L  165  1,543.33  9.35       NaN
#
#                   A          B   C       D     E           F
# 3711  PENTOBARBITAL  (SCHEDULE  2)    2270   289  246,602.99
# 3712           9041         13   0       0   NaN         NaN
# 3713        COCAINE      9041L  26  233.77  8.99         NaN
#
#                   A          B   C         D      E         F
# 3779  PENTOBARBITAL  (SCHEDULE  2)      2270      2  9,706.87
# 3780           9041          2   0         0    NaN       NaN
# 3781        CODEINE       9050  86  6,763.35  78.64       NaN
#
#                   A          B   C      D     E         F
# 3796  PENTOBARBITAL  (SCHEDULE  2)   2270     3  5,598.27
# 3797           9041          2   0      0   NaN       NaN
# 3798        CODEINE       9050   3  17.68  5.89       NaN
#
#                   A          B   C      D     E          F
# 3869  PENTOBARBITAL  (SCHEDULE  2)   2270    33  30,082.21
# 3870           9041          2   0      0   NaN        NaN
# 3871        COCAINE      9041L   3  14.21  4.74        NaN
#
#                   A          B   C       D     E           F
# 4882  PENTOBARBITAL  (SCHEDULE  2)    2270   201  148,985.17
# 4883           9041          4   0       0   NaN         NaN
# 4884        COCAINE      9041L  25  136.21  5.45         NaN

# %% [markdown]
# In a few of these cases it looks like cocaine 9041L may not be in the dataset (for certain states), but all the rows for 9041 still have zero gram data so we will let them drop as before.
#
# The unusual values in column B are related to these 9041 rows as well as header data.

# %%
for i in ['3', '1', '18', '5', '4', '2', '16', '13']:
    print(activity_2014[['A', 'B', 'C', 'D', 'E', 'F']].loc[activity_2014['B']==i])
    print()
# Out:
#           A  B  C       D    E            F
# 34    ARCOS  3  -  REPORT    5  STATISTICAL
# 71    ARCOS  3  -  REPORT    5  STATISTICAL
# 99    ARCOS  3  -  REPORT    5  STATISTICAL
# 136   ARCOS  3  -  REPORT    5  STATISTICAL
# 170   ARCOS  3  -  REPORT    5  STATISTICAL
# 201   ARCOS  3  -  REPORT    5  STATISTICAL
# 238   ARCOS  3  -  REPORT    5  STATISTICAL
# 273   ARCOS  3  -  REPORT    5  STATISTICAL
# 306   ARCOS  3  -  REPORT    5  STATISTICAL
# 343   ARCOS  3  -  REPORT    5  STATISTICAL
# 374   ARCOS  3  -  REPORT    5  STATISTICAL
# 409   ARCOS  3  -  REPORT    5  STATISTICAL
# 445   ARCOS  3  -  REPORT    5  STATISTICAL
# 479   ARCOS  3  -  REPORT    5  STATISTICAL
# 513   ARCOS  3  -  REPORT    5  STATISTICAL
# 532    9041  3  0       0  NaN          NaN
# 550   ARCOS  3  -  REPORT    5  STATISTICAL
# 558    9041  3  0       0  NaN          NaN
# 582   ARCOS  3  -  REPORT    5  STATISTICAL
# 615   ARCOS  3  -  REPORT    5  STATISTICAL
# 652   ARCOS  3  -  REPORT    5  STATISTICAL
# 683   ARCOS  3  -  REPORT    5  STATISTICAL
# 719   ARCOS  3  -  REPORT    5  STATISTICAL
# 753   ARCOS  3  -  REPORT    5  STATISTICAL
# 789   ARCOS  3  -  REPORT    5  STATISTICAL
# 825   ARCOS  3  -  REPORT    5  STATISTICAL
# 857   ARCOS  3  -  REPORT    5  STATISTICAL
# 895   ARCOS  3  -  REPORT    5  STATISTICAL
# 928   ARCOS  3  -  REPORT    5  STATISTICAL
# 960   ARCOS  3  -  REPORT    5  STATISTICAL
# ...     ... .. ..     ...  ...          ...
# 3997  ARCOS  3  -  REPORT    5  STATISTICAL
# 4034  ARCOS  3  -  REPORT    5  STATISTICAL
# 4065  ARCOS  3  -  REPORT    5  STATISTICAL
# 4099  ARCOS  3  -  REPORT    5  STATISTICAL
# 4133  ARCOS  3  -  REPORT    5  STATISTICAL
# 4167  ARCOS  3  -  REPORT    5  STATISTICAL
# 4201  ARCOS  3  -  REPORT    5  STATISTICAL
# 4238  ARCOS  3  -  REPORT    5  STATISTICAL
# 4272  ARCOS  3  -  REPORT    5  STATISTICAL
# 4303  ARCOS  3  -  REPORT    5  STATISTICAL
# 4340  ARCOS  3  -  REPORT    5  STATISTICAL
# 4375  ARCOS  3  -  REPORT    5  STATISTICAL
# 4407  ARCOS  3  -  REPORT    5  STATISTICAL
# 4441  ARCOS  3  -  REPORT    5  STATISTICAL
# 4471  ARCOS  3  -  REPORT    5  STATISTICAL
# 4503  ARCOS  3  -  REPORT    5  STATISTICAL
# 4537  ARCOS  3  -  REPORT    5  STATISTICAL
# 4573  ARCOS  3  -  REPORT    5  STATISTICAL
# 4608  ARCOS  3  -  REPORT    5  STATISTICAL
# 4639  ARCOS  3  -  REPORT    5  STATISTICAL
# 4676  ARCOS  3  -  REPORT    5  STATISTICAL
# 4711  ARCOS  3  -  REPORT    5  STATISTICAL
# 4741  ARCOS  3  -  REPORT    5  STATISTICAL
# 4778  ARCOS  3  -  REPORT    5  STATISTICAL
# 4810  ARCOS  3  -  REPORT    5  STATISTICAL
# 4843  ARCOS  3  -  REPORT    5  STATISTICAL
# 4879  ARCOS  3  -  REPORT    5  STATISTICAL
# 4912  ARCOS  3  -  REPORT    5  STATISTICAL
# 4945  ARCOS  3  -  REPORT    5  STATISTICAL
# 4981  ARCOS  3  -  REPORT    5  STATISTICAL
#
# [152 rows x 6 columns]
#
#          A  B  C  D    E    F
# 39    9041  1  0  0  NaN  NaN
# 63    9041  1  0  0  NaN  NaN
# 207   9041  1  0  0  NaN  NaN
# 1202  9041  1  0  0  NaN  NaN
# 2043  9041  1  0  0  NaN  NaN
# 2614  9041  1  0  0  NaN  NaN
#
#         A   B  C  D    E    F
# 256  9041  18  0  0  NaN  NaN
#
#         A  B  C  D    E    F
# 660  9041  5  0  0  NaN  NaN
#
#          A  B  C  D    E    F
# 1669  9041  4  0  0  NaN  NaN
# 1970  9041  4  0  0  NaN  NaN
# 4883  9041  4  0  0  NaN  NaN
#
#          A  B  C  D    E    F
# 2242  9041  2  0  0  NaN  NaN
# 2358  9041  2  0  0  NaN  NaN
# 3232  9041  2  0  0  NaN  NaN
# 3780  9041  2  0  0  NaN  NaN
# 3797  9041  2  0  0  NaN  NaN
# 3870  9041  2  0  0  NaN  NaN
#
#          A   B  C  D    E    F
# 3683  9041  16  0  0  NaN  NaN
#
#          A   B  C  D    E    F
# 3712  9041  13  0  0  NaN  NaN

# %%
activity_2014 = clean_activity_new(activity_2014, year=2014, 
                                   drug_codes=drug_codes, flat_geos=flat_geos, 
                                   activity_codes=activity_codes)
activity_2014.head()
# Out:
#    Year    State Business Activity                             Drug  \
# 4  2014  ALABAMA        PHARMACIES                      AMPHETAMINE
# 5  2014  ALABAMA        PHARMACIES  DL-METHAMPHETAMINE RACEMIC BASE
# 6  2014  ALABAMA        PHARMACIES                D-METHAMPHETAMINE
# 7  2014  ALABAMA        PHARMACIES                 LISDEXAMFETAMINE
# 8  2014  ALABAMA        PHARMACIES                  METHYLPHENIDATE
#
#    Registrants  Total grams sold  Avg grams/registrant
# 4         1341         444407.49                331.40
# 5           38            171.19                  4.50
# 6            2              1.61                  0.80
# 7         1297         244512.60                188.52
# 8         1333         287724.18                215.85

# %%
activity_2015 = pd.read_csv('activity_2015.txt', delim_whitespace=True)
check_activity_new(activity_2015, flat_geos=flat_geos, 
                   flat_activity_codes=flat_activity_codes)
# Out:
# Unusual numerical values in column A:
# ['9041']
#
# Unusual numerical values in column B
# ['3', '1', '12', '2']
#
# Unexpected value in column B for states: BUSINESS
# Unexpected value in column C for states: ACTIVITY:A
# Unexpected value in column C for states: ACTIVITY:B
# Unexpected value in column C for states: ACTIVITY:C
# Unexpected value in column C for states: ACTIVITY:D
# Unexpected value in column C for states: ACTIVITY:M
# Unexpected value in column C for states: ACTIVITY:N-U
# Unexpected value in column C for states: BUSINESS
# Checking column B
# Drug codes found in column B:
# ['1100', '1105D', '1205', '2165', '7379', '9050', '9064', '9120', '9143', '9150', '9193', '9220L', '9250B', '9300', '9652', '9780', '9041L', '9737', '9739', '9041', '9668', '9600', '7315D', '7370', '7377', '7381', '7433', '7437', '9010', '9020', '9200', '9313']
# non-numeric values in column B:
# ['PERIOD:' 'Date:' 'BUSINESS' 'NAME' 'RACEMIC' '(DL;D;L;ISOMERS)'
#  '(SCHEDULE' '(PETHIDINE)' 'POWDERED' 'BASE' 'SAMOA' 'HYDROXYBUTYRIC' 'OF'
#  nan '(PCE)' '(PCP)' 'SULFATE' 'HAMPSHIRE' 'JERSEY' 'MEXICO' 'YORK'
#  'CAROLINA' 'DAKOTA' 'RICO' 'ISLAND' 'ISLANDS' 'VIRGINIA']
#
# Checking column C
# Drug codes found in column C:
# ['1724', '9230', '9639', '9801', '9740', '7455', '7471', '9336']
# non-numeric values in column C:
# ['ACTIVITY:A' 'DRUG' 'BASE' 'ACTIVITY:B' '-' 'ACTIVITY:C' 'ACTIVITY:D'
#  'ACTIVITY:M' 'ACTIVITY:N-U' 'BUSINESS' 'ACID(FDA' 'COLUMBIA' nan]
#
# Checking column D
# Drug codes found in column D:
# ['1105B', '2315', '2125', '2270']
# non-numeric values in column D:
# ['TO' nan '-' 'CODE' 'REPORT' 'NARCOTIC' 'ACTIVITY:B' 'ACTIVITY:C'
#  'APPROVED' 'BUSINESS' 'ACTIVITY:A' 'ACTIVITY:D' 'ACTIVITY:M'
#  'ACTIVITY:N-U']
#
# Checking column E
# Drug codes found in column E:
# ['2012']
# non-numeric values in column E:
# [nan 'PHARMACIES' 'BUYERS' 'HOSPITALS' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' '-' 'ACTIVITY:A' 'ACTIVITY:B' 'ACTIVITY:C'
#  'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' 'NARCOTIC']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'TOTAL' 'STATISTICAL' 'INSTITUTIONS' 'PRACTITIONERS' 'PROGRAMS'
#  'HOSPITALS' '-' 'NARCOTIC' 'PHARMACIES' 'TEACHING' 'MID-LEVEL'
#  'TREATMENT']
#
# Checking column G
# No drug codes found.
# non-numeric values in column G:
# [nan 'GRAMS' 'SUMMARY' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS' 'TEACHING'
#  'MID-LEVEL' 'TREATMENT' 'INSTITUTIONS' 'PROGRAMS']
#
# Checking column FOR
# No drug codes found.
# non-numeric values in column FOR:
# [nan 'AVG' 'FOR' 'INSTITUTIONS' 'PRACTITIONERS']
#
# Checking column RETAIL
# No drug codes found.
# non-numeric values in column RETAIL:
# [nan 'GRAMS' 'RETAIL']
#
# Checking column DRUG
# No drug codes found.
# non-numeric values in column DRUG:
# [nan 'DRUG']
#
# Checking column PURCHASES
# No drug codes found.
# non-numeric values in column PURCHASES:
# [nan 'PURCHASES']
#
# Checking column BY
# No drug codes found.
# non-numeric values in column BY:
# [nan 'BY']
#
# Checking column GRAMS
# No drug codes found.
# non-numeric values in column GRAMS:
# [nan 'GRAMS']
#
# Checking column WT
# No drug codes found.
# non-numeric values in column WT:
# [nan 'WT']

# %%
# checking for 9041 cocaine data

activity_2015[activity_2015['A']=='9041']
# Out:
#          A   B  C  D    E    F    G  FOR RETAIL DRUG PURCHASES   BY GRAMS   WT
# 342   9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 412   9041  12  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 1173  9041   2  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 3757  9041   2  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN
# 4390  9041   1  0  0  NaN  NaN  NaN  NaN    NaN  NaN       NaN  NaN   NaN  NaN

# %%
# uncomment to check 

#activity_2015.iloc[341:344]
#activity_2015.iloc[411:414]
#activity_2015.iloc[1172:1175]
#activity_2015.iloc[3756:3759]
#activity_2015.iloc[4389:4392]

# %%
# check that these values are just header and 9041-related ['3', '1', '12', '2']
#activity_2015[activity_2015['B']=='3'].head()
#activity_2015[activity_2015['B']=='1']
#activity_2015[activity_2015['B']=='12']
#activity_2015[activity_2015['B']=='2']

# %%
activity_2015 = clean_activity_new(activity_2015, year=2015, 
                                   drug_codes=drug_codes, flat_geos=flat_geos, 
                                   activity_codes=activity_codes)
activity_2015.head()
# Out:
#    Year    State Business Activity                             Drug  \
# 4  2015  ALABAMA        PHARMACIES                      AMPHETAMINE
# 5  2015  ALABAMA        PHARMACIES  DL-METHAMPHETAMINE RACEMIC BASE
# 6  2015  ALABAMA        PHARMACIES                D-METHAMPHETAMINE
# 7  2015  ALABAMA        PHARMACIES                 LISDEXAMFETAMINE
# 8  2015  ALABAMA        PHARMACIES                  METHYLPHENIDATE
#
#    Registrants  Total grams sold  Avg grams/registrant
# 4         1360         475334.85                349.51
# 5           31            118.95                  3.84
# 6           13             24.10                  1.85
# 7         1325         265397.62                200.30
# 8         1347         285554.42                211.99

# %%
activity_2016 = pd.read_csv('activity_2016.txt', delim_whitespace=True)
check_activity_new(activity_2016, flat_geos=flat_geos, 
                   flat_activity_codes=flat_activity_codes)
# Out:
# Unusual numerical values in column A:
# ['25,314,852.67']
#
# Unusual numerical values in column A
# ['25,314,852.67']
#
# Unexpected value in column B for states: BUSINESS
# Unexpected value in column C for states: ACTIVITY:A
# Unexpected value in column C for states: ACTIVITY:B
# Unexpected value in column C for states: ACTIVITY:C
# Unexpected value in column C for states: ACTIVITY:D
# Unexpected value in column C for states: ACTIVITY:M
# Unexpected value in column C for states: ACTIVITY:N-U
# Unexpected value in column C for states: BUSINESS
# Checking column B
# Drug codes found in column B:
# ['1100', '1105D', '1205', '2165', '9050', '9064', '9120', '9143', '9150', '9193', '9220L', '9250B', '9300', '9652', '9780', '9041L', '9737', '9739', '9668', '7379']
# non-numeric values in column B:
# ['PERIOD:' 'BUSINESS' 'NAME' 'RACEMIC' '(DL;D;L;ISOMERS)' 'ACID'
#  '(PETHIDINE)' 'POWDERED' 'BASE' 'HYDROXYBUTYRIC' '(SCHEDULE' 'Date:'
#  'SUMMARY' 'SAMOA' 'TINCTURE' 'OF' nan '(PCP)' 'HAMPSHIRE' 'JERSEY'
#  'MEXICO' 'YORK' 'CAROLINA' 'DAKOTA' 'RICO' 'ISLAND' 'ISLANDS' 'VIRGINIA']
#
# Checking column C
# Drug codes found in column C:
# ['1724', '9230', '9639', '9801', '9740', '7471']
# non-numeric values in column C:
# ['ACTIVITY:A' 'DRUG' 'BASE' 'DERIVIATIVE' 'ACTIVITY:B' 'ACID(FDA' 'FOR'
#  'ACTIVITY:C' 'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' 'BUSINESS'
#  '(LAUDANUM)' 'COLUMBIA' nan]
#
# Checking column D
# Drug codes found in column D:
# ['1105B', '2125', '2270', '2315', '9630']
# non-numeric values in column D:
# ['TO' '-' 'CODE' 'OR' 'APPROVED' 'ARCOS' 'RETAIL' 'NARCOTIC' 'ACTIVITY:B'
#  'ACTIVITY:C' 'BUSINESS' nan 'ACTIVITY:A' 'ACTIVITY:D' 'ACTIVITY:M'
#  'ACTIVITY:N-U']
#
# Checking column E
# Drug codes found in column E:
# ['2012']
# non-numeric values in column E:
# ['PHARMACIES' 'BUYERS' 'SALT' 'HOSPITALS' 'DRUG' 'PRACTITIONERS'
#  'TEACHING' 'MID-LEVEL' 'TREATMENT' '-' 'ACTIVITY:A' 'ACTIVITY:B'
#  'ACTIVITY:C' 'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' nan 'NARCOTIC']
#
# Checking column F
# No drug codes found.
# non-numeric values in column F:
# [nan 'TOTAL' '[PER' '-' 'PURCHASES' 'INSTITUTIONS' 'PRACTITIONERS'
#  'PROGRAMS' 'HOSPITALS' 'NARCOTIC' 'PHARMACIES' 'TEACHING' 'MID-LEVEL'
#  'TREATMENT']
#
# Checking column G
# No drug codes found.
# non-numeric values in column G:
# [nan 'GRAMS' 'REPORT' 'BY' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS'
#  'TEACHING' 'MID-LEVEL' 'TREATMENT' 'INSTITUTIONS' 'PROGRAMS']
#
# Checking column FOR
# Drug codes found in column FOR:
# ['2100']
# non-numeric values in column FOR:
# [nan 'AVG' 'GRAMS' 'INSTITUTIONS' 'PRACTITIONERS']
#
# Checking column RETAIL
# No drug codes found.
# non-numeric values in column RETAIL:
# [nan 'GRAMS' 'WT']
#
# Checking column DRUG
# No drug codes found.
# non-numeric values in column DRUG:
# [nan]
#
# Checking column PURCHASES
# No drug codes found.
# non-numeric values in column PURCHASES:
# [nan]
#
# Checking column BY
# Null column.
#
# Checking column GRAMS
# Null column.
#
# Checking column WT
# Null column.

# %%
activity_2016[activity_2016['A']=='25,314,852.67']
# Out:
#                   A    B    C    D    E    F    G  FOR RETAIL DRUG  PURCHASES  \
# 2387  25,314,852.67  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN        NaN
#
#       BY  GRAMS  WT
# 2387 NaN    NaN NaN

# %%
activity_2016.iloc[2385:2389]
# Out:
#                     A                 B            C         D           E  \
# 2385  METHYLPHENIDATE  (DL;D;L;ISOMERS)         1724     1,343  517,387.64
# 2386            GAMMA    HYDROXYBUTYRIC     ACID(FDA  APPROVED        2012
# 2387    25,314,852.67               NaN          NaN       NaN         NaN
# 2388       BARBITURIC              ACID  DERIVIATIVE        OR        SALT
#
#            F              G   FOR RETAIL DRUG  PURCHASES  BY  GRAMS  WT
# 2385  385.25            NaN   NaN    NaN  NaN        NaN NaN    NaN NaN
# 2386       1  25,314,852.67   NaN    NaN  NaN        NaN NaN    NaN NaN
# 2387     NaN            NaN   NaN    NaN  NaN        NaN NaN    NaN NaN
# 2388    [PER            21C  2100      7  110      15.71 NaN    NaN NaN

# %%
activity_2016.loc[2386, 'FOR'] = activity_2016.loc[2387, 'A']
activity_2016.iloc[2385:2389]
# Out:
#                     A                 B            C         D           E  \
# 2385  METHYLPHENIDATE  (DL;D;L;ISOMERS)         1724     1,343  517,387.64
# 2386            GAMMA    HYDROXYBUTYRIC     ACID(FDA  APPROVED        2012
# 2387    25,314,852.67               NaN          NaN       NaN         NaN
# 2388       BARBITURIC              ACID  DERIVIATIVE        OR        SALT
#
#            F              G            FOR RETAIL DRUG  PURCHASES  BY  GRAMS  \
# 2385  385.25            NaN            NaN    NaN  NaN        NaN NaN    NaN
# 2386       1  25,314,852.67  25,314,852.67    NaN  NaN        NaN NaN    NaN
# 2387     NaN            NaN            NaN    NaN  NaN        NaN NaN    NaN
# 2388    [PER            21C           2100      7  110      15.71 NaN    NaN
#
#       WT
# 2385 NaN
# 2386 NaN
# 2387 NaN
# 2388 NaN

# %%
activity_2016 = clean_activity_new(activity_2016, year=2016, 
                                   drug_codes=drug_codes, flat_geos=flat_geos, 
                                   activity_codes=activity_codes)
activity_2016.head()
# Out:
#    Year    State Business Activity                             Drug  \
# 3  2016  ALABAMA        PHARMACIES                      AMPHETAMINE
# 4  2016  ALABAMA        PHARMACIES  DL-METHAMPHETAMINE RACEMIC BASE
# 5  2016  ALABAMA        PHARMACIES                D-METHAMPHETAMINE
# 6  2016  ALABAMA        PHARMACIES                 LISDEXAMFETAMINE
# 7  2016  ALABAMA        PHARMACIES                  METHYLPHENIDATE
#
#    Registrants  Total grams sold  Avg grams/registrant
# 3         1365         499133.36                365.67
# 4            9             32.95                  3.66
# 5           27             86.77                  3.21
# 6         1331         281761.32                211.69
# 7         1343         283227.95                210.89

# %%
activity_2017 = pd.read_csv('activity_2017.txt', delim_whitespace=True)
check_activity_new(activity_2017, flat_geos=flat_geos, 
                   flat_activity_codes=flat_activity_codes)
# Out:
# Unusual numerical values in column A:
# ['30,411,958.46']
#
# Unexpected activity code  in column E:
# Unusual numerical values in column A
# ['30,411,958.46']
#
# Unexpected value in column B for states: BUSINESS
# Unexpected value in column C for states: ACTIVITY:A
# Unexpected value in column C for states: ACTIVITY:B
# Unexpected value in column C for states: ACTIVITY:C
# Unexpected value in column C for states: ACTIVITY:D
# Unexpected value in column C for states: ACTIVITY:M
# Unexpected value in column C for states: ACTIVITY:N-U
# Unexpected value in column C for states: BUSINESS
# Checking column B
# Drug codes found in column B:
# ['1100', '1105D', '1205', '2165', '9050', '9064', '9120', '9143', '9150', '9193', '9220L', '9250B', '9300', '9652', '9780', '9041L', '9737', '9739', '7379', '9668', '9333', '9056']
# non-numeric values in column B:
# ['Date:' 'BUSINESS' 'NAME' 'RACEMIC' '(DL;D;L;ISOMERS)' 'ACID' 'IN'
#  '(PETHIDINE)' 'POWDERED' 'BASE' 'COMBINATION' '(SCHEDULE' 'RANGE:'
#  'SUMMARY' 'SAMOA' 'TINCTURE' 'HYDROXYBUTYRIC' 'OF' nan 'HAMPSHIRE'
#  'JERSEY' 'MEXICO' 'YORK' 'CAROLINA' 'DAKOTA' 'RICO' 'ISLAND' 'ISLANDS'
#  'VIRGINIA' 'STATES' 'UNITED' 'ACTIVITY:A' '(SYNDROS']
#
# Checking column C
# Drug codes found in column C:
# ['1724', '9230', '9639', '9801', '9740']
# non-numeric values in column C:
# ['ACTIVITY:A' 'DRUG' 'BASE' 'DERIVIATIVE' 'AN' 'PRODUCT' 'ACTIVITY:B'
#  'FOR' 'ACTIVITY:C' 'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' 'BUSINESS'
#  '(LAUDANUM)' 'ACID(FDA' 'COLUMBIA' nan 'SUMMARY' 'STATES' '-']
#
# Checking column D
# Drug codes found in column D:
# ['1105B', '2270', '2315', '2125', '9630']
# non-numeric values in column D:
# [nan '-' 'CODE' 'OR' 'ORAL' '(C-III)' 'TO' 'RETAIL' 'NARCOTIC'
#  'ACTIVITY:B' 'ACTIVITY:C' 'APPROVED' 'BUSINESS' 'ACTIVITY:A' 'ACTIVITY:M'
#  'ACTIVITY:N-U' 'ACTIVITY:D' 'FOR' 'APPROVED-CSA' 'PHARMACIES' 'CII)']
#
# Checking column E
# Drug codes found in column E:
# ['9809', '2012', '7365']
# non-numeric values in column E:
# [nan 'PHARMACIES' 'BUYERS' 'SALT' 'SOLUTION' 'HOSPITALS' 'DRUG'
#  'PRACTITIONERS' 'TEACHING' 'MID-LEVEL' 'TREATMENT' '-' 'ACTIVITY:A'
#  'ACTIVITY:B' 'ACTIVITY:C' 'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U'
#  'NARCOTIC' 'RETAIL' 'ACTIVITY:' 'III)']
#
# Checking column F
# Drug codes found in column F:
# ['2012']
# non-numeric values in column F:
# [nan 'TOTAL' '[PER' 'IN' 'ARCOS' 'PURCHASES' 'INSTITUTIONS'
#  'PRACTITIONERS' 'PROGRAMS' 'HOSPITALS' '-' 'NARCOTIC' 'PHARMACIES'
#  'MID-LEVEL' 'TREATMENT' 'TEACHING' 'DRUG' 'A' 'B' 'C' 'D' 'M' 'N-U']
#
# Checking column G
# No drug codes found.
# non-numeric values in column G:
# [nan 'GRAMS' 'FDA' 'BY' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS'
#  'TEACHING' 'MID-LEVEL' 'TREATMENT' 'PROGRAMS' 'INSTITUTIONS' 'PURCHASES'
#  '-' 'NARCOTIC']
#
# Checking column FOR
# Drug codes found in column FOR:
# ['2100', '1308.13(C)(3)]']
# Unexpected code found: 1308.13(C)(3)]
# non-numeric values in column FOR:
# [nan 'AVG' 'APPR' '-' 'GRAMS' 'INSTITUTIONS' 'PRACTITIONERS' 'BY'
#  'PHARMACIES' 'APPROVED' 'HOSPITALS' 'TEACHING' 'MID-LEVEL' 'TREATMENT']
#
# Checking column RETAIL
# Drug codes found in column RETAIL:
# ['7365', '2100', '3133.15']
# Unexpected code found: 3133.15
# non-numeric values in column RETAIL:
# [nan 'GRAMS' 'REPORT' 'WT' 'DRUG' 'INSTITUTIONS' 'PRACTITIONERS'
#  'PROGRAMS']
#
# Checking column DRUG
# No drug codes found.
# non-numeric values in column DRUG:
# [nan 'WT' 'PRODU']
#
# Checking column PURCHASES
# Drug codes found in column PURCHASES:
# ['7365']
# non-numeric values in column PURCHASES:
# [nan]
#
# Checking column BY
# No drug codes found.
# non-numeric values in column BY:
# [nan]
#
# Checking column GRAMS
# No drug codes found.
# non-numeric values in column GRAMS:
# [nan]
#
# Checking column WT
# No drug codes found.
# non-numeric values in column WT:
# [nan]

# %% [markdown]
# It looks like there are some differences with this file - the overall format is the same, but some of the numeric values are formatted differently. For example, the unusual value '3133.15' in column 'RETAIL' is getting picked up as a drug code because it has 4 digits in a row without a comma separator, as the data typically does.
#
# Things to check:
#
# * '30,411,958.46' in column A
# * '1308.13(C)(3)]' in column FOR
# * '3133.15' in column RETAIL
# * 'PRODU' in column DRUG

# %%
activity_2017[activity_2017['A']=='30,411,958.46']
# Out:
#                   A    B    C    D    E    F    G  FOR RETAIL DRUG PURCHASES  \
# 2450  30,411,958.46  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN       NaN
#
#       BY  GRAMS  WT
# 2450 NaN    NaN NaN

# %%
activity_2017.iloc[2448:2452]
# Out:
#                     A                 B            C         D           E  \
# 2448  METHYLPHENIDATE  (DL;D;L;ISOMERS)         1724     1,318  515,769.49
# 2449            GAMMA    HYDROXYBUTYRIC     ACID(FDA  APPROVED        2012
# 2450    30,411,958.46               NaN          NaN       NaN         NaN
# 2451       BARBITURIC              ACID  DERIVIATIVE        OR        SALT
#
#            F              G   FOR RETAIL    DRUG PURCHASES  BY  GRAMS  WT
# 2448  391.33            NaN   NaN    NaN     NaN       NaN NaN    NaN NaN
# 2449       1  30,411,958.46   NaN    NaN     NaN       NaN NaN    NaN NaN
# 2450     NaN            NaN   NaN    NaN     NaN       NaN NaN    NaN NaN
# 2451    [PER            21C  2100    378  15,805     41.81 NaN    NaN NaN

# %%
activity_2017.loc[2449, 'FOR'] = activity_2017.loc[2450, 'A']
activity_2017.iloc[2448:2452]
# Out:
#                     A                 B            C         D           E  \
# 2448  METHYLPHENIDATE  (DL;D;L;ISOMERS)         1724     1,318  515,769.49
# 2449            GAMMA    HYDROXYBUTYRIC     ACID(FDA  APPROVED        2012
# 2450    30,411,958.46               NaN          NaN       NaN         NaN
# 2451       BARBITURIC              ACID  DERIVIATIVE        OR        SALT
#
#            F              G            FOR RETAIL    DRUG PURCHASES  BY  \
# 2448  391.33            NaN            NaN    NaN     NaN       NaN NaN
# 2449       1  30,411,958.46  30,411,958.46    NaN     NaN       NaN NaN
# 2450     NaN            NaN            NaN    NaN     NaN       NaN NaN
# 2451    [PER            21C           2100    378  15,805     41.81 NaN
#
#       GRAMS  WT
# 2448    NaN NaN
# 2449    NaN NaN
# 2450    NaN NaN
# 2451    NaN NaN

# %%
activity_2017[activity_2017['RETAIL']=='3133.15']
# Out:
#           A               B         C             D     E     F   G  \
# 5140  GAMMA  HYDROXYBUTYRIC  ACID(FDA  APPROVED-CSA  III)  2012  12
#
#             FOR   RETAIL DRUG PURCHASES  BY  GRAMS  WT
# 5140  37,597.82  3133.15  NaN       NaN NaN    NaN NaN

# %% [markdown]
# For whatever reason, this value is formatted without a comma separator. This will cause an error if we let it get picked up by the cleaning function as a drug code. Many ways to deal with this, but since it's just one value I'm choosing to handle it by manually adding a comma so that it will be treated like the rest of the data.

# %%
activity_2017.loc[5140, 'RETAIL'] = '3,133.15'
activity_2017.iloc[5139:5141]
# Out:
#                     A                 B         C             D           E  \
# 5139  METHYLPHENIDATE  (DL;D;L;ISOMERS)      1724         5,376  606,458.81
# 5140            GAMMA    HYDROXYBUTYRIC  ACID(FDA  APPROVED-CSA        III)
#
#            F    G        FOR    RETAIL DRUG PURCHASES  BY  GRAMS  WT
# 5139  112.81  NaN        NaN       NaN  NaN       NaN NaN    NaN NaN
# 5140    2012   12  37,597.82  3,133.15  NaN       NaN NaN    NaN NaN

# %% [markdown]
# The check function also picked up this unusual value as a drug code in column 'FOR' - you might recognize it as part of a drug name but doesn't hurt to check it anyway and determine if the actual drug code will get picked up in that line.

# %%
activity_2017[activity_2017['FOR']=='1308.13(C)(3)]']
# Out:
#                A     B            C   D     E     F      G             FOR  \
# 5099  BARBITURIC  ACID  DERIVIATIVE  OR  SALT  [PER  21CFR  1308.13(C)(3)]
# 5141  BARBITURIC  ACID  DERIVIATIVE  OR  SALT  [PER  21CFR  1308.13(C)(3)]
# 5180  BARBITURIC  ACID  DERIVIATIVE  OR  SALT  [PER  21CFR  1308.13(C)(3)]
#
#      RETAIL    DRUG PURCHASES     BY  GRAMS  WT
# 5099   2100  18,623   596,769  32.04    NaN NaN
# 5141   2100     168  2,009.90  11.96    NaN NaN
# 5180   2100       6      93.5  15.58    NaN NaN

# %% [markdown]
# Same situation here - because it's not a code that's in the dictionary, it will throw a KeyError in the cleaning process. I will fudge it here by adding an extra space.

# %%
activity_2017.loc[activity_2017['FOR']=='1308.13(C)(3)]', 'FOR'] = '1,308.13(C)(3)]'

# %%
# this is just part of a drug name
activity_2017[activity_2017['DRUG']=='PRODU']
# Out:
#                A   B   C     D         E   F    G       FOR RETAIL   DRUG  \
# 5104  DRONABINOL  IN  AN  ORAL  SOLUTION  IN  FDA  APPROVED   DRUG  PRODU
#
#      PURCHASES     BY   GRAMS    WT
# 5104      7365  191.0  341.25  1.79

# %%
activity_2017 = clean_activity_new(activity_2017, year=2017, 
                                   drug_codes=drug_codes, flat_geos=flat_geos, 
                                   activity_codes=activity_codes)
activity_2017.head()
# Out:
#    Year    State Business Activity                             Drug  \
# 3  2017  ALABAMA        PHARMACIES                      AMPHETAMINE
# 4  2017  ALABAMA        PHARMACIES  DL-METHAMPHETAMINE RACEMIC BASE
# 5  2017  ALABAMA        PHARMACIES                D-METHAMPHETAMINE
# 6  2017  ALABAMA        PHARMACIES                 LISDEXAMFETAMINE
# 7  2017  ALABAMA        PHARMACIES                  METHYLPHENIDATE
#
#    Registrants  Total grams sold  Avg grams/registrant
# 3         1371         513195.41                374.32
# 4           32             96.04                  3.00
# 5            4             14.86                  3.72
# 6         1328         282505.33                212.73
# 7         1352         283489.85                209.68

# %%
# Define a new checksum function - in this case need to check 
# on the average values, no sums to check
def avgs_check(df):
    df['check'] = df['Total grams sold'].div(df['Registrants'], axis=0)
    df['diff'] = df['Avg grams/registrant'] - df['check']
    issues = df.loc[(df['diff'].abs())>0.2]
    if issues.empty:
        print('Averages check passed')
    else:
        print('Averages issues:')
        print(issues)
    df.drop(['check', 'diff'], axis=1, inplace=True)

# Define a new duplicates check function

def repeats_check_activity(df):
    df['check'] = df['Year'].astype(str)+df['State']+df['Business Activity']+df['Drug']
    checks = pd.Series(data=df['check'].value_counts())
    errors = checks.loc[checks!=1]
    if errors.empty:
        print('Repeats checks passed')
    else:
        print('Repeats errors:')
        print(errors)
    df.drop(['check'], axis=1, inplace=True)
    
def check_states(df, geos):
    """
    Compare the states present in the df with those we expect to find.
    """
    in_df = df['State'].unique()
    diff = set(geos).symmetric_difference(set(in_df))
    if diff:
        print('State values not matching:', diff)
    else:
        print("All expected state values present")

# %%
activity_dfs = {'2000': activity_2000, '2001': activity_2001, 
                '2002': activity_2002, '2003': activity_2003, 
                '2004': activity_2004, '2005': activity_2005, 
                '2006': activity_2006, '2007': activity_2007, 
                '2008': activity_2008, '2009': activity_2009, 
                '2010': activity_2010, '2011': activity_2011, 
                '2012': activity_2012, '2013': activity_2013, 
                '2014': activity_2014, '2015': activity_2015, 
                '2016': activity_2016, '2017': activity_2017}

for f in activity_dfs.keys():
    print('Checking {} file...'.format(f))
    avgs_check(activity_dfs[f])
    repeats_check_zip(activity_dfs[f])
    check_states(activity_dfs[f], geos)
    print()
    print()
# Out:
# Checking 2000 file...
# Averages check passed
# Repeats checks passed
# State values not matching: {'UNITED STATES', 'AMERICAN SAMOA'}
#
#
# Checking 2001 file...
# Averages check passed
# Repeats checks passed
# State values not matching: {'UNITED STATES', 'AMERICAN SAMOA'}
#
#
# Checking 2002 file...
# Averages check passed
# Repeats checks passed
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2003 file...
# Averages check passed
# Repeats checks passed
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2004 file...
# Averages check passed
# Repeats checks passed
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2005 file...
# Averages check passed
# Repeats checks passed
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2006 file...
# Averages check passed
# Repeats checks passed
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2007 file...
# Averages check passed
# Repeats checks passed
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2008 file...
# Averages check passed
# Repeats checks passed
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2009 file...
# Averages check passed
# Repeats checks passed
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2010 file...
# Averages check passed
# Repeats errors:
# 2010OREGONPRACTITIONERSCOCAINE        2
# 2010CALIFORNIAPRACTITIONERSCOCAINE    2
# Name: check, dtype: int64
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2011 file...
# Averages check passed
# Repeats errors:
# 2011UTAHPHARMACIESCOCAINE                       2
# 2011OHIOPRACTITIONERSCOCAINE                    2
# 2011WASHINGTONHOSPITALSCOCAINE                  2
# 2011WEST VIRGINIAPRACTITIONERSCOCAINE           2
# 2011ILLINOISPRACTITIONERSCOCAINE                2
# 2011LOUISIANAPRACTITIONERSCOCAINE               2
# 2011PENNSYLVANIAPRACTITIONERSCOCAINE            2
# 2011NEVADAHOSPITALSCOCAINE                      2
# 2011DISTRICT OF COLUMBIAPRACTITIONERSCOCAINE    2
# 2011ILLINOISHOSPITALSCOCAINE                    2
# 2011CALIFORNIAPRACTITIONERSCOCAINE              2
# 2011KANSASHOSPITALSCOCAINE                      2
# 2011WEST VIRGINIAHOSPITALSCOCAINE               2
# 2011MICHIGANPRACTITIONERSCOCAINE                2
# 2011ARIZONAPRACTITIONERSCOCAINE                 2
# 2011MASSACHUSETTSPRACTITIONERSCOCAINE           2
# 2011NEW YORKHOSPITALSCOCAINE                    2
# 2011SOUTH CAROLINAHOSPITALSCOCAINE              2
# 2011OREGONPRACTITIONERSCOCAINE                  2
# 2011ALABAMAPRACTITIONERSCOCAINE                 2
# 2011MARYLANDPRACTITIONERSCOCAINE                2
# 2011FLORIDAHOSPITALSCOCAINE                     2
# 2011CONNECTICUTPRACTITIONERSCOCAINE             2
# 2011CALIFORNIAHOSPITALSCOCAINE                  2
# 2011NEW YORKPRACTITIONERSCOCAINE                2
# 2011NORTH CAROLINAPRACTITIONERSCOCAINE          2
# 2011COLORADOPRACTITIONERSCOCAINE                2
# 2011LOUISIANAHOSPITALSCOCAINE                   2
# 2011RHODE ISLANDPRACTITIONERSCOCAINE            2
# 2011MARYLANDHOSPITALSCOCAINE                    2
# 2011FLORIDAPRACTITIONERSCOCAINE                 2
# 2011TEXASHOSPITALSCOCAINE                       2
# 2011MISSISSIPPIPRACTITIONERSCOCAINE             2
# 2011CONNECTICUTHOSPITALSCOCAINE                 2
# 2011OHIOHOSPITALSCOCAINE                        2
# 2011GEORGIAHOSPITALSCOCAINE                     2
# 2011TEXASPRACTITIONERSCOCAINE                   2
# 2011WISCONSINPRACTITIONERSCOCAINE               2
# 2011MINNESOTAPRACTITIONERSCOCAINE               2
# 2011MICHIGANHOSPITALSCOCAINE                    2
# 2011WASHINGTONPRACTITIONERSCOCAINE              2
# 2011ARIZONAHOSPITALSCOCAINE                     2
# 2011GEORGIAPRACTITIONERSCOCAINE                 2
# 2011MINNESOTAHOSPITALSCOCAINE                   2
# 2011PENNSYLVANIAHOSPITALSCOCAINE                2
# 2011NEW JERSEYPRACTITIONERSCOCAINE              2
# 2011ARIZONAPHARMACIESCOCAINE                    2
# 2011ARKANSASHOSPITALSCOCAINE                    2
# Name: check, dtype: int64
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2012 file...
# Averages check passed
# Repeats errors:
# 2012TEXASHOSPITALSCOCAINE                   2
# 2012MARYLANDPHARMACIESCOCAINE               2
# 2012GEORGIAPRACTITIONERSCOCAINE             2
# 2012FLORIDAPRACTITIONERSCOCAINE             2
# 2012CALIFORNIAPRACTITIONERSCOCAINE          2
# 2012NEW YORKHOSPITALSCOCAINE                2
# 2012WEST VIRGINIAHOSPITALSCOCAINE           2
# 2012DELAWAREHOSPITALSCOCAINE                2
# 2012DISTRICT OF COLUMBIAHOSPITALSCOCAINE    2
# 2012PENNSYLVANIAPRACTITIONERSCOCAINE        2
# 2012CALIFORNIAHOSPITALSCOCAINE              2
# 2012WISCONSINHOSPITALSCOCAINE               2
# 2012MARYLANDPRACTITIONERSCOCAINE            2
# 2012NEW HAMPSHIREPRACTITIONERSCOCAINE       2
# 2012RHODE ISLANDPRACTITIONERSCOCAINE        2
# 2012MASSACHUSETTSPRACTITIONERSCOCAINE       2
# 2012MICHIGANHOSPITALSCOCAINE                2
# 2012IDAHOHOSPITALSCOCAINE                   2
# 2012MARYLANDHOSPITALSCOCAINE                2
# 2012VERMONTPRACTITIONERSCOCAINE             2
# 2012NEW JERSEYPRACTITIONERSCOCAINE          2
# 2012ARIZONAPRACTITIONERSCOCAINE             2
# 2012INDIANAPRACTITIONERSCOCAINE             2
# 2012VIRGINIAPRACTITIONERSCOCAINE            2
# 2012IOWAPRACTITIONERSCOCAINE                2
# 2012SOUTH CAROLINAPRACTITIONERSCOCAINE      2
# 2012NEW JERSEYHOSPITALSCOCAINE              2
# 2012ALABAMAPRACTITIONERSCOCAINE             2
# 2012ARIZONAPHARMACIESCOCAINE                2
# 2012ILLINOISHOSPITALSCOCAINE                2
#                                            ..
# 2012CONNECTICUTPRACTITIONERSCOCAINE         2
# 2012MINNESOTAHOSPITALSCOCAINE               2
# 2012COLORADOHOSPITALSCOCAINE                2
# 2012ARIZONAHOSPITALSCOCAINE                 2
# 2012INDIANAHOSPITALSCOCAINE                 2
# 2012OREGONHOSPITALSCOCAINE                  2
# 2012NEVADAHOSPITALSCOCAINE                  2
# 2012NEW YORKPRACTITIONERSCOCAINE            2
# 2012LOUISIANAPRACTITIONERSCOCAINE           2
# 2012MISSISSIPPIPRACTITIONERSCOCAINE         2
# 2012TENNESSEEHOSPITALSCOCAINE               2
# 2012GEORGIAHOSPITALSCOCAINE                 2
# 2012OKLAHOMAHOSPITALSCOCAINE                2
# 2012LOUISIANAHOSPITALSCOCAINE               2
# 2012OHIOHOSPITALSCOCAINE                    2
# 2012TEXASPRACTITIONERSCOCAINE               2
# 2012WASHINGTONPRACTITIONERSCOCAINE          2
# 2012NORTH CAROLINAPRACTITIONERSCOCAINE      2
# 2012KANSASHOSPITALSCOCAINE                  2
# 2012MAINEPRACTITIONERSCOCAINE               2
# 2012MISSOURIHOSPITALSCOCAINE                2
# 2012ARKANSASPRACTITIONERSCOCAINE            2
# 2012MICHIGANPRACTITIONERSCOCAINE            2
# 2012OREGONPRACTITIONERSCOCAINE              2
# 2012MINNESOTAPRACTITIONERSCOCAINE           2
# 2012WISCONSINPRACTITIONERSCOCAINE           2
# 2012ILLINOISPRACTITIONERSCOCAINE            2
# 2012NORTH CAROLINAHOSPITALSCOCAINE          2
# 2012WEST VIRGINIAPRACTITIONERSCOCAINE       2
# 2012SOUTH CAROLINAHOSPITALSCOCAINE          2
# Name: check, Length: 69, dtype: int64
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2013 file...
# Averages check passed
# Repeats errors:
# 2013FLORIDAHOSPITALSCOCAINE              2
# 2013CALIFORNIAPRACTITIONERSCOCAINE       2
# 2013NEW JERSEYPRACTITIONERSCOCAINE       2
# 2013COLORADOHOSPITALSCOCAINE             2
# 2013IDAHOHOSPITALSCOCAINE                2
# 2013MAINEPRACTITIONERSCOCAINE            2
# 2013ARIZONAPHARMACIESCOCAINE             2
# 2013FLORIDAPRACTITIONERSCOCAINE          2
# 2013WASHINGTONHOSPITALSCOCAINE           2
# 2013COLORADOPRACTITIONERSCOCAINE         2
# 2013VIRGINIAPRACTITIONERSCOCAINE         2
# 2013GEORGIAPRACTITIONERSCOCAINE          2
# 2013MISSISSIPPIPRACTITIONERSCOCAINE      2
# 2013MISSOURIHOSPITALSCOCAINE             2
# 2013MINNESOTAPRACTITIONERSCOCAINE        2
# 2013INDIANAPRACTITIONERSCOCAINE          2
# 2013GEORGIAHOSPITALSCOCAINE              2
# 2013ARIZONAHOSPITALSCOCAINE              2
# 2013CONNECTICUTPRACTITIONERSCOCAINE      2
# 2013NEW JERSEYHOSPITALSCOCAINE           2
# 2013TEXASPRACTITIONERSCOCAINE            2
# 2013UTAHPHARMACIESCOCAINE                2
# 2013ILLINOISPRACTITIONERSCOCAINE         2
# 2013CALIFORNIAHOSPITALSCOCAINE           2
# 2013MARYLANDHOSPITALSCOCAINE             2
# 2013ARIZONAPRACTITIONERSCOCAINE          2
# 2013PENNSYLVANIAPRACTITIONERSCOCAINE     2
# 2013VERMONTPRACTITIONERSCOCAINE          2
# 2013GEORGIAPHARMACIESCOCAINE             2
# 2013INDIANAHOSPITALSCOCAINE              2
# 2013MARYLANDPRACTITIONERSCOCAINE         2
# 2013PENNSYLVANIAHOSPITALSCOCAINE         2
# 2013LOUISIANAPRACTITIONERSCOCAINE        2
# 2013TEXASHOSPITALSCOCAINE                2
# 2013MICHIGANPRACTITIONERSCOCAINE         2
# 2013VIRGINIAHOSPITALSCOCAINE             2
# 2013WISCONSINHOSPITALSCOCAINE            2
# 2013ALABAMAHOSPITALSCOCAINE              2
# 2013LOUISIANAHOSPITALSCOCAINE            2
# 2013MISSISSIPPIHOSPITALSCOCAINE          2
# 2013MARYLANDPHARMACIESCOCAINE            2
# 2013SOUTH DAKOTAHOSPITALSCOCAINE         2
# 2013MICHIGANHOSPITALSCOCAINE             2
# 2013CONNECTICUTHOSPITALSCOCAINE          2
# 2013NORTH DAKOTAHOSPITALSCOCAINE         2
# 2013MINNESOTAHOSPITALSCOCAINE            2
# 2013ARKANSASPRACTITIONERSCOCAINE         2
# 2013NEVADAHOSPITALSCOCAINE               2
# 2013NEW HAMPSHIREPRACTITIONERSCOCAINE    2
# 2013MASSACHUSETTSPRACTITIONERSCOCAINE    2
# 2013MASSACHUSETTSHOSPITALSCOCAINE        2
# 2013RHODE ISLANDPRACTITIONERSCOCAINE     2
# 2013IOWAPRACTITIONERSCOCAINE             2
# 2013ILLINOISHOSPITALSCOCAINE             2
# 2013KENTUCKYHOSPITALSCOCAINE             2
# 2013WASHINGTONPRACTITIONERSCOCAINE       2
# 2013KANSASHOSPITALSCOCAINE               2
# Name: check, dtype: int64
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2014 file...
# Averages check passed
# Repeats errors:
# 2014IOWAPRACTITIONERSCOCAINE                2
# 2014TEXASHOSPITALSCOCAINE                   2
# 2014CONNECTICUTHOSPITALSCOCAINE             2
# 2014SOUTH CAROLINAPRACTITIONERSCOCAINE      2
# 2014LOUISIANAPRACTITIONERSCOCAINE           2
# 2014NORTH DAKOTAHOSPITALSCOCAINE            2
# 2014ILLINOISHOSPITALSCOCAINE                2
# 2014WEST VIRGINIAPHARMACIESCOCAINE          2
# 2014WASHINGTONPRACTITIONERSCOCAINE          2
# 2014OKLAHOMAHOSPITALSCOCAINE                2
# 2014NEW JERSEYPRACTITIONERSCOCAINE          2
# 2014WEST VIRGINIAPRACTITIONERSCOCAINE       2
# 2014MICHIGANHOSPITALSCOCAINE                2
# 2014TENNESSEEPRACTITIONERSCOCAINE           2
# 2014GEORGIAHOSPITALSCOCAINE                 2
# 2014NEW JERSEYHOSPITALSCOCAINE              2
# 2014FLORIDAPRACTITIONERSCOCAINE             2
# 2014KANSASHOSPITALSCOCAINE                  2
# 2014ARKANSASPRACTITIONERSCOCAINE            2
# 2014ARIZONAHOSPITALSCOCAINE                 2
# 2014SOUTH CAROLINAHOSPITALSCOCAINE          2
# 2014INDIANAHOSPITALSCOCAINE                 2
# 2014NEW YORKHOSPITALSCOCAINE                2
# 2014OREGONPRACTITIONERSCOCAINE              2
# 2014MISSOURIHOSPITALSCOCAINE                2
# 2014NEW YORKPRACTITIONERSCOCAINE            2
# 2014LOUISIANAHOSPITALSCOCAINE               2
# 2014DELAWAREHOSPITALSCOCAINE                2
# 2014UTAHPHARMACIESCOCAINE                   2
# 2014CALIFORNIAPRACTITIONERSCOCAINE          2
# 2014NEBRASKAPRACTITIONERSCOCAINE            2
# 2014ARKANSASHOSPITALSCOCAINE                2
# 2014VIRGINIAPRACTITIONERSCOCAINE            2
# 2014OHIOHOSPITALSCOCAINE                    2
# 2014INDIANAPRACTITIONERSCOCAINE             2
# 2014VIRGINIAHOSPITALSCOCAINE                2
# 2014NEW HAMPSHIREPRACTITIONERSCOCAINE       2
# 2014DISTRICT OF COLUMBIAHOSPITALSCOCAINE    2
# 2014OREGONHOSPITALSCOCAINE                  2
# 2014WASHINGTONHOSPITALSCOCAINE              2
# 2014SOUTH DAKOTAHOSPITALSCOCAINE            2
# 2014TEXASPRACTITIONERSCOCAINE               2
# 2014MASSACHUSETTSPRACTITIONERSCOCAINE       2
# 2014FLORIDAHOSPITALSCOCAINE                 2
# 2014IOWAHOSPITALSCOCAINE                    2
# 2014MICHIGANPRACTITIONERSCOCAINE            2
# 2014GEORGIAPHARMACIESCOCAINE                2
# 2014TENNESSEEHOSPITALSCOCAINE               2
# 2014MISSISSIPPIHOSPITALSCOCAINE             2
# 2014WISCONSINHOSPITALSCOCAINE               2
# 2014NEVADAHOSPITALSCOCAINE                  2
# 2014ILLINOISPRACTITIONERSCOCAINE            2
# 2014CALIFORNIAHOSPITALSCOCAINE              2
# 2014MARYLANDHOSPITALSCOCAINE                2
# 2014WEST VIRGINIAHOSPITALSCOCAINE           2
# 2014NORTH CAROLINAHOSPITALSCOCAINE          2
# Name: check, dtype: int64
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2015 file...
# Averages check passed
# Repeats errors:
# 2015WASHINGTONHOSPITALSCOCAINE              2
# 2015SOUTH CAROLINAHOSPITALSCOCAINE          2
# 2015LOUISIANAPRACTITIONERSCOCAINE           2
# 2015WISCONSINPRACTITIONERSCOCAINE           2
# 2015OHIOPRACTITIONERSCOCAINE                2
# 2015NEBRASKAPRACTITIONERSCOCAINE            2
# 2015OHIOHOSPITALSCOCAINE                    2
# 2015IOWAHOSPITALSCOCAINE                    2
# 2015ALABAMAPRACTITIONERSCOCAINE             2
# 2015MICHIGANHOSPITALSCOCAINE                2
# 2015DISTRICT OF COLUMBIAHOSPITALSCOCAINE    2
# 2015WEST VIRGINIAHOSPITALSCOCAINE           2
# 2015FLORIDAPRACTITIONERSCOCAINE             2
# 2015NEW JERSEYHOSPITALSCOCAINE              2
# 2015TEXASPRACTITIONERSCOCAINE               2
# 2015INDIANAPRACTITIONERSCOCAINE             2
# 2015NEW HAMPSHIREPRACTITIONERSCOCAINE       2
# 2015WISCONSINHOSPITALSCOCAINE               2
# 2015PENNSYLVANIAHOSPITALSCOCAINE            2
# 2015MINNESOTAPRACTITIONERSCOCAINE           2
# 2015VIRGINIAHOSPITALSCOCAINE                2
# 2015TEXASHOSPITALSCOCAINE                   2
# 2015COLORADOPRACTITIONERSCOCAINE            2
# 2015CALIFORNIAPRACTITIONERSCOCAINE          2
# 2015MICHIGANPRACTITIONERSCOCAINE            2
# 2015INDIANAHOSPITALSCOCAINE                 2
# 2015ARIZONAHOSPITALSCOCAINE                 2
# 2015GEORGIAPHARMACIESCOCAINE                2
# 2015NORTH CAROLINAHOSPITALSCOCAINE          2
# 2015MASSACHUSETTSPRACTITIONERSCOCAINE       2
#                                            ..
# 2015MISSISSIPPIPRACTITIONERSCOCAINE         2
# 2015KANSASHOSPITALSCOCAINE                  2
# 2015WASHINGTONPRACTITIONERSCOCAINE          2
# 2015NEW YORKPRACTITIONERSCOCAINE            2
# 2015CONNECTICUTPRACTITIONERSCOCAINE         2
# 2015ILLINOISPRACTITIONERSCOCAINE            2
# 2015ILLINOISHOSPITALSCOCAINE                2
# 2015LOUISIANAHOSPITALSCOCAINE               2
# 2015TENNESSEEHOSPITALSCOCAINE               2
# 2015IOWAPRACTITIONERSCOCAINE                2
# 2015NEW JERSEYPRACTITIONERSCOCAINE          2
# 2015OREGONPRACTITIONERSCOCAINE              2
# 2015ARIZONAPRACTITIONERSCOCAINE             2
# 2015PENNSYLVANIAPRACTITIONERSCOCAINE        2
# 2015KENTUCKYHOSPITALSCOCAINE                2
# 2015OREGONHOSPITALSCOCAINE                  2
# 2015ARIZONAPHARMACIESCOCAINE                2
# 2015GEORGIAHOSPITALSCOCAINE                 2
# 2015CONNECTICUTHOSPITALSCOCAINE             2
# 2015NORTH CAROLINAPRACTITIONERSCOCAINE      2
# 2015MARYLANDHOSPITALSCOCAINE                2
# 2015MISSOURIHOSPITALSCOCAINE                2
# 2015OKLAHOMAHOSPITALSCOCAINE                2
# 2015NEW YORKHOSPITALSCOCAINE                2
# 2015WEST VIRGINIAPHARMACIESCOCAINE          2
# 2015MASSACHUSETTSHOSPITALSCOCAINE           2
# 2015DELAWAREHOSPITALSCOCAINE                2
# 2015ARKANSASHOSPITALSCOCAINE                2
# 2015SOUTH DAKOTAHOSPITALSCOCAINE            2
# 2015VIRGINIAPRACTITIONERSCOCAINE            2
# Name: check, Length: 70, dtype: int64
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2016 file...
# Averages check passed
# Repeats checks passed
# State values not matching: {'UNITED STATES'}
#
#
# Checking 2017 file...
# Averages check passed
# Repeats errors:
# 2017WYOMINGPRACTITIONERSHYDROCODONE                             2
# 2017WYOMINGPHARMACIESCODEINE                                    2
# 2017WYOMINGHOSPITALSOPIUM POWDERED                              2
# 2017WYOMINGHOSPITALSHYDROMORPHONE                               2
# 2017WYOMINGHOSPITALSBUPRENORPHINE                               2
# 2017WYOMINGPHARMACIESDL-METHAMPHETAMINE RACEMIC BASE            2
# 2017WYOMINGHOSPITALSPENTOBARBITAL (SCHEDULE 2)                  2
# 2017WYOMINGPHARMACIESREMIFENTANIL                               2
# 2017WYOMINGHOSPITALSMETHADONE                                   2
# 2017WYOMINGMID-LEVEL PRACTITIONERSOXYCODONE                     2
# 2017WYOMINGPRACTITIONERSPENTOBARBITAL (SCHEDULE 2)              2
# 2017WYOMINGPHARMACIESLISDEXAMFETAMINE                           2
# 2017WYOMINGPHARMACIESBUPRENORPHINE                              2
# 2017WYOMINGPHARMACIESBUTALBITAL                                 2
# 2017WYOMINGPHARMACIESTAPENTADOL                                 2
# 2017WYOMINGHOSPITALSHYDROCODONE                                 2
# 2017WYOMINGPRACTITIONERSMEPERIDINE (PETHIDINE)                  2
# 2017WYOMINGHOSPITALSBUTALBITAL                                  2
# 2017WYOMINGPHARMACIESHYDROCODONE                                2
# 2017WYOMINGTEACHING INSTITUTIONSBUPRENORPHINE                   2
# 2017WYOMINGPRACTITIONERSBUPRENORPHINE                           2
# 2017WYOMINGPRACTITIONERSMORPHINE                                2
# 2017WYOMINGHOSPITALSCOCAINE                                     2
# 2017WYOMINGHOSPITALSSUFENTANIL BASE                             2
# 2017WYOMINGHOSPITALSREMIFENTANIL                                2
# 2017WYOMINGHOSPITALSLISDEXAMFETAMINE                            2
# 2017WYOMINGPHARMACIESOPIUM POWDERED                             2
# 2017WYOMINGHOSPITALSMETHYLPHENIDATE                             2
# 2017WYOMINGHOSPITALSFENTANYL BASE                               2
# 2017WYOMINGPRACTITIONERSHYDROMORPHONE                           2
# 2017WYOMINGPHARMACIESMETHYLPHENIDATE                            2
# 2017WYOMINGPHARMACIESBARBITURIC ACID DERIVIATIVE OR SALT        2
# 2017WYOMINGPHARMACIESETORPHINE                                  2
# 2017WYOMINGHOSPITALSOXYCODONE                                   2
# 2017WYOMINGPHARMACIESMETHADONE                                  2
# 2017WYOMINGPRACTITIONERSFENTANYL BASE                           2
# 2017WYOMINGHOSPITALSMEPERIDINE (PETHIDINE)                      2
# 2017WYOMINGHOSPITALSCODEINE                                     2
# 2017WYOMINGPHARMACIESMEPERIDINE (PETHIDINE)                     2
# 2017WYOMINGMID-LEVEL PRACTITIONERSCODEINE                       2
# 2017WYOMINGPHARMACIESOXYCODONE                                  2
# 2017WYOMINGPRACTITIONERSCODEINE                                 2
# 2017WYOMINGPHARMACIESMORPHINE                                   2
# 2017WYOMINGPHARMACIESOPIUM COMBINATION PRODUCT (C-III)          2
# 2017WYOMINGPHARMACIESHYDROMORPHONE                              2
# 2017WYOMINGHOSPITALSTAPENTADOL                                  2
# 2017WYOMINGHOSPITALSAMPHETAMINE                                 2
# 2017WYOMINGPHARMACIESAMPHETAMINE                                2
# 2017WYOMINGHOSPITALSMORPHINE                                    2
# 2017WYOMINGMID-LEVEL PRACTITIONERSPENTOBARBITAL (SCHEDULE 2)    2
# 2017WYOMINGPHARMACIESCOCAINE                                    2
# 2017WYOMINGPRACTITIONERSOXYCODONE                               2
# 2017WYOMINGPHARMACIESFENTANYL BASE                              2
# 2017WYOMINGMID-LEVEL PRACTITIONERSHYDROCODONE                   2
# 2017WYOMINGPHARMACIESOXYMORPHONE                                2
# 2017WYOMINGHOSPITALSALFENTANIL                                  2
# Name: check, dtype: int64
# State values not matching: {'UNITED STATES'}

# %% [markdown]
# The repeats checking function turned up a lot to investigate, most of which is probably related to the 9041 / 9041L cocaine codes, but there are some other things to look at.
#
# Starting with 2010, Oregon-practictioners-cocaine and California-practitioners-cocaine.

# %%
activity_2010.loc[(activity_2010['State']=='OREGON')
             & (activity_2010['Drug']=='COCAINE')]
# Out:
#       Year   State Business Activity     Drug  Registrants  Total grams sold  \
# 3770  2010  OREGON        PHARMACIES  COCAINE           14            156.45
# 3801  2010  OREGON         HOSPITALS  COCAINE           49            502.04
# 3826  2010  OREGON     PRACTITIONERS  COCAINE            1              0.00
# 3827  2010  OREGON     PRACTITIONERS  COCAINE           20             89.85
#
#       Avg grams/registrant
# 3770                 11.18
# 3801                 10.25
# 3826                  0.00
# 3827                  4.49

# %%
check_2010 = pd.read_csv('activity_2010.txt', delim_whitespace=True)
check_2010.iloc[3825:3829]
# Out:
#               ARCOS          3   -    REPORT     5 STATISTICAL SUMMARY  FOR  \
# 3825  PENTOBARBITAL  (SCHEDULE  2)      2270   130  107,185.27   824.5  NaN
# 3826        COCAINE       9041   1         0     0         NaN     NaN  NaN
# 3827        COCAINE      9041L  20     89.85  4.49         NaN     NaN  NaN
# 3828        CODEINE       9050  62  1,128.29  18.2         NaN     NaN  NaN
#
#      RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 3825    NaN   NaN        NaN NaN    NaN NaN
# 3826    NaN   NaN        NaN NaN    NaN NaN
# 3827    NaN   NaN        NaN NaN    NaN NaN
# 3828    NaN   NaN        NaN NaN    NaN NaN

# %%
activity_2010.loc[(activity_2010['State']=='CALIFORNIA')
             & (activity_2010['Drug']=='COCAINE')]
# Out:
#      Year       State      Business Activity     Drug  Registrants  \
# 403  2010  CALIFORNIA             PHARMACIES  COCAINE           82
# 433  2010  CALIFORNIA              HOSPITALS  COCAINE          424
# 464  2010  CALIFORNIA          PRACTITIONERS  COCAINE            1
# 465  2010  CALIFORNIA          PRACTITIONERS  COCAINE          122
# 491  2010  CALIFORNIA  TEACHING INSTITUTIONS  COCAINE            1
#
#      Total grams sold  Avg grams/registrant
# 403            734.10                  8.95
# 433           4669.99                 11.01
# 464              0.00                  0.00
# 465            392.49                  3.22
# 491              4.46                  4.46

# %%
check_2010.iloc[463:466]
# Out:
#              ARCOS          3    -  REPORT     5   STATISTICAL   SUMMARY  FOR  \
# 463  PENTOBARBITAL  (SCHEDULE   2)    2270   507  1,745,954.32  3,443.70  NaN
# 464        COCAINE       9041    1       0     0           NaN       NaN  NaN
# 465        COCAINE      9041L  122  392.49  3.22           NaN       NaN  NaN
#
#     RETAIL  DRUG  PURCHASES  BY  GRAMS  WT
# 463    NaN   NaN        NaN NaN    NaN NaN
# 464    NaN   NaN        NaN NaN    NaN NaN
# 465    NaN   NaN        NaN NaN    NaN NaN

# %% [markdown]
# Since these are both related to the 9041 code and are zeros, I will drop them out.

# %%
activity_2010 = activity_2010.drop(labels = [3826, 464], axis='index')
del check_2010

# %%
repeats_check_activity(activity_2010)
# Out:
# Repeats checks passed

# %% [markdown]
# There are so many results for 2011 - 2015 that are related to cocaine that it is easiest to drop out any rows that are cocaine but have zero grams distributed, and then run the repeats check again.

# %%
activity_2011 = activity_2011.drop(activity_2011.loc[(activity_2011['Drug']=='COCAINE')
                 & (activity_2011['Total grams sold']==0)].index)

# %%
repeats_check_activity(activity_2011)
# Out:
# Repeats checks passed

# %%
activity_2012 = activity_2012.drop(activity_2012.loc[(activity_2012['Drug']=='COCAINE')
                 & (activity_2012['Total grams sold']==0)].index)

# %%
repeats_check_activity(activity_2012)
# Out:
# Repeats checks passed

# %%
activity_2013 = activity_2013.drop(activity_2013.loc[(activity_2013['Drug']=='COCAINE')
                 & (activity_2013['Total grams sold']==0)].index)

# %%
repeats_check_activity(activity_2013)
# Out:
# Repeats checks passed

# %%
activity_2014 = activity_2014.drop(activity_2014.loc[(activity_2014['Drug']=='COCAINE')
                 & (activity_2014['Total grams sold']==0)].index)

# %%
repeats_check_activity(activity_2014)
# Out:
# Repeats checks passed

# %%
activity_2015 = activity_2015.drop(activity_2015.loc[(activity_2015['Drug']=='COCAINE')
                 & (activity_2015['Total grams sold']==0)].index)

# %%
repeats_check_activity(activity_2015)
# Out:
# Repeats checks passed

# %% [markdown]
# For the 2017 data, there are repeating rows related to a number of drugs that are not cocaine, and they are all related to the state of Wyoming, so we need to examine more carefully.

# %%
activity_2017.loc[(activity_2017['State']=='WYOMING')
                 & (activity_2017['Drug']=='CODEINE')
                 & (activity_2017['Business Activity']=='PHARMACIES')]
# Out:
#       Year    State Business Activity     Drug  Registrants  Total grams sold  \
# 5028  2017  WYOMING        PHARMACIES  CODEINE          119          14898.72
# 5107  2017  WYOMING        PHARMACIES  CODEINE        65917       15427479.78
#
#       Avg grams/registrant
# 5028                125.20
# 5107                234.04

# %%
check_2017 = pd.read_csv('activity_2017.txt', delim_whitespace=True)
check_2017.iloc[5026:5030]
# Out:
#            ARCOS      3    -     REPORT      5 STATISTICAL SUMMARY  FOR  \
# 5026  BUTALBITAL   2165   46      1,605  34.89         NaN     NaN  NaN
# 5027     COCAINE  9041L    2      21.14  10.57         NaN     NaN  NaN
# 5028     CODEINE   9050  119  14,898.72  125.2         NaN     NaN  NaN
# 5029   ETORPHINE   9056    1         57     57         NaN     NaN  NaN
#
#      RETAIL DRUG PURCHASES  BY  GRAMS  WT
# 5026    NaN  NaN       NaN NaN    NaN NaN
# 5027    NaN  NaN       NaN NaN    NaN NaN
# 5028    NaN  NaN       NaN NaN    NaN NaN
# 5029    NaN  NaN       NaN NaN    NaN NaN

# %%
check_2017.iloc[5105:5110]
# Out:
#               ARCOS      3       -         REPORT       5 STATISTICAL SUMMARY  \
# 5105       NABILONE   7379      65          13.75    0.21         NaN     NaN
# 5106        COCAINE  9041L     206       1,408.73    6.84         NaN     NaN
# 5107        CODEINE   9050  65,917  15,427,479.78  234.04         NaN     NaN
# 5108      ETORPHINE   9056       1             57      57         NaN     NaN
# 5109  BUPRENORPHINE   9064  59,274   3,179,903.93   53.65         NaN     NaN
#
#       FOR RETAIL DRUG PURCHASES  BY  GRAMS  WT
# 5105  NaN    NaN  NaN       NaN NaN    NaN NaN
# 5106  NaN    NaN  NaN       NaN NaN    NaN NaN
# 5107  NaN    NaN  NaN       NaN NaN    NaN NaN
# 5108  NaN    NaN  NaN       NaN NaN    NaN NaN
# 5109  NaN    NaN  NaN       NaN NaN    NaN NaN

# %% [markdown]
# This looks like it may actually be a forward fill issue.

# %%
check_2017.iloc[5000:5030]
# Out:
#                    ARCOS                 3             -      REPORT  \
# 5000               OPIUM          POWDERED          9639           7
# 5001         OXYMORPHONE              9652            10       10.03
# 5002          ALFENTANIL              9737            14        4.06
# 5003        REMIFENTANIL              9739            15        0.88
# 5004          SUFENTANIL              BASE          9740           3
# 5005            FENTANYL              BASE          9801         337
# 5006     STATE:WISCONSIN          BUSINESS    ACTIVITY:M           -
# 5007                DRUG              NAME          DRUG        CODE
# 5008       PENTOBARBITAL         (SCHEDULE            2)        2270
# 5009             CODEINE              9050             1        2.23
# 5010            MORPHINE              9300             2        5.83
# 5011            FENTANYL              BASE          9801           1
# 5012     STATE:WISCONSIN          BUSINESS  ACTIVITY:N-U    NARCOTIC
# 5013                DRUG              NAME          DRUG        CODE
# 5014       BUPRENORPHINE              9064             8    1,883.52
# 5015           METHADONE             9250B            19  222,981.97
# 5016       STATE:WYOMING          BUSINESS    ACTIVITY:A           -
# 5017                DRUG              NAME          DRUG        CODE
# 5018         AMPHETAMINE              1100           119   24,045.57
# 5019  DL-METHAMPHETAMINE           RACEMIC          BASE       1105B
# 5020    LISDEXAMFETAMINE              1205           118   10,068.77
# 5021     METHYLPHENIDATE  (DL;D;L;ISOMERS)          1724         119
# 5022          BARBITURIC              ACID   DERIVIATIVE          OR
# 5023                DATE            RANGE:    01/01/2017          TO
# 5024         STATISTICAL           SUMMARY           FOR      RETAIL
# 5025                 Run             Date:    07/03/2018         NaN
# 5026          BUTALBITAL              2165            46       1,605
# 5027             COCAINE             9041L             2       21.14
# 5028             CODEINE              9050           119   14,898.72
# 5029           ETORPHINE              9056             1          57
#
#                5    STATISTICAL SUMMARY    FOR  RETAIL   DRUG PURCHASES  BY  \
# 5000       37.08            5.3     NaN    NaN     NaN    NaN       NaN NaN
# 5001           1            NaN     NaN    NaN     NaN    NaN       NaN NaN
# 5002        0.29            NaN     NaN    NaN     NaN    NaN       NaN NaN
# 5003        0.06            NaN     NaN    NaN     NaN    NaN       NaN NaN
# 5004        0.01              0     NaN    NaN     NaN    NaN       NaN NaN
# 5005       48.78           0.14     NaN    NaN     NaN    NaN       NaN NaN
# 5006   MID-LEVEL  PRACTITIONERS     NaN    NaN     NaN    NaN       NaN NaN
# 5007      BUYERS          TOTAL   GRAMS    AVG   GRAMS    NaN       NaN NaN
# 5008          21      12,552.62  597.74    NaN     NaN    NaN       NaN NaN
# 5009        2.23            NaN     NaN    NaN     NaN    NaN       NaN NaN
# 5010        2.91            NaN     NaN    NaN     NaN    NaN       NaN NaN
# 5011        0.01           0.01     NaN    NaN     NaN    NaN       NaN NaN
# 5012   TREATMENT       PROGRAMS     NaN    NaN     NaN    NaN       NaN NaN
# 5013      BUYERS          TOTAL   GRAMS    AVG   GRAMS    NaN       NaN NaN
# 5014      235.44            NaN     NaN    NaN     NaN    NaN       NaN NaN
# 5015   11,735.89            NaN     NaN    NaN     NaN    NaN       NaN NaN
# 5016  PHARMACIES            NaN     NaN    NaN     NaN    NaN       NaN NaN
# 5017      BUYERS          TOTAL   GRAMS    AVG   GRAMS    NaN       NaN NaN
# 5018      202.06            NaN     NaN    NaN     NaN    NaN       NaN NaN
# 5019           5           21.3    4.26    NaN     NaN    NaN       NaN NaN
# 5020       85.33            NaN     NaN    NaN     NaN    NaN       NaN NaN
# 5021   30,396.30         255.43     NaN    NaN     NaN    NaN       NaN NaN
# 5022        SALT           [PER     21C   2100      30  1,525     50.83 NaN
# 5023  12/31/2017          ARCOS       3      -  REPORT      5       NaN NaN
# 5024        DRUG      PURCHASES      BY  GRAMS      WT    NaN       NaN NaN
# 5025         NaN            NaN     NaN    NaN     NaN    NaN       NaN NaN
# 5026       34.89            NaN     NaN    NaN     NaN    NaN       NaN NaN
# 5027       10.57            NaN     NaN    NaN     NaN    NaN       NaN NaN
# 5028       125.2            NaN     NaN    NaN     NaN    NaN       NaN NaN
# 5029          57            NaN     NaN    NaN     NaN    NaN       NaN NaN
#
#       GRAMS  WT
# 5000    NaN NaN
# 5001    NaN NaN
# 5002    NaN NaN
# 5003    NaN NaN
# 5004    NaN NaN
# 5005    NaN NaN
# 5006    NaN NaN
# 5007    NaN NaN
# 5008    NaN NaN
# 5009    NaN NaN
# 5010    NaN NaN
# 5011    NaN NaN
# 5012    NaN NaN
# 5013    NaN NaN
# 5014    NaN NaN
# 5015    NaN NaN
# 5016    NaN NaN
# 5017    NaN NaN
# 5018    NaN NaN
# 5019    NaN NaN
# 5020    NaN NaN
# 5021    NaN NaN
# 5022    NaN NaN
# 5023    NaN NaN
# 5024    NaN NaN
# 5025    NaN NaN
# 5026    NaN NaN
# 5027    NaN NaN
# 5028    NaN NaN
# 5029    NaN NaN

# %%
check_2017.iloc[5067:5107]
# Out:
#                    ARCOS                 3            -         REPORT  \
# 5067            FENTANYL              BASE         9801             45
# 5068       STATE:WYOMING          BUSINESS   ACTIVITY:C              -
# 5069                DRUG              NAME         DRUG           CODE
# 5070       PENTOBARBITAL         (SCHEDULE           2)           2270
# 5071             CODEINE              9050           13         218.35
# 5072       BUPRENORPHINE              9064           58           2.04
# 5073           OXYCODONE              9143            1           9.75
# 5074       HYDROMORPHONE              9150           40          18.51
# 5075         HYDROCODONE              9193           26         186.32
# 5076          MEPERIDINE       (PETHIDINE)         9230              4
# 5077            MORPHINE              9300           35           46.7
# 5078            FENTANYL              BASE         9801             39
# 5079       STATE:WYOMING          BUSINESS   ACTIVITY:D              -
# 5080                DRUG              NAME         DRUG           CODE
# 5081       BUPRENORPHINE              9064            1              0
# 5082       STATE:WYOMING          BUSINESS   ACTIVITY:M              -
# 5083                DRUG              NAME         DRUG           CODE
# 5084       PENTOBARBITAL         (SCHEDULE           2)           2270
# 5085             CODEINE              9050            1           10.8
# 5086           OXYCODONE              9143            1           0.54
# 5087         HYDROCODONE              9193            1           0.36
# 5088                DATE            RANGE:   01/01/2017             TO
# 5089              UNITED            STATES      SUMMARY            FOR
# 5090                 Run             Date:   07/05/2018            NaN
# 5091              ENTIRE            UNITED       STATES       BUSINESS
# 5092                DRUG              NAME         DRUG           CODE
# 5093         AMPHETAMINE              1100       64,254  20,407,502.81
# 5094  DL-METHAMPHETAMINE           RACEMIC         BASE          1105B
# 5095   D-METHAMPHETAMINE             1105D          121         469.99
# 5096    LISDEXAMFETAMINE              1205       59,765   9,592,434.05
# 5097     METHYLPHENIDATE  (DL;D;L;ISOMERS)         1724         63,671
# 5098               GAMMA    HYDROXYBUTYRIC     ACID(FDA   APPROVED-CSA
# 5099          BARBITURIC              ACID  DERIVIATIVE             OR
# 5100         AMOBARBITAL         (SCHEDULE           2)           2125
# 5101          BUTALBITAL              2165       24,330        847,360
# 5102       PENTOBARBITAL         (SCHEDULE           2)           2270
# 5103        SECOBARBITAL         (SCHEDULE           2)           2315
# 5104          DRONABINOL                IN           AN           ORAL
# 5105            NABILONE              7379           65          13.75
# 5106             COCAINE             9041L          206       1,408.73
#
#                   5    STATISTICAL    SUMMARY             FOR         RETAIL  \
# 5067           84.7           1.88        NaN             NaN            NaN
# 5068  PRACTITIONERS            NaN        NaN             NaN            NaN
# 5069         BUYERS          TOTAL      GRAMS             AVG          GRAMS
# 5070             38      40,259.73   1,059.47             NaN            NaN
# 5071           16.8            NaN        NaN             NaN            NaN
# 5072           0.04            NaN        NaN             NaN            NaN
# 5073           9.75            NaN        NaN             NaN            NaN
# 5074           0.46            NaN        NaN             NaN            NaN
# 5075           7.17            NaN        NaN             NaN            NaN
# 5076          10.02           2.51        NaN             NaN            NaN
# 5077           1.33            NaN        NaN             NaN            NaN
# 5078           1.87           0.05        NaN             NaN            NaN
# 5079       TEACHING   INSTITUTIONS        NaN             NaN            NaN
# 5080         BUYERS          TOTAL      GRAMS             AVG          GRAMS
# 5081              0            NaN        NaN             NaN            NaN
# 5082      MID-LEVEL  PRACTITIONERS        NaN             NaN            NaN
# 5083         BUYERS          TOTAL      GRAMS             AVG          GRAMS
# 5084              2         177.72      88.86             NaN            NaN
# 5085           10.8            NaN        NaN             NaN            NaN
# 5086           0.54            NaN        NaN             NaN            NaN
# 5087           0.36            NaN        NaN             NaN            NaN
# 5088     12/31/2017          ARCOS          3               -         REPORT
# 5089         RETAIL           DRUG  PURCHASES              BY          GRAMS
# 5090            NaN            NaN        NaN             NaN            NaN
# 5091      ACTIVITY:              A          -      PHARMACIES            NaN
# 5092         BUYERS          TOTAL      GRAMS             AVG          GRAMS
# 5093         317.61            NaN        NaN             NaN            NaN
# 5094          1,944       6,893.33       3.55             NaN            NaN
# 5095           3.88            NaN        NaN             NaN            NaN
# 5096          160.5            NaN        NaN             NaN            NaN
# 5097  17,701,935.44         278.02        NaN             NaN            NaN
# 5098           III)           2012          1   30,411,958.46  30,411,958.46
# 5099           SALT           [PER      21CFR  1308.13(C)(3)]           2100
# 5100              2           0.91       0.46             NaN            NaN
# 5101          34.83            NaN        NaN             NaN            NaN
# 5102              9         880.93      97.88             NaN            NaN
# 5103            267      10,024.73      37.55             NaN            NaN
# 5104       SOLUTION             IN        FDA        APPROVED           DRUG
# 5105           0.21            NaN        NaN             NaN            NaN
# 5106           6.84            NaN        NaN             NaN            NaN
#
#         DRUG PURCHASES      BY   GRAMS    WT
# 5067     NaN       NaN     NaN     NaN   NaN
# 5068     NaN       NaN     NaN     NaN   NaN
# 5069     NaN       NaN     NaN     NaN   NaN
# 5070     NaN       NaN     NaN     NaN   NaN
# 5071     NaN       NaN     NaN     NaN   NaN
# 5072     NaN       NaN     NaN     NaN   NaN
# 5073     NaN       NaN     NaN     NaN   NaN
# 5074     NaN       NaN     NaN     NaN   NaN
# 5075     NaN       NaN     NaN     NaN   NaN
# 5076     NaN       NaN     NaN     NaN   NaN
# 5077     NaN       NaN     NaN     NaN   NaN
# 5078     NaN       NaN     NaN     NaN   NaN
# 5079     NaN       NaN     NaN     NaN   NaN
# 5080     NaN       NaN     NaN     NaN   NaN
# 5081     NaN       NaN     NaN     NaN   NaN
# 5082     NaN       NaN     NaN     NaN   NaN
# 5083     NaN       NaN     NaN     NaN   NaN
# 5084     NaN       NaN     NaN     NaN   NaN
# 5085     NaN       NaN     NaN     NaN   NaN
# 5086     NaN       NaN     NaN     NaN   NaN
# 5087     NaN       NaN     NaN     NaN   NaN
# 5088       7       NaN     NaN     NaN   NaN
# 5089      WT       NaN     NaN     NaN   NaN
# 5090     NaN       NaN     NaN     NaN   NaN
# 5091     NaN       NaN     NaN     NaN   NaN
# 5092     NaN       NaN     NaN     NaN   NaN
# 5093     NaN       NaN     NaN     NaN   NaN
# 5094     NaN       NaN     NaN     NaN   NaN
# 5095     NaN       NaN     NaN     NaN   NaN
# 5096     NaN       NaN     NaN     NaN   NaN
# 5097     NaN       NaN     NaN     NaN   NaN
# 5098     NaN       NaN     NaN     NaN   NaN
# 5099  18,623   596,769   32.04     NaN   NaN
# 5100     NaN       NaN     NaN     NaN   NaN
# 5101     NaN       NaN     NaN     NaN   NaN
# 5102     NaN       NaN     NaN     NaN   NaN
# 5103     NaN       NaN     NaN     NaN   NaN
# 5104   PRODU      7365  191.00  341.25  1.79
# 5105     NaN       NaN     NaN     NaN   NaN
# 5106     NaN       NaN     NaN     NaN   NaN

# %% [markdown]
# Turns out this was a forward fill problem, so the duplicate checker worked exactly as intended. In row 5091 you can see that we are getting US total data and it just didn't get picked up properly in cleaning, so all those rows were marked as Wyoming data.
#
# The reason for this is that the 2017 file deviated from the expected format of having "STATE:" concatenated with the geography name in the first column.
#
# The cleaning function for new files now includes a line to handle this specific case. Below I'll rerun the 2017 cleaning.

# %%
activity_2017 = pd.read_csv('activity_2017.txt', delim_whitespace=True)
check_activity_new(activity_2017, flat_geos=flat_geos, 
                   flat_activity_codes=flat_activity_codes)
# Out:
# Unusual numerical values in column A:
# ['30,411,958.46']
#
# Unexpected activity code  in column E:
# Unusual numerical values in column A
# ['30,411,958.46']
#
# Unexpected value in column B for states: BUSINESS
# Unexpected value in column C for states: ACTIVITY:A
# Unexpected value in column C for states: ACTIVITY:B
# Unexpected value in column C for states: ACTIVITY:C
# Unexpected value in column C for states: ACTIVITY:D
# Unexpected value in column C for states: ACTIVITY:M
# Unexpected value in column C for states: ACTIVITY:N-U
# Unexpected value in column C for states: BUSINESS
# Checking column B
# Drug codes found in column B:
# ['1100', '1105D', '1205', '2165', '9050', '9064', '9120', '9143', '9150', '9193', '9220L', '9250B', '9300', '9652', '9780', '9041L', '9737', '9739', '7379', '9668', '9333', '9056']
# non-numeric values in column B:
# ['Date:' 'BUSINESS' 'NAME' 'RACEMIC' '(DL;D;L;ISOMERS)' 'ACID' 'IN'
#  '(PETHIDINE)' 'POWDERED' 'BASE' 'COMBINATION' '(SCHEDULE' 'RANGE:'
#  'SUMMARY' 'SAMOA' 'TINCTURE' 'HYDROXYBUTYRIC' 'OF' nan 'HAMPSHIRE'
#  'JERSEY' 'MEXICO' 'YORK' 'CAROLINA' 'DAKOTA' 'RICO' 'ISLAND' 'ISLANDS'
#  'VIRGINIA' 'STATES' 'UNITED' 'ACTIVITY:A' '(SYNDROS']
#
# Checking column C
# Drug codes found in column C:
# ['1724', '9230', '9639', '9801', '9740']
# non-numeric values in column C:
# ['ACTIVITY:A' 'DRUG' 'BASE' 'DERIVIATIVE' 'AN' 'PRODUCT' 'ACTIVITY:B'
#  'FOR' 'ACTIVITY:C' 'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U' 'BUSINESS'
#  '(LAUDANUM)' 'ACID(FDA' 'COLUMBIA' nan 'SUMMARY' 'STATES' '-']
#
# Checking column D
# Drug codes found in column D:
# ['1105B', '2270', '2315', '2125', '9630']
# non-numeric values in column D:
# [nan '-' 'CODE' 'OR' 'ORAL' '(C-III)' 'TO' 'RETAIL' 'NARCOTIC'
#  'ACTIVITY:B' 'ACTIVITY:C' 'APPROVED' 'BUSINESS' 'ACTIVITY:A' 'ACTIVITY:M'
#  'ACTIVITY:N-U' 'ACTIVITY:D' 'FOR' 'APPROVED-CSA' 'PHARMACIES' 'CII)']
#
# Checking column E
# Drug codes found in column E:
# ['9809', '2012', '7365']
# non-numeric values in column E:
# [nan 'PHARMACIES' 'BUYERS' 'SALT' 'SOLUTION' 'HOSPITALS' 'DRUG'
#  'PRACTITIONERS' 'TEACHING' 'MID-LEVEL' 'TREATMENT' '-' 'ACTIVITY:A'
#  'ACTIVITY:B' 'ACTIVITY:C' 'ACTIVITY:D' 'ACTIVITY:M' 'ACTIVITY:N-U'
#  'NARCOTIC' 'RETAIL' 'ACTIVITY:' 'III)']
#
# Checking column F
# Drug codes found in column F:
# ['2012']
# non-numeric values in column F:
# [nan 'TOTAL' '[PER' 'IN' 'ARCOS' 'PURCHASES' 'INSTITUTIONS'
#  'PRACTITIONERS' 'PROGRAMS' 'HOSPITALS' '-' 'NARCOTIC' 'PHARMACIES'
#  'MID-LEVEL' 'TREATMENT' 'TEACHING' 'DRUG' 'A' 'B' 'C' 'D' 'M' 'N-U']
#
# Checking column G
# No drug codes found.
# non-numeric values in column G:
# [nan 'GRAMS' 'FDA' 'BY' 'PHARMACIES' 'HOSPITALS' 'PRACTITIONERS'
#  'TEACHING' 'MID-LEVEL' 'TREATMENT' 'PROGRAMS' 'INSTITUTIONS' 'PURCHASES'
#  '-' 'NARCOTIC']
#
# Checking column FOR
# Drug codes found in column FOR:
# ['2100', '1308.13(C)(3)]']
# Unexpected code found: 1308.13(C)(3)]
# non-numeric values in column FOR:
# [nan 'AVG' 'APPR' '-' 'GRAMS' 'INSTITUTIONS' 'PRACTITIONERS' 'BY'
#  'PHARMACIES' 'APPROVED' 'HOSPITALS' 'TEACHING' 'MID-LEVEL' 'TREATMENT']
#
# Checking column RETAIL
# Drug codes found in column RETAIL:
# ['7365', '2100', '3133.15']
# Unexpected code found: 3133.15
# non-numeric values in column RETAIL:
# [nan 'GRAMS' 'REPORT' 'WT' 'DRUG' 'INSTITUTIONS' 'PRACTITIONERS'
#  'PROGRAMS']
#
# Checking column DRUG
# No drug codes found.
# non-numeric values in column DRUG:
# [nan 'WT' 'PRODU']
#
# Checking column PURCHASES
# Drug codes found in column PURCHASES:
# ['7365']
# non-numeric values in column PURCHASES:
# [nan]
#
# Checking column BY
# No drug codes found.
# non-numeric values in column BY:
# [nan]
#
# Checking column GRAMS
# No drug codes found.
# non-numeric values in column GRAMS:
# [nan]
#
# Checking column WT
# No drug codes found.
# non-numeric values in column WT:
# [nan]

# %%
activity_2017.loc[2449, 'FOR'] = activity_2017.loc[2450, 'A']
activity_2017.loc[5140, 'RETAIL'] = '3,133.15'
activity_2017.loc[activity_2017['FOR']=='1308.13(C)(3)]', 'FOR'] = '1,308.13(C)(3)]'
activity_2017 = clean_activity_new(activity_2017, year=2017, 
                                   drug_codes=drug_codes, flat_geos=flat_geos, 
                                   activity_codes=activity_codes)
activity_2017.head()
# Out:
#    Year    State Business Activity                             Drug  \
# 3  2017  ALABAMA        PHARMACIES                      AMPHETAMINE
# 4  2017  ALABAMA        PHARMACIES  DL-METHAMPHETAMINE RACEMIC BASE
# 5  2017  ALABAMA        PHARMACIES                D-METHAMPHETAMINE
# 6  2017  ALABAMA        PHARMACIES                 LISDEXAMFETAMINE
# 7  2017  ALABAMA        PHARMACIES                  METHYLPHENIDATE
#
#    Registrants  Total grams sold  Avg grams/registrant
# 3         1371         513195.41                374.32
# 4           32             96.04                  3.00
# 5            4             14.86                  3.72
# 6         1328         282505.33                212.73
# 7         1352         283489.85                209.68

# %%
avgs_check(activity_2017)
repeats_check_zip(activity_2017)
check_states(activity_2017, geos)
# Out:
# Averages check passed
# Repeats checks passed
# All expected state values present

# %%
activity_dfs = {'2000': activity_2000, '2001': activity_2001, 
                '2002': activity_2002, '2003': activity_2003, 
                '2004': activity_2004, '2005': activity_2005, 
                '2006': activity_2006, '2007': activity_2007, 
                '2008': activity_2008, '2009': activity_2009, 
                '2010': activity_2010, '2011': activity_2011, 
                '2012': activity_2012, '2013': activity_2013, 
                '2014': activity_2014, '2015': activity_2015, 
                '2016': activity_2016, '2017': activity_2017}


activity_all = pd.concat(list(activity_dfs.values()), ignore_index=True)

# to be consistent with the other data, we'll drop the US totals
activity_all = activity_all.drop(activity_all[activity_all['State']=='UNITED STATES'].index)


activity_all.to_csv('distribution_by_activity.csv', index=False)

# %% [markdown]
# Data cleansing finished! On to do some exploratory data analysis and visualization.

# %%
activity_all.tail()
# Out:
#        Year    State        Business Activity                        Drug  \
# 61347  2017  WYOMING    TEACHING INSTITUTIONS               BUPRENORPHINE
# 61348  2017  WYOMING  MID-LEVEL PRACTITIONERS  PENTOBARBITAL (SCHEDULE 2)
# 61349  2017  WYOMING  MID-LEVEL PRACTITIONERS                     CODEINE
# 61350  2017  WYOMING  MID-LEVEL PRACTITIONERS                   OXYCODONE
# 61351  2017  WYOMING  MID-LEVEL PRACTITIONERS                 HYDROCODONE
#
#        Registrants  Total grams sold  Avg grams/registrant
# 61347            1              0.00                  0.00
# 61348            2            177.72                 88.86
# 61349            1             10.80                 10.80
# 61350            1              0.54                  0.54
# 61351            1              0.36                  0.36
